# %% [markdown]
# # **Data Retriever**

# %%
import MetaTrader5 as mt5
import pandas as pd
import ta.momentum as momentum
from datetime import datetime, timedelta
import time
import plotly.graph_objects as go

def get_historical_data(symbol, timeframe, start_date, end_date):
    if not mt5.initialize():
        print("initialize() failed ☢️")
        mt5.shutdown()
        return None

    rates = mt5.copy_rates_range(symbol, timeframe, start_date, end_date)
    print(f"Retrieved {len(rates)} data points")

    if rates is None:
        print("Failed to retrieve historical data. ☢️")
        mt5.shutdown()
        return None

    df = pd.DataFrame(rates)
    df["time"] = pd.to_datetime(df["time"], unit="s")
    df = df.set_index("time")

    mt5.shutdown()

    return df


def calculate_rsi(df, period=14):
    try:
        rsi_indicator = momentum.RSIIndicator(df["close"], window=period)
        df["rsi"] = rsi_indicator.rsi()
    except Exception as e:
        print(f"Error calculating RSI: {e}")

def find_filling_mode(symbol):
    for i in range(2):
        request = {
            "action": mt5.TRADE_ACTION_DEAL,
            "symbol": symbol,
            "volume": mt5.symbol_info(symbol).volume_min,
            "type": mt5.ORDER_TYPE_BUY,
            "price": mt5.symbol_info_tick(symbol).ask,
            "type_filling": i,
            "type_time": mt5.ORDER_TIME_GTC
        }

        result = mt5.order_check(request)

        if result.comment == "Done":
            print("Trade was closed")
            break

    return i

# %% [markdown]
# # **BackTest + Trade Visualizer + RSI (Maverick boom 1000/500/300)**

# %%
from plotly.subplots import make_subplots

def backtest_strategy(df, lot_size=0.2):
    trades = []
    in_trade = False

    for i in range(3, len(df)):
        current_bar = df.iloc[i]
        previous_bar = df.iloc[i - 1]
        confirmation_bar = df.iloc[i - 2]

        # Check for sell conditions
        if current_bar["rsi"] > 70 and confirmation_bar["close"] > confirmation_bar["open"] \
                and previous_bar["close"] < previous_bar["open"] \
                and current_bar["close"] < current_bar["open"]:
            
            if not in_trade:
                # Open a sell trade
                trade = {"entry_time": current_bar.name, "entry_price": current_bar["open"], "trade_type": "SELL"}
                trades.append(trade)
                in_trade = True

        # Check for trade closing condition
        if in_trade:
            if current_bar["close"] < current_bar["open"]:
                # Close the trade
                trades[-1]["exit_time"] = current_bar.name
                trades[-1]["exit_price"] = current_bar["close"]
                trades[-1]["pnl"] = trades[-1]["entry_price"] - trades[-1]["exit_price"]
                trades[-1]["pnl"] *= lot_size
                in_trade = False

    return trades

def plot_trades(df, trades):
    fig = go.Figure(data=[go.Candlestick(x=df.index,
                                        open=df['open'],
                                        high=df['high'],
                                        low=df['low'],
                                        close=df['close'],
                                        increasing_line_color='orange',
                                        decreasing_line_color='green',
                                        line_width=1)])

    entry_exit_traces = []  # Store entry and exit traces separately

    for trade in trades:
        entry_time = trade["entry_time"]
        entry_price = trade["entry_price"]
        exit_time = trade["exit_time"]
        exit_price = trade["exit_price"]

        entry_trace = go.Scatter(x=[entry_time], y=[entry_price],
                                 mode='markers',
                                 marker=dict(size=10, symbol='triangle-up', color='orange'))
        
        exit_trace = go.Scatter(x=[exit_time], y=[exit_price],
                                mode='markers',
                                marker=dict(size=10, symbol='triangle-down', color='green'))

        entry_exit_traces.append(entry_trace)
        entry_exit_traces.append(exit_trace)

    # Calculate RSI levels
    rsi_levels = df['rsi']
    rsi_oversold = [30] * len(df)
    rsi_overbought = [70] * len(df)

    # Create a subplot with shared x-axis
    subplot_fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.05)

    # Add candlestick chart to the first subplot
    subplot_fig.add_trace(go.Candlestick(x=df.index,
                                          open=df['open'],
                                          high=df['high'],
                                          low=df['low'],
                                          close=df['close'],
                                          increasing_line_color='orange',
                                          decreasing_line_color='green',
                                          line_width=1), row=1, col=1)

    # Add entry and exit traces to the first subplot
    for trace in entry_exit_traces:
        subplot_fig.add_trace(trace, row=1, col=1)

    # Add RSI plot to the second subplot
    subplot_fig.add_trace(go.Scatter(x=df.index, y=rsi_levels, name='RSI', line=dict(color='blue')), row=2, col=1)
    subplot_fig.add_trace(go.Scatter(x=df.index, y=rsi_oversold, name='Oversold', line=dict(color='red', dash='dash')), row=2, col=1)
    subplot_fig.add_trace(go.Scatter(x=df.index, y=rsi_overbought, name='Overbought', line=dict(color='green', dash='dash')), row=2, col=1)

    # Update layout of the subplots
    subplot_fig.update_layout(
        title="Backtest Trades with RSI",
        xaxis_title="Time",
        height=800,  # Set the height of the entire plot
        xaxis_rangeslider_visible=False,
        plot_bgcolor='black',
        paper_bgcolor='black',
        font=dict(color='white'),
        showlegend=True,
        autosize=True,
        margin=dict(l=50, r=50, t=50, b=50),
        xaxis_showgrid=False,
        yaxis_showgrid=False,
    )

    subplot_fig.show()


if __name__ == "__main__":
    symbol = "Boom 1000 Index"
    timeframe = mt5.TIMEFRAME_M1
    lot_size = 1.0
    period = 7.0

    # Specify the date range for historical data (adjust as needed)
    start_date = datetime(2023, 8, 16)
    end_date = datetime.now()
    #end_date = datetime(2023, 8, 16)
    # Step 1: Load historical data within the specified date range
    df = get_historical_data(symbol, timeframe, start_date, end_date)

    # Step 2: Calculate RSI
    calculate_rsi(df, period)

    # Step 3: Backtest the strategy
    trades = backtest_strategy(df, lot_size)

    # Step 4: Print the backtest results
    total_pnl = 0
    for trade in trades:
        print(f"Trade Type: {trade['trade_type']}")
        print(f"Entry Time: {trade['entry_time']}, Entry Price: {trade['entry_price']}")
        print(f"Exit Time: {trade['exit_time']}, Exit Price: {trade['exit_price']}")
        print(f"Profit/Loss: {trade['pnl']:.2f}\n")
        total_pnl += trade['pnl']

    print(f"Total Profit/Loss: {total_pnl:.2f}")
    print(f"Total Trades: {len(trades)}")

    # Step 5: Plot the trades
    plot_trades(df, trades)
# Out:
# Retrieved 1279 data points
# Trade Type: SELL
# Entry Time: 2023-08-15 23:15:00, Entry Price: 10461.738
# Exit Time: 2023-08-15 23:15:00, Exit Price: 10461.178
# Profit/Loss: 0.56
#
# Trade Type: SELL
# Entry Time: 2023-08-15 23:19:00, Entry Price: 10469.304
# Exit Time: 2023-08-15 23:19:00, Exit Price: 10468.579
# Profit/Loss: 0.73
#
# Trade Type: SELL
# Entry Time: 2023-08-15 23:49:00, Entry Price: 10492.78
# Exit Time: 2023-08-15 23:49:00, Exit Price: 10492.219
# Profit/Loss: 0.56
#
# Trade Type: SELL
# Entry Time: 2023-08-16 00:11:00, Entry Price: 10493.655
# Exit Time: 2023-08-16 00:11:00, Exit Price: 10493.127
# Profit/Loss: 0.53
#
# Trade Type: SELL
# Entry Time: 2023-08-16 00:32:00, Entry Price: 10498.588
# Exit Time: 2023-08-16 00:32:00, Exit Price: 10497.976
# Profit/Loss: 0.61
#
# Trade Type: SELL
# Entry Time: 2023-08-16 00:48:00, Entry Price: 10502.536
# Exit Time: 2023-08-16 00:48:00, Exit Price: 10501.877
# Profit/Loss: 0.66
#
# Trade Type: SELL
# Entry Time: 2023-08-16 01:53:00, Entry Price: 10496.541
# Exit Time: 2023-08-16 01:53:00, Exit Price: 10495.94
# Profit/Loss: 0.60
#
# Trade Type: SELL
# Entry Time: 2023-08-16 03:15:00, Entry Price: 10478.785
# Exit Time: 2023-08-16 03:15:00, Exit Price: 10478.261
# Profit/Loss: 0.52
#
# Trade Type: SELL
# Entry Time: 2023-08-16 04:05:00, Entry Price: 10465.743
# Exit Time: 2023-08-16 04:05:00, Exit Price: 10465.212
# Profit/Loss: 0.53
#
# Trade Type: SELL
# Entry Time: 2023-08-16 05:23:00, Entry Price: 10450.721
# Exit Time: 2023-08-16 05:23:00, Exit Price: 10450.071
# Profit/Loss: 0.65
#
# Trade Type: SELL
# Entry Time: 2023-08-16 05:28:00, Entry Price: 10467.612
# Exit Time: 2023-08-16 05:28:00, Exit Price: 10467.176
# Profit/Loss: 0.44
#
# Trade Type: SELL
# Entry Time: 2023-08-16 05:53:00, Entry Price: 10469.356
# Exit Time: 2023-08-16 05:53:00, Exit Price: 10468.676
# Profit/Loss: 0.68
#
# Trade Type: SELL
# Entry Time: 2023-08-16 07:18:00, Entry Price: 10469.195
# Exit Time: 2023-08-16 07:18:00, Exit Price: 10468.529
# Profit/Loss: 0.67
#
# Trade Type: SELL
# Entry Time: 2023-08-16 07:23:00, Entry Price: 10470.181
# Exit Time: 2023-08-16 07:23:00, Exit Price: 10469.563
# Profit/Loss: 0.62
#
# Trade Type: SELL
# Entry Time: 2023-08-16 08:15:00, Entry Price: 10470.228
# Exit Time: 2023-08-16 08:15:00, Exit Price: 10469.592
# Profit/Loss: 0.64
#
# Trade Type: SELL
# Entry Time: 2023-08-16 10:16:00, Entry Price: 10430.018
# Exit Time: 2023-08-16 10:16:00, Exit Price: 10429.283
# Profit/Loss: 0.74
#
# Trade Type: SELL
# Entry Time: 2023-08-16 11:23:00, Entry Price: 10404.789
# Exit Time: 2023-08-16 11:23:00, Exit Price: 10404.115
# Profit/Loss: 0.67
#
# Trade Type: SELL
# Entry Time: 2023-08-16 11:33:00, Entry Price: 10418.744
# Exit Time: 2023-08-16 11:33:00, Exit Price: 10418.043
# Profit/Loss: 0.70
#
# Trade Type: SELL
# Entry Time: 2023-08-16 11:38:00, Entry Price: 10423.377
# Exit Time: 2023-08-16 11:38:00, Exit Price: 10422.742
# Profit/Loss: 0.64
#
# Trade Type: SELL
# Entry Time: 2023-08-16 13:56:00, Entry Price: 10395.247
# Exit Time: 2023-08-16 13:56:00, Exit Price: 10394.608
# Profit/Loss: 0.64
#
# Trade Type: SELL
# Entry Time: 2023-08-16 14:03:00, Entry Price: 10393.629
# Exit Time: 2023-08-16 14:03:00, Exit Price: 10393.065
# Profit/Loss: 0.56
#
# Trade Type: SELL
# Entry Time: 2023-08-16 14:13:00, Entry Price: 10410.985
# Exit Time: 2023-08-16 14:13:00, Exit Price: 10410.3
# Profit/Loss: 0.69
#
# Trade Type: SELL
# Entry Time: 2023-08-16 14:31:00, Entry Price: 10411.882
# Exit Time: 2023-08-16 14:31:00, Exit Price: 10411.273
# Profit/Loss: 0.61
#
# Trade Type: SELL
# Entry Time: 2023-08-16 14:35:00, Entry Price: 10449.357
# Exit Time: 2023-08-16 14:35:00, Exit Price: 10448.857
# Profit/Loss: 0.50
#
# Trade Type: SELL
# Entry Time: 2023-08-16 14:40:00, Entry Price: 10470.271
# Exit Time: 2023-08-16 14:40:00, Exit Price: 10469.533
# Profit/Loss: 0.74
#
# Trade Type: SELL
# Entry Time: 2023-08-16 14:52:00, Entry Price: 10479.156
# Exit Time: 2023-08-16 14:52:00, Exit Price: 10478.666
# Profit/Loss: 0.49
#
# Trade Type: SELL
# Entry Time: 2023-08-16 15:48:00, Entry Price: 10468.69
# Exit Time: 2023-08-16 15:48:00, Exit Price: 10467.972
# Profit/Loss: 0.72
#
# Trade Type: SELL
# Entry Time: 2023-08-16 15:58:00, Entry Price: 10484.404
# Exit Time: 2023-08-16 15:58:00, Exit Price: 10483.792
# Profit/Loss: 0.61
#
# Trade Type: SELL
# Entry Time: 2023-08-16 16:37:00, Entry Price: 10486.811
# Exit Time: 2023-08-16 16:37:00, Exit Price: 10486.245
# Profit/Loss: 0.57
#
# Trade Type: SELL
# Entry Time: 2023-08-16 16:50:00, Entry Price: 10492.89
# Exit Time: 2023-08-16 16:50:00, Exit Price: 10492.196
# Profit/Loss: 0.69
#
# Trade Type: SELL
# Entry Time: 2023-08-16 16:57:00, Entry Price: 10507.794
# Exit Time: 2023-08-16 16:57:00, Exit Price: 10507.254
# Profit/Loss: 0.54
#
# Trade Type: SELL
# Entry Time: 2023-08-16 17:20:00, Entry Price: 10506.392
# Exit Time: 2023-08-16 17:20:00, Exit Price: 10505.755
# Profit/Loss: 0.64
#
# Trade Type: SELL
# Entry Time: 2023-08-16 19:00:00, Entry Price: 10477.904
# Exit Time: 2023-08-16 19:00:00, Exit Price: 10477.242
# Profit/Loss: 0.66
#
# Total Profit/Loss: 20.39
# Total Trades: 33

# %% [markdown]
# # **BackTest + Trade Visualizer + RSI (Maverick Crash 1000/500/300)**

# %%
def backtest_strategy(df, lot_size=0.2):
    trades = []
    in_trade = False

    for i in range(3, len(df)):
        current_bar = df.iloc[i]
        previous_bar = df.iloc[i - 1]
        confirmation_bar = df.iloc[i - 2]

        # Check for buy conditions
        if current_bar["rsi"] < 30 and confirmation_bar["close"] < confirmation_bar["open"] \
                and previous_bar["close"] > previous_bar["open"] \
                and current_bar["close"] > current_bar["open"]:
            
            if not in_trade:
                # Open a buy trade
                trade = {"entry_time": current_bar.name, "entry_price": current_bar["open"], "trade_type": "BUY"}
                trades.append(trade)
                in_trade = True

        # Check for trade closing condition
        if in_trade:
            if current_bar["close"] > current_bar["open"]:
                # Close the trade
                trades[-1]["exit_time"] = current_bar.name
                trades[-1]["exit_price"] = current_bar["close"]
                trades[-1]["pnl"] = trades[-1]["exit_price"] - trades[-1]["entry_price"]
                trades[-1]["pnl"] *= lot_size
                in_trade = False

    return trades

from plotly.subplots import make_subplots

def plot_trades(df, trades):
    fig = go.Figure(data=[go.Candlestick(x=df.index,
                                        open=df['open'],
                                        high=df['high'],
                                        low=df['low'],
                                        close=df['close'],
                                        increasing_line_color='orange',
                                        decreasing_line_color='green',
                                        line_width=1)])

    entry_exit_traces = []  # Store entry and exit traces separately

    for trade in trades:
        entry_time = trade["entry_time"]
        entry_price = trade["entry_price"]
        exit_time = trade["exit_time"]
        exit_price = trade["exit_price"]

        entry_trace = go.Scatter(x=[entry_time], y=[entry_price],
                                 mode='markers',
                                 marker=dict(size=10, symbol='triangle-up', color='orange'))
        
        exit_trace = go.Scatter(x=[exit_time], y=[exit_price],
                                mode='markers',
                                marker=dict(size=10, symbol='triangle-down', color='green'))

        entry_exit_traces.append(entry_trace)
        entry_exit_traces.append(exit_trace)

    # Calculate RSI levels
    rsi_levels = df['rsi']
    rsi_oversold = [30] * len(df)
    rsi_overbought = [70] * len(df)

    # Create a subplot with shared x-axis
    subplot_fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.05)

    # Add candlestick chart to the first subplot
    subplot_fig.add_trace(go.Candlestick(x=df.index,
                                          open=df['open'],
                                          high=df['high'],
                                          low=df['low'],
                                          close=df['close'],
                                          increasing_line_color='orange',
                                          decreasing_line_color='green',
                                          line_width=1), row=1, col=1)

    # Add entry and exit traces to the first subplot
    for trace in entry_exit_traces:
        subplot_fig.add_trace(trace, row=1, col=1)

    # Add RSI plot to the second subplot
    subplot_fig.add_trace(go.Scatter(x=df.index, y=rsi_levels, name='RSI', line=dict(color='blue')), row=2, col=1)
    subplot_fig.add_trace(go.Scatter(x=df.index, y=rsi_oversold, name='Oversold', line=dict(color='red', dash='dash')), row=2, col=1)
    subplot_fig.add_trace(go.Scatter(x=df.index, y=rsi_overbought, name='Overbought', line=dict(color='green', dash='dash')), row=2, col=1)

    # Update layout of the subplots
    subplot_fig.update_layout(
        title="Backtest Trades with RSI",
        xaxis_title="Time",
        height=800,  # Set the height of the entire plot
        xaxis_rangeslider_visible=False,
        plot_bgcolor='black',
        paper_bgcolor='black',
        font=dict(color='white'),
        showlegend=True,
        autosize=True,
        margin=dict(l=50, r=50, t=50, b=50),
        xaxis_showgrid=False,
        yaxis_showgrid=False,
    )

    subplot_fig.show()

def plot_histogram(trades):
    pnl_values = [trade.get('pnl', 0) for trade in trades]

    # Filter out zero values (trades that didn't close)
    pnl_values = [pnl for pnl in pnl_values if pnl != 0]

    winning_trades = [pnl for pnl in pnl_values if pnl > 0]
    losing_trades = [pnl for pnl in pnl_values if pnl < 0]

    fig = go.Figure()

    fig.add_trace(go.Histogram(x=winning_trades, opacity=0.75, name="Winning Trades"))
    fig.add_trace(go.Histogram(x=losing_trades, opacity=0.75, name="Losing Trades"))

    fig.update_layout(
        title="Number of Winning and Losing Trades",
        xaxis_title="Profit/Loss",
        yaxis_title="Number of Trades",
        plot_bgcolor='black',
        paper_bgcolor='black',
        font=dict(color='white'),
        showlegend=True,
        autosize=True,
        margin=dict(l=50, r=50, t=50, b=50),
        xaxis_showgrid=True,
        yaxis_showgrid=True,
    )

    fig.update_layout(barmode='overlay')

    fig.show()

def plot_total(trades):
    pnl_values = [trade.get('pnl', 0) for trade in trades]

    # Filter out zero values (trades that didn't close)
    pnl_values = [pnl for pnl in pnl_values if pnl != 0]

    winning_trades = [pnl for pnl in pnl_values if pnl > 0]
    losing_trades = [pnl for pnl in pnl_values if pnl < 0]

    total_winning_trades = len(winning_trades)
    total_losing_trades = len(losing_trades)

    fig = go.Figure()

    fig.add_trace(go.Bar(x=["Winning Trades"], y=[total_winning_trades], name="Winning Trades", marker_color='green'))
    fig.add_trace(go.Bar(x=["Losing Trades"], y=[total_losing_trades], name="Losing Trades", marker_color='red'))

    fig.update_layout(
        title="Number of Winning and Losing Trades",
        xaxis_title="Trade Type",
        yaxis_title="Number of Trades",
        plot_bgcolor='black',
        paper_bgcolor='black',
        font=dict(color='white'),
        showlegend=True,
        autosize=True,
        margin=dict(l=50, r=50, t=50, b=50),
        xaxis_showgrid=False,
        yaxis_showgrid=True,
    )

    fig.show()

if __name__ == "__main__":
    symbol = "Crash 1000 Index"
    timeframe = mt5.TIMEFRAME_M1
    lot_size = 1.0
    period = 7.0

    # Specify the date range for historical data (adjust as needed)
    start_date = datetime(2023, 7, 16)
    end_date = datetime.now()
    #end_date = datetime(2023, 8, 16)
    # Step 1: Load historical data within the specified date range
    df = get_historical_data(symbol, timeframe, start_date, end_date)

    # Step 2: Calculate RSI
    calculate_rsi(df, period)

    # Step 3: Backtest the strategy
    trades = backtest_strategy(df, lot_size)

    # Step 4: Print the backtest results
    total_pnl = 0
    for trade in trades:
        print(f"Trade Type: {trade['trade_type']}")
        print(f"Entry Time: {trade['entry_time']}, Entry Price: {trade['entry_price']}")
        print(f"Exit Time: {trade['exit_time']}, Exit Price: {trade['exit_price']}")
        print(f"Profit/Loss: {trade['pnl']:.2f}\n")
        total_pnl += trade['pnl']

    print(f"Total Profit/Loss: {total_pnl:.2f}")
    print(f"Total Trades: {len(trades)}")

    # Step 5: Plot the trades
    plot_histogram(trades)
    plot_total(trades)
    #plot_trades(df, trades)
# Out:
# Retrieved 45891 data points
# Trade Type: BUY
# Entry Time: 2023-07-15 23:06:00, Entry Price: 7505.162
# Exit Time: 2023-07-15 23:06:00, Exit Price: 7505.579
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-15 23:27:00, Entry Price: 7504.018
# Exit Time: 2023-07-15 23:27:00, Exit Price: 7504.444
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-15 23:32:00, Entry Price: 7487.932
# Exit Time: 2023-07-15 23:32:00, Exit Price: 7488.413
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-16 00:03:00, Entry Price: 7490.442
# Exit Time: 2023-07-16 00:03:00, Exit Price: 7490.904
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-16 00:58:00, Entry Price: 7505.47
# Exit Time: 2023-07-16 00:58:00, Exit Price: 7505.897
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-16 02:17:00, Entry Price: 7519.425
# Exit Time: 2023-07-16 02:17:00, Exit Price: 7519.87
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-16 03:19:00, Entry Price: 7537.31
# Exit Time: 2023-07-16 03:19:00, Exit Price: 7537.802
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-16 03:25:00, Entry Price: 7529.624
# Exit Time: 2023-07-16 03:25:00, Exit Price: 7530.059
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-16 03:36:00, Entry Price: 7519.618
# Exit Time: 2023-07-16 03:36:00, Exit Price: 7520.032
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-16 03:51:00, Entry Price: 7505.512
# Exit Time: 2023-07-16 03:51:00, Exit Price: 7505.912
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-16 04:43:00, Entry Price: 7510.802
# Exit Time: 2023-07-16 04:43:00, Exit Price: 7511.212
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-16 06:25:00, Entry Price: 7534.623
# Exit Time: 2023-07-16 06:25:00, Exit Price: 7535.005
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-16 06:39:00, Entry Price: 7528.135
# Exit Time: 2023-07-16 06:39:00, Exit Price: 7528.566
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-16 07:08:00, Entry Price: 7530.728
# Exit Time: 2023-07-16 07:08:00, Exit Price: 7531.205
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-16 07:17:00, Entry Price: 7527.725
# Exit Time: 2023-07-16 07:17:00, Exit Price: 7528.229
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-16 07:25:00, Entry Price: 7517.109
# Exit Time: 2023-07-16 07:25:00, Exit Price: 7517.499
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-16 07:33:00, Entry Price: 7515.288
# Exit Time: 2023-07-16 07:33:00, Exit Price: 7515.752
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-16 08:36:00, Entry Price: 7525.423
# Exit Time: 2023-07-16 08:36:00, Exit Price: 7525.889
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-16 08:43:00, Entry Price: 7514.979
# Exit Time: 2023-07-16 08:43:00, Exit Price: 7515.461
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-16 09:10:00, Entry Price: 7509.542
# Exit Time: 2023-07-16 09:10:00, Exit Price: 7509.966
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-16 10:26:00, Entry Price: 7525.671
# Exit Time: 2023-07-16 10:26:00, Exit Price: 7526.086
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-16 11:05:00, Entry Price: 7524.689
# Exit Time: 2023-07-16 11:05:00, Exit Price: 7525.117
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-16 11:35:00, Entry Price: 7524.116
# Exit Time: 2023-07-16 11:35:00, Exit Price: 7524.543
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-16 12:29:00, Entry Price: 7515.895
# Exit Time: 2023-07-16 12:29:00, Exit Price: 7516.295
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-16 12:43:00, Entry Price: 7515.387
# Exit Time: 2023-07-16 12:43:00, Exit Price: 7515.834
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-16 13:05:00, Entry Price: 7504.56
# Exit Time: 2023-07-16 13:05:00, Exit Price: 7505.051
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-16 13:14:00, Entry Price: 7478.977
# Exit Time: 2023-07-16 13:14:00, Exit Price: 7479.363
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-16 13:35:00, Entry Price: 7472.6
# Exit Time: 2023-07-16 13:35:00, Exit Price: 7472.967
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-07-16 16:17:00, Entry Price: 7500.842
# Exit Time: 2023-07-16 16:17:00, Exit Price: 7501.269
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-16 16:21:00, Entry Price: 7495.212
# Exit Time: 2023-07-16 16:21:00, Exit Price: 7495.635
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-16 16:29:00, Entry Price: 7481.607
# Exit Time: 2023-07-16 16:29:00, Exit Price: 7482.071
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-16 16:50:00, Entry Price: 7478.522
# Exit Time: 2023-07-16 16:50:00, Exit Price: 7479.01
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-16 17:34:00, Entry Price: 7480.904
# Exit Time: 2023-07-16 17:34:00, Exit Price: 7481.327
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-16 18:06:00, Entry Price: 7483.275
# Exit Time: 2023-07-16 18:06:00, Exit Price: 7483.7
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-16 18:50:00, Entry Price: 7480.873
# Exit Time: 2023-07-16 18:50:00, Exit Price: 7481.252
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-16 19:15:00, Entry Price: 7470.658
# Exit Time: 2023-07-16 19:15:00, Exit Price: 7471.049
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-16 19:47:00, Entry Price: 7465.033
# Exit Time: 2023-07-16 19:47:00, Exit Price: 7465.464
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-16 20:15:00, Entry Price: 7462.679
# Exit Time: 2023-07-16 20:15:00, Exit Price: 7463.108
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-16 21:04:00, Entry Price: 7460.073
# Exit Time: 2023-07-16 21:04:00, Exit Price: 7460.502
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-16 21:11:00, Entry Price: 7445.001
# Exit Time: 2023-07-16 21:11:00, Exit Price: 7445.391
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-16 21:14:00, Entry Price: 7442.642
# Exit Time: 2023-07-16 21:14:00, Exit Price: 7443.154
# Profit/Loss: 0.51
#
# Trade Type: BUY
# Entry Time: 2023-07-16 21:31:00, Entry Price: 7435.617
# Exit Time: 2023-07-16 21:31:00, Exit Price: 7436.001
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-16 21:38:00, Entry Price: 7407.645
# Exit Time: 2023-07-16 21:38:00, Exit Price: 7408.092
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-16 21:41:00, Entry Price: 7399.257
# Exit Time: 2023-07-16 21:41:00, Exit Price: 7399.754
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-16 22:14:00, Entry Price: 7395.595
# Exit Time: 2023-07-16 22:14:00, Exit Price: 7396.077
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-16 23:30:00, Entry Price: 7409.199
# Exit Time: 2023-07-16 23:30:00, Exit Price: 7409.616
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-16 23:58:00, Entry Price: 7404.342
# Exit Time: 2023-07-16 23:58:00, Exit Price: 7404.817
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-17 00:21:00, Entry Price: 7394.07
# Exit Time: 2023-07-17 00:21:00, Exit Price: 7394.555
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-17 02:00:00, Entry Price: 7417.778
# Exit Time: 2023-07-17 02:00:00, Exit Price: 7418.218
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-17 03:28:00, Entry Price: 7437.88
# Exit Time: 2023-07-17 03:28:00, Exit Price: 7438.261
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-17 04:19:00, Entry Price: 7438.009
# Exit Time: 2023-07-17 04:19:00, Exit Price: 7438.493
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-17 04:23:00, Entry Price: 7425.158
# Exit Time: 2023-07-17 04:23:00, Exit Price: 7425.562
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-17 04:40:00, Entry Price: 7420.432
# Exit Time: 2023-07-17 04:40:00, Exit Price: 7420.856
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-17 04:45:00, Entry Price: 7419.848
# Exit Time: 2023-07-17 04:45:00, Exit Price: 7420.309
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-17 05:40:00, Entry Price: 7435.168
# Exit Time: 2023-07-17 05:40:00, Exit Price: 7435.662
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-17 05:52:00, Entry Price: 7432.267
# Exit Time: 2023-07-17 05:52:00, Exit Price: 7432.735
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-17 06:37:00, Entry Price: 7437.809
# Exit Time: 2023-07-17 06:37:00, Exit Price: 7438.23
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-17 07:25:00, Entry Price: 7441.885
# Exit Time: 2023-07-17 07:25:00, Exit Price: 7442.291
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-17 08:07:00, Entry Price: 7449.785
# Exit Time: 2023-07-17 08:07:00, Exit Price: 7450.283
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-17 08:58:00, Entry Price: 7459.328
# Exit Time: 2023-07-17 08:58:00, Exit Price: 7459.802
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-17 09:27:00, Entry Price: 7455.665
# Exit Time: 2023-07-17 09:27:00, Exit Price: 7456.11
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-17 09:59:00, Entry Price: 7453.071
# Exit Time: 2023-07-17 09:59:00, Exit Price: 7453.436
# Profit/Loss: 0.36
#
# Trade Type: BUY
# Entry Time: 2023-07-17 10:16:00, Entry Price: 7448.547
# Exit Time: 2023-07-17 10:16:00, Exit Price: 7449.003
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-17 10:22:00, Entry Price: 7445.447
# Exit Time: 2023-07-17 10:22:00, Exit Price: 7445.918
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-17 10:39:00, Entry Price: 7433.561
# Exit Time: 2023-07-17 10:39:00, Exit Price: 7434.012
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-17 11:21:00, Entry Price: 7434.021
# Exit Time: 2023-07-17 11:21:00, Exit Price: 7434.542
# Profit/Loss: 0.52
#
# Trade Type: BUY
# Entry Time: 2023-07-17 13:27:00, Entry Price: 7456.736
# Exit Time: 2023-07-17 13:27:00, Exit Price: 7457.155
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-17 13:36:00, Entry Price: 7439.019
# Exit Time: 2023-07-17 13:36:00, Exit Price: 7439.434
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-17 13:46:00, Entry Price: 7438.261
# Exit Time: 2023-07-17 13:46:00, Exit Price: 7438.713
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-17 14:21:00, Entry Price: 7437.682
# Exit Time: 2023-07-17 14:21:00, Exit Price: 7438.069
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-17 14:30:00, Entry Price: 7431.329
# Exit Time: 2023-07-17 14:30:00, Exit Price: 7431.742
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-17 16:12:00, Entry Price: 7446.284
# Exit Time: 2023-07-17 16:12:00, Exit Price: 7446.788
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-17 17:00:00, Entry Price: 7452.955
# Exit Time: 2023-07-17 17:00:00, Exit Price: 7453.375
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-17 18:02:00, Entry Price: 7453.466
# Exit Time: 2023-07-17 18:02:00, Exit Price: 7453.913
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-17 18:08:00, Entry Price: 7438.734
# Exit Time: 2023-07-17 18:08:00, Exit Price: 7439.189
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-17 19:03:00, Entry Price: 7439.193
# Exit Time: 2023-07-17 19:03:00, Exit Price: 7439.621
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-17 20:38:00, Entry Price: 7442.342
# Exit Time: 2023-07-17 20:38:00, Exit Price: 7442.715
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-07-17 21:15:00, Entry Price: 7441.072
# Exit Time: 2023-07-17 21:15:00, Exit Price: 7441.469
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-17 21:21:00, Entry Price: 7435.54
# Exit Time: 2023-07-17 21:21:00, Exit Price: 7435.99
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-17 23:32:00, Entry Price: 7453.781
# Exit Time: 2023-07-17 23:32:00, Exit Price: 7454.26
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-17 23:55:00, Entry Price: 7448.746
# Exit Time: 2023-07-17 23:55:00, Exit Price: 7449.108
# Profit/Loss: 0.36
#
# Trade Type: BUY
# Entry Time: 2023-07-18 00:08:00, Entry Price: 7441.955
# Exit Time: 2023-07-18 00:08:00, Exit Price: 7442.39
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-18 01:49:00, Entry Price: 7467.368
# Exit Time: 2023-07-18 01:49:00, Exit Price: 7467.797
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-18 02:24:00, Entry Price: 7466.989
# Exit Time: 2023-07-18 02:24:00, Exit Price: 7467.466
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-18 02:28:00, Entry Price: 7460.025
# Exit Time: 2023-07-18 02:28:00, Exit Price: 7460.478
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-18 02:54:00, Entry Price: 7457.151
# Exit Time: 2023-07-18 02:54:00, Exit Price: 7457.572
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-18 03:20:00, Entry Price: 7452.65
# Exit Time: 2023-07-18 03:20:00, Exit Price: 7453.053
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-18 03:30:00, Entry Price: 7447.619
# Exit Time: 2023-07-18 03:30:00, Exit Price: 7448.033
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-18 03:33:00, Entry Price: 7435.048
# Exit Time: 2023-07-18 03:33:00, Exit Price: 7435.388
# Profit/Loss: 0.34
#
# Trade Type: BUY
# Entry Time: 2023-07-18 04:31:00, Entry Price: 7450.274
# Exit Time: 2023-07-18 04:31:00, Exit Price: 7450.633
# Profit/Loss: 0.36
#
# Trade Type: BUY
# Entry Time: 2023-07-18 04:35:00, Entry Price: 7445.161
# Exit Time: 2023-07-18 04:35:00, Exit Price: 7445.652
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-18 04:42:00, Entry Price: 7437.27
# Exit Time: 2023-07-18 04:42:00, Exit Price: 7437.7
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-18 04:45:00, Entry Price: 7424.254
# Exit Time: 2023-07-18 04:45:00, Exit Price: 7424.605
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-07-18 05:32:00, Entry Price: 7426.561
# Exit Time: 2023-07-18 05:32:00, Exit Price: 7426.99
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-18 05:55:00, Entry Price: 7426.135
# Exit Time: 2023-07-18 05:55:00, Exit Price: 7426.547
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-18 06:40:00, Entry Price: 7426.328
# Exit Time: 2023-07-18 06:40:00, Exit Price: 7426.835
# Profit/Loss: 0.51
#
# Trade Type: BUY
# Entry Time: 2023-07-18 07:21:00, Entry Price: 7418.814
# Exit Time: 2023-07-18 07:21:00, Exit Price: 7419.206
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-18 07:31:00, Entry Price: 7415.483
# Exit Time: 2023-07-18 07:31:00, Exit Price: 7415.958
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-18 07:44:00, Entry Price: 7413.352
# Exit Time: 2023-07-18 07:44:00, Exit Price: 7413.779
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-18 08:01:00, Entry Price: 7403.823
# Exit Time: 2023-07-18 08:01:00, Exit Price: 7404.259
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-18 08:40:00, Entry Price: 7402.141
# Exit Time: 2023-07-18 08:40:00, Exit Price: 7402.55
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-18 09:05:00, Entry Price: 7399.239
# Exit Time: 2023-07-18 09:05:00, Exit Price: 7399.666
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-18 09:18:00, Entry Price: 7394.272
# Exit Time: 2023-07-18 09:18:00, Exit Price: 7394.678
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-18 11:23:00, Entry Price: 7433.674
# Exit Time: 2023-07-18 11:23:00, Exit Price: 7434.093
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-18 11:26:00, Entry Price: 7425.611
# Exit Time: 2023-07-18 11:26:00, Exit Price: 7426.046
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-18 12:14:00, Entry Price: 7421.952
# Exit Time: 2023-07-18 12:14:00, Exit Price: 7422.371
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-18 12:36:00, Entry Price: 7410.917
# Exit Time: 2023-07-18 12:36:00, Exit Price: 7411.33
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-18 12:54:00, Entry Price: 7403.953
# Exit Time: 2023-07-18 12:54:00, Exit Price: 7404.419
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-18 13:18:00, Entry Price: 7389.331
# Exit Time: 2023-07-18 13:18:00, Exit Price: 7389.749
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-18 13:38:00, Entry Price: 7388.539
# Exit Time: 2023-07-18 13:38:00, Exit Price: 7388.843
# Profit/Loss: 0.30
#
# Trade Type: BUY
# Entry Time: 2023-07-18 14:46:00, Entry Price: 7393.341
# Exit Time: 2023-07-18 14:46:00, Exit Price: 7393.767
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-18 17:20:00, Entry Price: 7423.73
# Exit Time: 2023-07-18 17:20:00, Exit Price: 7424.151
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-18 18:09:00, Entry Price: 7425.384
# Exit Time: 2023-07-18 18:09:00, Exit Price: 7425.83
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-18 19:26:00, Entry Price: 7440.234
# Exit Time: 2023-07-18 19:26:00, Exit Price: 7440.658
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-18 20:06:00, Entry Price: 7447.539
# Exit Time: 2023-07-18 20:06:00, Exit Price: 7447.94
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-18 20:38:00, Entry Price: 7443.589
# Exit Time: 2023-07-18 20:38:00, Exit Price: 7444.011
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-18 21:49:00, Entry Price: 7447.452
# Exit Time: 2023-07-18 21:49:00, Exit Price: 7447.873
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-18 21:52:00, Entry Price: 7439.926
# Exit Time: 2023-07-18 21:52:00, Exit Price: 7440.349
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-18 22:37:00, Entry Price: 7447.688
# Exit Time: 2023-07-18 22:37:00, Exit Price: 7448.148
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-18 23:11:00, Entry Price: 7447.393
# Exit Time: 2023-07-18 23:11:00, Exit Price: 7447.881
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-18 23:27:00, Entry Price: 7439.98
# Exit Time: 2023-07-18 23:27:00, Exit Price: 7440.409
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-19 00:26:00, Entry Price: 7449.033
# Exit Time: 2023-07-19 00:26:00, Exit Price: 7449.447
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-19 00:47:00, Entry Price: 7447.349
# Exit Time: 2023-07-19 00:47:00, Exit Price: 7447.745
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-19 01:11:00, Entry Price: 7444.78
# Exit Time: 2023-07-19 01:11:00, Exit Price: 7445.164
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-19 01:16:00, Entry Price: 7438.387
# Exit Time: 2023-07-19 01:16:00, Exit Price: 7438.738
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-07-19 01:20:00, Entry Price: 7439.116
# Exit Time: 2023-07-19 01:20:00, Exit Price: 7439.502
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-19 01:29:00, Entry Price: 7433.662
# Exit Time: 2023-07-19 01:29:00, Exit Price: 7434.086
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-19 01:39:00, Entry Price: 7427.405
# Exit Time: 2023-07-19 01:39:00, Exit Price: 7427.776
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-07-19 02:51:00, Entry Price: 7443.56
# Exit Time: 2023-07-19 02:51:00, Exit Price: 7443.989
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-19 04:02:00, Entry Price: 7465.016
# Exit Time: 2023-07-19 04:02:00, Exit Price: 7465.419
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-19 04:11:00, Entry Price: 7454.822
# Exit Time: 2023-07-19 04:11:00, Exit Price: 7455.236
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-19 04:42:00, Entry Price: 7454.233
# Exit Time: 2023-07-19 04:42:00, Exit Price: 7454.721
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-19 07:20:00, Entry Price: 7484.813
# Exit Time: 2023-07-19 07:20:00, Exit Price: 7485.255
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-19 07:29:00, Entry Price: 7479.975
# Exit Time: 2023-07-19 07:29:00, Exit Price: 7480.424
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-19 08:43:00, Entry Price: 7475.968
# Exit Time: 2023-07-19 08:43:00, Exit Price: 7476.439
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-19 09:08:00, Entry Price: 7465.262
# Exit Time: 2023-07-19 09:08:00, Exit Price: 7465.728
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-19 09:43:00, Entry Price: 7455.949
# Exit Time: 2023-07-19 09:43:00, Exit Price: 7456.387
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-19 09:46:00, Entry Price: 7441.595
# Exit Time: 2023-07-19 09:46:00, Exit Price: 7442.08
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-19 10:49:00, Entry Price: 7457.435
# Exit Time: 2023-07-19 10:49:00, Exit Price: 7457.907
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-19 12:01:00, Entry Price: 7473.505
# Exit Time: 2023-07-19 12:01:00, Exit Price: 7473.988
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-19 12:06:00, Entry Price: 7469.909
# Exit Time: 2023-07-19 12:06:00, Exit Price: 7470.338
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-19 12:14:00, Entry Price: 7455.285
# Exit Time: 2023-07-19 12:14:00, Exit Price: 7455.74
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-19 12:19:00, Entry Price: 7448.607
# Exit Time: 2023-07-19 12:19:00, Exit Price: 7449.05
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-19 14:20:00, Entry Price: 7479.009
# Exit Time: 2023-07-19 14:20:00, Exit Price: 7479.475
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-19 15:44:00, Entry Price: 7491.91
# Exit Time: 2023-07-19 15:44:00, Exit Price: 7492.451
# Profit/Loss: 0.54
#
# Trade Type: BUY
# Entry Time: 2023-07-19 16:09:00, Entry Price: 7492.548
# Exit Time: 2023-07-19 16:09:00, Exit Price: 7493.0
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-19 16:17:00, Entry Price: 7486.048
# Exit Time: 2023-07-19 16:17:00, Exit Price: 7486.483
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-19 16:44:00, Entry Price: 7482.098
# Exit Time: 2023-07-19 16:44:00, Exit Price: 7482.534
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-19 18:14:00, Entry Price: 7496.593
# Exit Time: 2023-07-19 18:14:00, Exit Price: 7496.997
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-19 18:32:00, Entry Price: 7489.553
# Exit Time: 2023-07-19 18:32:00, Exit Price: 7489.984
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-19 18:36:00, Entry Price: 7489.015
# Exit Time: 2023-07-19 18:36:00, Exit Price: 7489.504
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-19 18:39:00, Entry Price: 7479.675
# Exit Time: 2023-07-19 18:39:00, Exit Price: 7480.119
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-19 18:43:00, Entry Price: 7456.476
# Exit Time: 2023-07-19 18:43:00, Exit Price: 7456.923
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-19 21:27:00, Entry Price: 7507.162
# Exit Time: 2023-07-19 21:27:00, Exit Price: 7507.598
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-19 21:44:00, Entry Price: 7499.884
# Exit Time: 2023-07-19 21:44:00, Exit Price: 7500.287
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-19 22:21:00, Entry Price: 7495.633
# Exit Time: 2023-07-19 22:21:00, Exit Price: 7496.08
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-19 22:29:00, Entry Price: 7493.862
# Exit Time: 2023-07-19 22:29:00, Exit Price: 7494.26
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-19 23:12:00, Entry Price: 7485.486
# Exit Time: 2023-07-19 23:12:00, Exit Price: 7485.929
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-20 00:58:00, Entry Price: 7512.345
# Exit Time: 2023-07-20 00:58:00, Exit Price: 7512.771
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-20 01:02:00, Entry Price: 7496.342
# Exit Time: 2023-07-20 01:02:00, Exit Price: 7496.793
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-20 01:32:00, Entry Price: 7500.318
# Exit Time: 2023-07-20 01:32:00, Exit Price: 7500.78
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-20 01:35:00, Entry Price: 7487.732
# Exit Time: 2023-07-20 01:35:00, Exit Price: 7488.174
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-20 01:41:00, Entry Price: 7489.021
# Exit Time: 2023-07-20 01:41:00, Exit Price: 7489.433
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-20 01:46:00, Entry Price: 7463.829
# Exit Time: 2023-07-20 01:46:00, Exit Price: 7464.271
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-20 01:59:00, Entry Price: 7462.741
# Exit Time: 2023-07-20 01:59:00, Exit Price: 7463.254
# Profit/Loss: 0.51
#
# Trade Type: BUY
# Entry Time: 2023-07-20 02:07:00, Entry Price: 7433.08
# Exit Time: 2023-07-20 02:07:00, Exit Price: 7433.602
# Profit/Loss: 0.52
#
# Trade Type: BUY
# Entry Time: 2023-07-20 02:51:00, Entry Price: 7436.501
# Exit Time: 2023-07-20 02:51:00, Exit Price: 7436.972
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-20 04:17:00, Entry Price: 7444.071
# Exit Time: 2023-07-20 04:17:00, Exit Price: 7444.456
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-20 04:40:00, Entry Price: 7439.382
# Exit Time: 2023-07-20 04:40:00, Exit Price: 7439.897
# Profit/Loss: 0.52
#
# Trade Type: BUY
# Entry Time: 2023-07-20 05:28:00, Entry Price: 7446.34
# Exit Time: 2023-07-20 05:28:00, Exit Price: 7446.833
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-20 07:04:00, Entry Price: 7474.935
# Exit Time: 2023-07-20 07:04:00, Exit Price: 7475.346
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-20 09:29:00, Entry Price: 7503.637
# Exit Time: 2023-07-20 09:29:00, Exit Price: 7504.105
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-20 11:28:00, Entry Price: 7538.896
# Exit Time: 2023-07-20 11:28:00, Exit Price: 7539.333
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-20 12:27:00, Entry Price: 7553.472
# Exit Time: 2023-07-20 12:27:00, Exit Price: 7553.996
# Profit/Loss: 0.52
#
# Trade Type: BUY
# Entry Time: 2023-07-20 13:56:00, Entry Price: 7560.204
# Exit Time: 2023-07-20 13:56:00, Exit Price: 7560.663
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-20 14:09:00, Entry Price: 7545.458
# Exit Time: 2023-07-20 14:09:00, Exit Price: 7545.861
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-20 14:13:00, Entry Price: 7536.739
# Exit Time: 2023-07-20 14:13:00, Exit Price: 7537.173
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-20 14:16:00, Entry Price: 7530.425
# Exit Time: 2023-07-20 14:16:00, Exit Price: 7530.878
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-20 14:19:00, Entry Price: 7514.188
# Exit Time: 2023-07-20 14:19:00, Exit Price: 7514.654
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-20 15:36:00, Entry Price: 7526.293
# Exit Time: 2023-07-20 15:36:00, Exit Price: 7526.699
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-20 16:16:00, Entry Price: 7533.518
# Exit Time: 2023-07-20 16:16:00, Exit Price: 7533.912
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-20 16:41:00, Entry Price: 7531.344
# Exit Time: 2023-07-20 16:41:00, Exit Price: 7531.801
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-20 16:45:00, Entry Price: 7528.222
# Exit Time: 2023-07-20 16:45:00, Exit Price: 7528.718
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-20 16:51:00, Entry Price: 7513.271
# Exit Time: 2023-07-20 16:51:00, Exit Price: 7513.76
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-20 16:59:00, Entry Price: 7511.863
# Exit Time: 2023-07-20 16:59:00, Exit Price: 7512.296
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-20 17:22:00, Entry Price: 7511.66
# Exit Time: 2023-07-20 17:22:00, Exit Price: 7512.093
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-20 18:22:00, Entry Price: 7510.154
# Exit Time: 2023-07-20 18:22:00, Exit Price: 7510.582
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-20 18:36:00, Entry Price: 7499.172
# Exit Time: 2023-07-20 18:36:00, Exit Price: 7499.624
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-20 20:22:00, Entry Price: 7511.298
# Exit Time: 2023-07-20 20:22:00, Exit Price: 7511.717
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-21 00:06:00, Entry Price: 7561.288
# Exit Time: 2023-07-21 00:06:00, Exit Price: 7561.699
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-21 00:15:00, Entry Price: 7559.267
# Exit Time: 2023-07-21 00:15:00, Exit Price: 7559.777
# Profit/Loss: 0.51
#
# Trade Type: BUY
# Entry Time: 2023-07-21 00:33:00, Entry Price: 7540.28
# Exit Time: 2023-07-21 00:33:00, Exit Price: 7540.849
# Profit/Loss: 0.57
#
# Trade Type: BUY
# Entry Time: 2023-07-21 02:54:00, Entry Price: 7582.59
# Exit Time: 2023-07-21 02:54:00, Exit Price: 7583.097
# Profit/Loss: 0.51
#
# Trade Type: BUY
# Entry Time: 2023-07-21 02:58:00, Entry Price: 7577.983
# Exit Time: 2023-07-21 02:58:00, Exit Price: 7578.44
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-21 03:04:00, Entry Price: 7572.993
# Exit Time: 2023-07-21 03:04:00, Exit Price: 7573.517
# Profit/Loss: 0.52
#
# Trade Type: BUY
# Entry Time: 2023-07-21 03:08:00, Entry Price: 7570.1
# Exit Time: 2023-07-21 03:08:00, Exit Price: 7570.601
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-21 05:18:00, Entry Price: 7589.265
# Exit Time: 2023-07-21 05:18:00, Exit Price: 7589.678
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-21 05:21:00, Entry Price: 7585.034
# Exit Time: 2023-07-21 05:21:00, Exit Price: 7585.46
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-21 05:30:00, Entry Price: 7578.825
# Exit Time: 2023-07-21 05:30:00, Exit Price: 7579.272
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-21 06:12:00, Entry Price: 7585.036
# Exit Time: 2023-07-21 06:12:00, Exit Price: 7585.533
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-21 07:13:00, Entry Price: 7580.647
# Exit Time: 2023-07-21 07:13:00, Exit Price: 7581.112
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-21 08:10:00, Entry Price: 7588.924
# Exit Time: 2023-07-21 08:10:00, Exit Price: 7589.322
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-21 08:26:00, Entry Price: 7584.87
# Exit Time: 2023-07-21 08:26:00, Exit Price: 7585.281
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-21 08:38:00, Entry Price: 7576.325
# Exit Time: 2023-07-21 08:38:00, Exit Price: 7576.771
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-21 08:42:00, Entry Price: 7567.679
# Exit Time: 2023-07-21 08:42:00, Exit Price: 7568.113
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-21 09:17:00, Entry Price: 7571.76
# Exit Time: 2023-07-21 09:17:00, Exit Price: 7572.203
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-21 09:27:00, Entry Price: 7565.594
# Exit Time: 2023-07-21 09:27:00, Exit Price: 7566.038
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-21 09:56:00, Entry Price: 7556.722
# Exit Time: 2023-07-21 09:56:00, Exit Price: 7557.174
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-21 10:37:00, Entry Price: 7565.556
# Exit Time: 2023-07-21 10:37:00, Exit Price: 7565.97
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-21 10:55:00, Entry Price: 7561.028
# Exit Time: 2023-07-21 10:55:00, Exit Price: 7561.437
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-21 14:31:00, Entry Price: 7601.921
# Exit Time: 2023-07-21 14:31:00, Exit Price: 7602.358
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-21 14:44:00, Entry Price: 7593.416
# Exit Time: 2023-07-21 14:44:00, Exit Price: 7593.858
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-21 14:53:00, Entry Price: 7584.664
# Exit Time: 2023-07-21 14:53:00, Exit Price: 7585.174
# Profit/Loss: 0.51
#
# Trade Type: BUY
# Entry Time: 2023-07-21 16:12:00, Entry Price: 7582.627
# Exit Time: 2023-07-21 16:12:00, Exit Price: 7583.082
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-21 16:20:00, Entry Price: 7567.056
# Exit Time: 2023-07-21 16:20:00, Exit Price: 7567.468
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-21 17:41:00, Entry Price: 7587.515
# Exit Time: 2023-07-21 17:41:00, Exit Price: 7587.958
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-21 18:50:00, Entry Price: 7600.789
# Exit Time: 2023-07-21 18:50:00, Exit Price: 7601.209
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-21 19:00:00, Entry Price: 7592.912
# Exit Time: 2023-07-21 19:00:00, Exit Price: 7593.299
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-21 19:22:00, Entry Price: 7584.85
# Exit Time: 2023-07-21 19:22:00, Exit Price: 7585.309
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-21 19:34:00, Entry Price: 7577.431
# Exit Time: 2023-07-21 19:34:00, Exit Price: 7577.933
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-21 20:57:00, Entry Price: 7584.004
# Exit Time: 2023-07-21 20:57:00, Exit Price: 7584.424
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-21 21:03:00, Entry Price: 7573.635
# Exit Time: 2023-07-21 21:03:00, Exit Price: 7574.12
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-21 21:55:00, Entry Price: 7572.583
# Exit Time: 2023-07-21 21:55:00, Exit Price: 7573.01
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-21 21:58:00, Entry Price: 7558.978
# Exit Time: 2023-07-21 21:58:00, Exit Price: 7559.379
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-21 22:10:00, Entry Price: 7552.655
# Exit Time: 2023-07-21 22:10:00, Exit Price: 7553.09
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-21 22:52:00, Entry Price: 7554.559
# Exit Time: 2023-07-21 22:52:00, Exit Price: 7555.015
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-21 23:41:00, Entry Price: 7550.543
# Exit Time: 2023-07-21 23:41:00, Exit Price: 7550.922
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-22 00:05:00, Entry Price: 7545.533
# Exit Time: 2023-07-22 00:05:00, Exit Price: 7545.966
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-22 00:37:00, Entry Price: 7537.3
# Exit Time: 2023-07-22 00:37:00, Exit Price: 7537.804
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-22 00:43:00, Entry Price: 7532.343
# Exit Time: 2023-07-22 00:43:00, Exit Price: 7532.821
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-22 00:57:00, Entry Price: 7527.211
# Exit Time: 2023-07-22 00:57:00, Exit Price: 7527.644
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-22 01:47:00, Entry Price: 7534.991
# Exit Time: 2023-07-22 01:47:00, Exit Price: 7535.364
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-07-22 02:03:00, Entry Price: 7515.796
# Exit Time: 2023-07-22 02:03:00, Exit Price: 7516.249
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-22 02:07:00, Entry Price: 7512.127
# Exit Time: 2023-07-22 02:07:00, Exit Price: 7512.585
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-22 02:17:00, Entry Price: 7510.686
# Exit Time: 2023-07-22 02:17:00, Exit Price: 7511.124
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-22 02:28:00, Entry Price: 7496.528
# Exit Time: 2023-07-22 02:28:00, Exit Price: 7496.955
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-22 02:55:00, Entry Price: 7491.014
# Exit Time: 2023-07-22 02:55:00, Exit Price: 7491.455
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-22 03:15:00, Entry Price: 7480.064
# Exit Time: 2023-07-22 03:15:00, Exit Price: 7480.462
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-22 04:21:00, Entry Price: 7491.837
# Exit Time: 2023-07-22 04:21:00, Exit Price: 7492.332
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-22 04:46:00, Entry Price: 7479.269
# Exit Time: 2023-07-22 04:46:00, Exit Price: 7479.73
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-22 05:14:00, Entry Price: 7479.776
# Exit Time: 2023-07-22 05:14:00, Exit Price: 7480.209
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-22 05:57:00, Entry Price: 7480.854
# Exit Time: 2023-07-22 05:57:00, Exit Price: 7481.305
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-22 06:05:00, Entry Price: 7472.669
# Exit Time: 2023-07-22 06:05:00, Exit Price: 7473.131
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-22 06:22:00, Entry Price: 7464.682
# Exit Time: 2023-07-22 06:22:00, Exit Price: 7465.127
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-22 08:32:00, Entry Price: 7493.705
# Exit Time: 2023-07-22 08:32:00, Exit Price: 7494.172
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-22 09:40:00, Entry Price: 7501.028
# Exit Time: 2023-07-22 09:40:00, Exit Price: 7501.412
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-22 11:01:00, Entry Price: 7523.076
# Exit Time: 2023-07-22 11:01:00, Exit Price: 7523.485
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-22 11:05:00, Entry Price: 7518.704
# Exit Time: 2023-07-22 11:05:00, Exit Price: 7519.199
# Profit/Loss: 0.49
#
# Trade Type: BUY
# Entry Time: 2023-07-22 12:05:00, Entry Price: 7520.235
# Exit Time: 2023-07-22 12:05:00, Exit Price: 7520.629
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-22 13:23:00, Entry Price: 7537.158
# Exit Time: 2023-07-22 13:23:00, Exit Price: 7537.623
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-22 13:57:00, Entry Price: 7534.292
# Exit Time: 2023-07-22 13:57:00, Exit Price: 7534.737
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-22 14:16:00, Entry Price: 7522.958
# Exit Time: 2023-07-22 14:16:00, Exit Price: 7523.388
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-22 14:55:00, Entry Price: 7527.346
# Exit Time: 2023-07-22 14:55:00, Exit Price: 7527.81
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-22 14:58:00, Entry Price: 7511.636
# Exit Time: 2023-07-22 14:58:00, Exit Price: 7512.043
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-22 15:06:00, Entry Price: 7506.212
# Exit Time: 2023-07-22 15:06:00, Exit Price: 7506.621
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-22 15:12:00, Entry Price: 7504.938
# Exit Time: 2023-07-22 15:12:00, Exit Price: 7505.315
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-22 15:33:00, Entry Price: 7498.06
# Exit Time: 2023-07-22 15:33:00, Exit Price: 7498.491
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-22 15:44:00, Entry Price: 7493.552
# Exit Time: 2023-07-22 15:44:00, Exit Price: 7493.97
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-22 15:58:00, Entry Price: 7475.477
# Exit Time: 2023-07-22 15:58:00, Exit Price: 7475.825
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-07-22 17:22:00, Entry Price: 7488.923
# Exit Time: 2023-07-22 17:22:00, Exit Price: 7489.337
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-22 17:57:00, Entry Price: 7495.232
# Exit Time: 2023-07-22 17:57:00, Exit Price: 7495.65
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-22 18:00:00, Entry Price: 7487.43
# Exit Time: 2023-07-22 18:00:00, Exit Price: 7487.841
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-22 18:03:00, Entry Price: 7479.77
# Exit Time: 2023-07-22 18:03:00, Exit Price: 7480.249
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-22 18:06:00, Entry Price: 7479.214
# Exit Time: 2023-07-22 18:06:00, Exit Price: 7479.715
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-22 19:39:00, Entry Price: 7489.178
# Exit Time: 2023-07-22 19:39:00, Exit Price: 7489.603
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-22 19:50:00, Entry Price: 7473.228
# Exit Time: 2023-07-22 19:50:00, Exit Price: 7473.759
# Profit/Loss: 0.53
#
# Trade Type: BUY
# Entry Time: 2023-07-22 20:02:00, Entry Price: 7466.773
# Exit Time: 2023-07-22 20:02:00, Exit Price: 7467.234
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-22 20:18:00, Entry Price: 7461.38
# Exit Time: 2023-07-22 20:18:00, Exit Price: 7461.806
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-22 21:26:00, Entry Price: 7475.987
# Exit Time: 2023-07-22 21:26:00, Exit Price: 7476.373
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-22 21:45:00, Entry Price: 7475.48
# Exit Time: 2023-07-22 21:45:00, Exit Price: 7475.939
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-22 22:46:00, Entry Price: 7479.155
# Exit Time: 2023-07-22 22:46:00, Exit Price: 7479.542
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-22 23:11:00, Entry Price: 7474.645
# Exit Time: 2023-07-22 23:11:00, Exit Price: 7475.057
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-22 23:57:00, Entry Price: 7478.192
# Exit Time: 2023-07-22 23:57:00, Exit Price: 7478.607
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-23 01:04:00, Entry Price: 7489.535
# Exit Time: 2023-07-23 01:04:00, Exit Price: 7489.991
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-23 01:38:00, Entry Price: 7489.686
# Exit Time: 2023-07-23 01:38:00, Exit Price: 7490.217
# Profit/Loss: 0.53
#
# Trade Type: BUY
# Entry Time: 2023-07-23 01:52:00, Entry Price: 7478.703
# Exit Time: 2023-07-23 01:52:00, Exit Price: 7479.137
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-23 02:15:00, Entry Price: 7469.439
# Exit Time: 2023-07-23 02:15:00, Exit Price: 7469.962
# Profit/Loss: 0.52
#
# Trade Type: BUY
# Entry Time: 2023-07-23 02:19:00, Entry Price: 7462.154
# Exit Time: 2023-07-23 02:19:00, Exit Price: 7462.586
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-23 03:33:00, Entry Price: 7462.347
# Exit Time: 2023-07-23 03:33:00, Exit Price: 7462.895
# Profit/Loss: 0.55
#
# Trade Type: BUY
# Entry Time: 2023-07-23 03:40:00, Entry Price: 7453.482
# Exit Time: 2023-07-23 03:40:00, Exit Price: 7454.001
# Profit/Loss: 0.52
#
# Trade Type: BUY
# Entry Time: 2023-07-23 05:30:00, Entry Price: 7478.916
# Exit Time: 2023-07-23 05:30:00, Exit Price: 7479.357
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-23 06:14:00, Entry Price: 7480.265
# Exit Time: 2023-07-23 06:14:00, Exit Price: 7480.677
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-23 06:17:00, Entry Price: 7477.043
# Exit Time: 2023-07-23 06:17:00, Exit Price: 7477.424
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-23 06:28:00, Entry Price: 7471.934
# Exit Time: 2023-07-23 06:28:00, Exit Price: 7472.378
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-23 06:48:00, Entry Price: 7457.86
# Exit Time: 2023-07-23 06:48:00, Exit Price: 7458.271
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-23 07:28:00, Entry Price: 7442.428
# Exit Time: 2023-07-23 07:28:00, Exit Price: 7442.897
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-23 07:42:00, Entry Price: 7434.726
# Exit Time: 2023-07-23 07:42:00, Exit Price: 7435.123
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-23 07:52:00, Entry Price: 7423.159
# Exit Time: 2023-07-23 07:52:00, Exit Price: 7423.615
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-23 07:55:00, Entry Price: 7421.961
# Exit Time: 2023-07-23 07:55:00, Exit Price: 7422.064
# Profit/Loss: 0.10
#
# Trade Type: BUY
# Entry Time: 2023-07-23 08:14:00, Entry Price: 7421.702
# Exit Time: 2023-07-23 08:14:00, Exit Price: 7422.09
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-23 08:31:00, Entry Price: 7415.718
# Exit Time: 2023-07-23 08:31:00, Exit Price: 7416.149
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-23 09:49:00, Entry Price: 7421.124
# Exit Time: 2023-07-23 09:49:00, Exit Price: 7421.578
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-23 09:54:00, Entry Price: 7416.006
# Exit Time: 2023-07-23 09:54:00, Exit Price: 7416.47
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-23 10:45:00, Entry Price: 7411.211
# Exit Time: 2023-07-23 10:45:00, Exit Price: 7411.677
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-23 11:42:00, Entry Price: 7413.478
# Exit Time: 2023-07-23 11:42:00, Exit Price: 7413.994
# Profit/Loss: 0.52
#
# Trade Type: BUY
# Entry Time: 2023-07-23 11:57:00, Entry Price: 7410.148
# Exit Time: 2023-07-23 11:57:00, Exit Price: 7410.649
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-23 12:04:00, Entry Price: 7407.495
# Exit Time: 2023-07-23 12:04:00, Exit Price: 7407.889
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-23 12:13:00, Entry Price: 7404.427
# Exit Time: 2023-07-23 12:13:00, Exit Price: 7404.844
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-23 12:23:00, Entry Price: 7397.141
# Exit Time: 2023-07-23 12:23:00, Exit Price: 7397.593
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-23 13:24:00, Entry Price: 7403.996
# Exit Time: 2023-07-23 13:24:00, Exit Price: 7404.467
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-23 13:39:00, Entry Price: 7401.829
# Exit Time: 2023-07-23 13:39:00, Exit Price: 7402.26
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-23 13:53:00, Entry Price: 7392.548
# Exit Time: 2023-07-23 13:53:00, Exit Price: 7393.018
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-23 14:12:00, Entry Price: 7380.242
# Exit Time: 2023-07-23 14:12:00, Exit Price: 7380.594
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-07-23 14:42:00, Entry Price: 7378.265
# Exit Time: 2023-07-23 14:42:00, Exit Price: 7378.75
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-23 15:04:00, Entry Price: 7361.465
# Exit Time: 2023-07-23 15:04:00, Exit Price: 7361.961
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-23 15:09:00, Entry Price: 7353.082
# Exit Time: 2023-07-23 15:09:00, Exit Price: 7353.54
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-23 15:29:00, Entry Price: 7332.28
# Exit Time: 2023-07-23 15:29:00, Exit Price: 7332.737
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-07-23 16:15:00, Entry Price: 7337.894
# Exit Time: 2023-07-23 16:15:00, Exit Price: 7338.292
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-23 16:38:00, Entry Price: 7339.006
# Exit Time: 2023-07-23 16:38:00, Exit Price: 7339.426
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-23 17:05:00, Entry Price: 7331.564
# Exit Time: 2023-07-23 17:05:00, Exit Price: 7331.936
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-07-23 18:24:00, Entry Price: 7321.912
# Exit Time: 2023-07-23 18:24:00, Exit Price: 7322.395
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-23 18:51:00, Entry Price: 7321.755
# Exit Time: 2023-07-23 18:51:00, Exit Price: 7322.192
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-23 19:17:00, Entry Price: 7314.423
# Exit Time: 2023-07-23 19:17:00, Exit Price: 7314.832
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-23 19:20:00, Entry Price: 7301.613
# Exit Time: 2023-07-23 19:20:00, Exit Price: 7302.001
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-07-23 19:36:00, Entry Price: 7299.141
# Exit Time: 2023-07-23 19:36:00, Exit Price: 7299.524
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-23 20:06:00, Entry Price: 7299.833
# Exit Time: 2023-07-23 20:06:00, Exit Price: 7300.228
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-23 20:33:00, Entry Price: 7297.625
# Exit Time: 2023-07-23 20:33:00, Exit Price: 7298.053
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-23 20:55:00, Entry Price: 7288.389
# Exit Time: 2023-07-23 20:55:00, Exit Price: 7288.828
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-07-23 21:02:00, Entry Price: 7281.129
# Exit Time: 2023-07-23 21:02:00, Exit Price: 7281.499
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-07-23 22:12:00, Entry Price: 7291.247
# Exit Time: 2023-07-23 22:12:00, Exit Price: 7291.629
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-23 22:38:00, Entry Price: 7286.121
# Exit Time: 2023-07-23 22:38:00, Exit Price: 7286.536
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-07-23 23:04:00, Entry Price: 7282.777
# Exit Time: 2023-07-23 23:04:00, Exit Price: 7283.284
# Profit/Loss: 0.51
#
# Trade Type: BUY
# Entry Time: 2023-07-23 23:09:00, Entry Price: 7272.993
# Exit Time: 2023-07-23 23:09:00, Exit Price: 7273.39
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-07-23 23:40:00, Entry Price: 7266.999
# Exit Time: 2023-07-23 23:40:00, Exit Price: 7267.445
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-24 00:08:00, Entry Price: 7264.2
# Exit Time: 2023-07-24 00:08:00, Exit Price: 7264.655
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-07-24 00:41:00, Entry Price: 7266.312
# Exit Time: 2023-07-24 00:41:00, Exit Price: 7266.738
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-24 01:03:00, Entry Price: 7259.802
# Exit Time: 2023-07-24 01:03:00, Exit Price: 7260.232
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-24 01:58:00, Entry Price: 7262.151
# Exit Time: 2023-07-24 01:58:00, Exit Price: 7262.568
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-07-24 02:04:00, Entry Price: 7261.303
# Exit Time: 2023-07-24 02:04:00, Exit Price: 7261.734
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-24 02:53:00, Entry Price: 7261.929
# Exit Time: 2023-07-24 02:53:00, Exit Price: 7262.433
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-24 04:49:00, Entry Price: 7276.785
# Exit Time: 2023-07-24 04:49:00, Exit Price: 7277.162
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-07-24 05:09:00, Entry Price: 7275.721
# Exit Time: 2023-07-24 05:09:00, Exit Price: 7276.204
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-07-24 07:52:00, Entry Price: 7305.922
# Exit Time: 2023-07-24 07:52:00, Exit Price: 7306.349
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-07-24 09:14:00, Entry Price: 7320.16
# Exit Time: 2023-07-24 09:14:00, Exit Price: 7320.633
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-07-24 10:46:00, Entry Price: 7349.994
# Exit Time: 2023-07-24 10:46:00, Exit Price: 7350.495
# Profit/Loss: 0.50
#
# Trade Type: BUY
# Entry Time: 2023-07-24 11:18:00, Entry Price: 7345.837
# Exit Time: 2023-07-24 11:18:00, Exit Price: 7346.207
# Profit/Loss: 0.37
#
# ...
# Exit Time: 2023-08-13 14:49:00, Exit Price: 6812.553
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-08-13 14:55:00, Entry Price: 6806.375
# Exit Time: 2023-08-13 14:55:00, Exit Price: 6806.721
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-08-13 15:24:00, Entry Price: 6802.369
# Exit Time: 2023-08-13 15:24:00, Exit Price: 6802.739
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-08-13 15:55:00, Entry Price: 6797.145
# Exit Time: 2023-08-13 15:55:00, Exit Price: 6797.519
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-08-13 16:02:00, Entry Price: 6794.177
# Exit Time: 2023-08-13 16:02:00, Exit Price: 6794.569
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-13 16:10:00, Entry Price: 6785.362
# Exit Time: 2023-08-13 16:10:00, Exit Price: 6785.801
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-08-13 18:40:00, Entry Price: 6827.149
# Exit Time: 2023-08-13 18:40:00, Exit Price: 6827.536
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-13 19:11:00, Entry Price: 6813.64
# Exit Time: 2023-08-13 19:11:00, Exit Price: 6814.01
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-08-13 19:15:00, Entry Price: 6811.375
# Exit Time: 2023-08-13 19:15:00, Exit Price: 6811.777
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-08-13 19:24:00, Entry Price: 6800.533
# Exit Time: 2023-08-13 19:24:00, Exit Price: 6800.925
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-13 19:50:00, Entry Price: 6787.618
# Exit Time: 2023-08-13 19:50:00, Exit Price: 6788.001
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-13 19:57:00, Entry Price: 6782.033
# Exit Time: 2023-08-13 19:57:00, Exit Price: 6782.417
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-13 21:43:00, Entry Price: 6800.749
# Exit Time: 2023-08-13 21:43:00, Exit Price: 6801.089
# Profit/Loss: 0.34
#
# Trade Type: BUY
# Entry Time: 2023-08-13 22:01:00, Entry Price: 6796.682
# Exit Time: 2023-08-13 22:01:00, Exit Price: 6797.144
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-08-13 22:09:00, Entry Price: 6786.09
# Exit Time: 2023-08-13 22:09:00, Exit Price: 6786.465
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-13 22:13:00, Entry Price: 6783.116
# Exit Time: 2023-08-13 22:13:00, Exit Price: 6783.522
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-13 22:36:00, Entry Price: 6780.748
# Exit Time: 2023-08-13 22:36:00, Exit Price: 6781.152
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-08-13 23:50:00, Entry Price: 6787.787
# Exit Time: 2023-08-13 23:50:00, Exit Price: 6788.263
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-08-14 00:05:00, Entry Price: 6782.987
# Exit Time: 2023-08-14 00:05:00, Exit Price: 6783.413
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-08-14 00:36:00, Entry Price: 6779.076
# Exit Time: 2023-08-14 00:36:00, Exit Price: 6779.436
# Profit/Loss: 0.36
#
# Trade Type: BUY
# Entry Time: 2023-08-14 01:03:00, Entry Price: 6779.836
# Exit Time: 2023-08-14 01:03:00, Exit Price: 6780.208
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-08-14 01:14:00, Entry Price: 6774.89
# Exit Time: 2023-08-14 01:14:00, Exit Price: 6775.303
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-14 02:15:00, Entry Price: 6784.005
# Exit Time: 2023-08-14 02:15:00, Exit Price: 6784.457
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-08-14 02:29:00, Entry Price: 6776.409
# Exit Time: 2023-08-14 02:29:00, Exit Price: 6776.832
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-14 02:32:00, Entry Price: 6766.91
# Exit Time: 2023-08-14 02:32:00, Exit Price: 6767.253
# Profit/Loss: 0.34
#
# Trade Type: BUY
# Entry Time: 2023-08-14 03:29:00, Entry Price: 6775.502
# Exit Time: 2023-08-14 03:29:00, Exit Price: 6775.892
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-14 03:33:00, Entry Price: 6773.747
# Exit Time: 2023-08-14 03:33:00, Exit Price: 6774.154
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-14 03:44:00, Entry Price: 6769.188
# Exit Time: 2023-08-14 03:44:00, Exit Price: 6769.594
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-14 04:40:00, Entry Price: 6767.018
# Exit Time: 2023-08-14 04:40:00, Exit Price: 6767.392
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-08-14 05:25:00, Entry Price: 6766.823
# Exit Time: 2023-08-14 05:25:00, Exit Price: 6767.229
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-14 06:07:00, Entry Price: 6770.978
# Exit Time: 2023-08-14 06:07:00, Exit Price: 6771.39
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-14 06:34:00, Entry Price: 6752.514
# Exit Time: 2023-08-14 06:34:00, Exit Price: 6752.877
# Profit/Loss: 0.36
#
# Trade Type: BUY
# Entry Time: 2023-08-14 06:41:00, Entry Price: 6743.005
# Exit Time: 2023-08-14 06:41:00, Exit Price: 6743.433
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-08-14 07:17:00, Entry Price: 6736.115
# Exit Time: 2023-08-14 07:17:00, Exit Price: 6736.535
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-14 07:44:00, Entry Price: 6733.391
# Exit Time: 2023-08-14 07:44:00, Exit Price: 6733.862
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-08-14 07:58:00, Entry Price: 6732.195
# Exit Time: 2023-08-14 07:58:00, Exit Price: 6732.573
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-14 08:16:00, Entry Price: 6719.755
# Exit Time: 2023-08-14 08:16:00, Exit Price: 6720.188
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-08-14 10:24:00, Entry Price: 6741.692
# Exit Time: 2023-08-14 10:24:00, Exit Price: 6742.109
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-14 10:42:00, Entry Price: 6726.952
# Exit Time: 2023-08-14 10:42:00, Exit Price: 6727.385
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-08-14 10:48:00, Entry Price: 6728.799
# Exit Time: 2023-08-14 10:48:00, Exit Price: 6729.186
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-14 11:37:00, Entry Price: 6726.11
# Exit Time: 2023-08-14 11:37:00, Exit Price: 6726.519
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-14 12:23:00, Entry Price: 6733.568
# Exit Time: 2023-08-14 12:23:00, Exit Price: 6733.919
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-08-14 12:46:00, Entry Price: 6718.304
# Exit Time: 2023-08-14 12:46:00, Exit Price: 6718.713
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-14 16:03:00, Entry Price: 6756.305
# Exit Time: 2023-08-14 16:03:00, Exit Price: 6756.665
# Profit/Loss: 0.36
#
# Trade Type: BUY
# Entry Time: 2023-08-14 18:15:00, Entry Price: 6775.932
# Exit Time: 2023-08-14 18:15:00, Exit Price: 6776.312
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-14 19:10:00, Entry Price: 6787.112
# Exit Time: 2023-08-14 19:10:00, Exit Price: 6787.486
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-08-14 19:39:00, Entry Price: 6786.923
# Exit Time: 2023-08-14 19:39:00, Exit Price: 6787.256
# Profit/Loss: 0.33
#
# Trade Type: BUY
# Entry Time: 2023-08-14 19:58:00, Entry Price: 6775.061
# Exit Time: 2023-08-14 19:58:00, Exit Price: 6775.452
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-14 20:02:00, Entry Price: 6768.77
# Exit Time: 2023-08-14 20:02:00, Exit Price: 6769.149
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-14 20:34:00, Entry Price: 6769.925
# Exit Time: 2023-08-14 20:34:00, Exit Price: 6770.344
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-14 21:07:00, Entry Price: 6770.347
# Exit Time: 2023-08-14 21:07:00, Exit Price: 6770.696
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-08-14 22:05:00, Entry Price: 6777.373
# Exit Time: 2023-08-14 22:05:00, Exit Price: 6777.75
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-14 22:24:00, Entry Price: 6773.032
# Exit Time: 2023-08-14 22:24:00, Exit Price: 6773.451
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-14 22:42:00, Entry Price: 6752.677
# Exit Time: 2023-08-14 22:42:00, Exit Price: 6752.982
# Profit/Loss: 0.31
#
# Trade Type: BUY
# Entry Time: 2023-08-15 00:09:00, Entry Price: 6773.526
# Exit Time: 2023-08-15 00:09:00, Exit Price: 6773.922
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-08-15 00:14:00, Entry Price: 6765.589
# Exit Time: 2023-08-15 00:14:00, Exit Price: 6765.996
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-15 00:51:00, Entry Price: 6771.466
# Exit Time: 2023-08-15 00:51:00, Exit Price: 6771.88
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-15 01:43:00, Entry Price: 6773.13
# Exit Time: 2023-08-15 01:43:00, Exit Price: 6773.582
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-08-15 02:02:00, Entry Price: 6773.14
# Exit Time: 2023-08-15 02:02:00, Exit Price: 6773.51
# Profit/Loss: 0.37
#
# Trade Type: BUY
# Entry Time: 2023-08-15 03:06:00, Entry Price: 6785.059
# Exit Time: 2023-08-15 03:06:00, Exit Price: 6785.399
# Profit/Loss: 0.34
#
# Trade Type: BUY
# Entry Time: 2023-08-15 07:12:00, Entry Price: 6830.464
# Exit Time: 2023-08-15 07:12:00, Exit Price: 6830.815
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-08-15 10:44:00, Entry Price: 6882.223
# Exit Time: 2023-08-15 10:44:00, Exit Price: 6882.681
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-08-15 11:33:00, Entry Price: 6893.083
# Exit Time: 2023-08-15 11:33:00, Exit Price: 6893.527
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-08-15 11:38:00, Entry Price: 6881.122
# Exit Time: 2023-08-15 11:38:00, Exit Price: 6881.529
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-15 11:46:00, Entry Price: 6875.542
# Exit Time: 2023-08-15 11:46:00, Exit Price: 6875.884
# Profit/Loss: 0.34
#
# Trade Type: BUY
# Entry Time: 2023-08-15 11:54:00, Entry Price: 6873.517
# Exit Time: 2023-08-15 11:54:00, Exit Price: 6873.896
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-15 13:05:00, Entry Price: 6867.978
# Exit Time: 2023-08-15 13:05:00, Exit Price: 6868.429
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-08-15 14:40:00, Entry Price: 6893.521
# Exit Time: 2023-08-15 14:40:00, Exit Price: 6893.939
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-15 14:45:00, Entry Price: 6882.452
# Exit Time: 2023-08-15 14:45:00, Exit Price: 6882.901
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-08-15 16:23:00, Entry Price: 6890.288
# Exit Time: 2023-08-15 16:23:00, Exit Price: 6890.727
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-08-15 16:37:00, Entry Price: 6888.958
# Exit Time: 2023-08-15 16:37:00, Exit Price: 6889.318
# Profit/Loss: 0.36
#
# Trade Type: BUY
# Entry Time: 2023-08-15 17:36:00, Entry Price: 6891.236
# Exit Time: 2023-08-15 17:36:00, Exit Price: 6891.65
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-15 17:43:00, Entry Price: 6883.201
# Exit Time: 2023-08-15 17:43:00, Exit Price: 6883.661
# Profit/Loss: 0.46
#
# Trade Type: BUY
# Entry Time: 2023-08-15 17:57:00, Entry Price: 6882.06
# Exit Time: 2023-08-15 17:57:00, Exit Price: 6882.543
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-08-15 19:17:00, Entry Price: 6904.438
# Exit Time: 2023-08-15 19:17:00, Exit Price: 6904.861
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-15 19:34:00, Entry Price: 6887.211
# Exit Time: 2023-08-15 19:34:00, Exit Price: 6887.646
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-08-15 20:20:00, Entry Price: 6888.792
# Exit Time: 2023-08-15 20:20:00, Exit Price: 6889.268
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-08-15 20:55:00, Entry Price: 6892.732
# Exit Time: 2023-08-15 20:55:00, Exit Price: 6893.207
# Profit/Loss: 0.48
#
# Trade Type: BUY
# Entry Time: 2023-08-15 21:13:00, Entry Price: 6885.318
# Exit Time: 2023-08-15 21:13:00, Exit Price: 6885.756
# Profit/Loss: 0.44
#
# Trade Type: BUY
# Entry Time: 2023-08-15 22:35:00, Entry Price: 6883.775
# Exit Time: 2023-08-15 22:35:00, Exit Price: 6884.174
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-08-15 23:12:00, Entry Price: 6890.56
# Exit Time: 2023-08-15 23:12:00, Exit Price: 6890.892
# Profit/Loss: 0.33
#
# Trade Type: BUY
# Entry Time: 2023-08-15 23:17:00, Entry Price: 6887.924
# Exit Time: 2023-08-15 23:17:00, Exit Price: 6888.351
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-08-15 23:41:00, Entry Price: 6880.571
# Exit Time: 2023-08-15 23:41:00, Exit Price: 6880.932
# Profit/Loss: 0.36
#
# Trade Type: BUY
# Entry Time: 2023-08-16 00:11:00, Entry Price: 6879.718
# Exit Time: 2023-08-16 00:11:00, Exit Price: 6880.126
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-16 00:19:00, Entry Price: 6874.761
# Exit Time: 2023-08-16 00:19:00, Exit Price: 6875.228
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-08-16 00:23:00, Entry Price: 6867.283
# Exit Time: 2023-08-16 00:23:00, Exit Price: 6867.736
# Profit/Loss: 0.45
#
# Trade Type: BUY
# Entry Time: 2023-08-16 00:28:00, Entry Price: 6864.676
# Exit Time: 2023-08-16 00:28:00, Exit Price: 6864.986
# Profit/Loss: 0.31
#
# Trade Type: BUY
# Entry Time: 2023-08-16 02:35:00, Entry Price: 6894.517
# Exit Time: 2023-08-16 02:35:00, Exit Price: 6895.027
# Profit/Loss: 0.51
#
# Trade Type: BUY
# Entry Time: 2023-08-16 03:04:00, Entry Price: 6892.369
# Exit Time: 2023-08-16 03:04:00, Exit Price: 6892.766
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-08-16 03:08:00, Entry Price: 6878.473
# Exit Time: 2023-08-16 03:08:00, Exit Price: 6878.816
# Profit/Loss: 0.34
#
# Trade Type: BUY
# Entry Time: 2023-08-16 06:45:00, Entry Price: 6938.36
# Exit Time: 2023-08-16 06:45:00, Exit Price: 6938.828
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-08-16 07:18:00, Entry Price: 6937.596
# Exit Time: 2023-08-16 07:18:00, Exit Price: 6938.02
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-16 07:47:00, Entry Price: 6933.926
# Exit Time: 2023-08-16 07:47:00, Exit Price: 6934.352
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-08-16 08:04:00, Entry Price: 6932.391
# Exit Time: 2023-08-16 08:04:00, Exit Price: 6932.82
# Profit/Loss: 0.43
#
# Trade Type: BUY
# Entry Time: 2023-08-16 09:38:00, Entry Price: 6935.185
# Exit Time: 2023-08-16 09:38:00, Exit Price: 6935.583
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-08-16 11:54:00, Entry Price: 6945.857
# Exit Time: 2023-08-16 11:54:00, Exit Price: 6946.281
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-16 12:12:00, Entry Price: 6945.611
# Exit Time: 2023-08-16 12:12:00, Exit Price: 6945.991
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-16 12:20:00, Entry Price: 6936.439
# Exit Time: 2023-08-16 12:20:00, Exit Price: 6936.908
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-08-16 12:24:00, Entry Price: 6928.649
# Exit Time: 2023-08-16 12:24:00, Exit Price: 6929.039
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-16 13:05:00, Entry Price: 6934.716
# Exit Time: 2023-08-16 13:05:00, Exit Price: 6935.128
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-16 13:40:00, Entry Price: 6937.082
# Exit Time: 2023-08-16 13:40:00, Exit Price: 6937.482
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-08-16 13:50:00, Entry Price: 6934.669
# Exit Time: 2023-08-16 13:50:00, Exit Price: 6935.021
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-08-16 14:25:00, Entry Price: 6935.263
# Exit Time: 2023-08-16 14:25:00, Exit Price: 6935.673
# Profit/Loss: 0.41
#
# Trade Type: BUY
# Entry Time: 2023-08-16 14:28:00, Entry Price: 6927.77
# Exit Time: 2023-08-16 14:28:00, Exit Price: 6928.125
# Profit/Loss: 0.35
#
# Trade Type: BUY
# Entry Time: 2023-08-16 14:38:00, Entry Price: 6916.159
# Exit Time: 2023-08-16 14:38:00, Exit Price: 6916.542
# Profit/Loss: 0.38
#
# Trade Type: BUY
# Entry Time: 2023-08-16 15:17:00, Entry Price: 6922.085
# Exit Time: 2023-08-16 15:17:00, Exit Price: 6922.478
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-16 15:20:00, Entry Price: 6921.165
# Exit Time: 2023-08-16 15:20:00, Exit Price: 6921.569
# Profit/Loss: 0.40
#
# Trade Type: BUY
# Entry Time: 2023-08-16 15:29:00, Entry Price: 6913.679
# Exit Time: 2023-08-16 15:29:00, Exit Price: 6914.144
# Profit/Loss: 0.47
#
# Trade Type: BUY
# Entry Time: 2023-08-16 16:18:00, Entry Price: 6917.357
# Exit Time: 2023-08-16 16:18:00, Exit Price: 6917.747
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-16 16:26:00, Entry Price: 6907.252
# Exit Time: 2023-08-16 16:26:00, Exit Price: 6907.674
# Profit/Loss: 0.42
#
# Trade Type: BUY
# Entry Time: 2023-08-16 16:31:00, Entry Price: 6905.94
# Exit Time: 2023-08-16 16:31:00, Exit Price: 6906.33
# Profit/Loss: 0.39
#
# Trade Type: BUY
# Entry Time: 2023-08-16 17:19:00, Entry Price: 6905.601
# Exit Time: 2023-08-16 17:19:00, Exit Price: 6905.918
# Profit/Loss: 0.32
#
# Total Profit/Loss: 526.23
# Total Trades: 1253

# %% [markdown]
# ## **BackTest (RSI under 30 strategy BOOM) + Trade Visualizer (Profitable but high amount lost per trades ❌)**

# %% [markdown]
# ## To be tested too

# %%
# ...

def backtest_new_strategy(df, lot_size=0.2):
    trades = []
    in_trade = False

    for i in range(2, len(df)):
        current_bar = df.iloc[i]
        previous_bar = df.iloc[i - 1]

        # Check for new sell conditions
        if previous_bar["rsi"] > 30 and current_bar["rsi"] <= 30:
            if not in_trade:
                # Open a sell trade
                trade = {"entry_time": current_bar.name, "entry_price": current_bar["open"], "trade_type": "SELL"}
                trades.append(trade)
                in_trade = True

        # Check for trade closing condition
        if in_trade:
            # Calculate the closing time for the trade (1 minute after the trade was executed)
            closing_time = trade["entry_time"] + timedelta(minutes=1)

            if current_bar.name >= closing_time:
                # Close the trade
                trade["exit_time"] = current_bar.name
                trade["exit_price"] = current_bar["close"]
                trade["pnl"] = trade["entry_price"] - trade["exit_price"]
                trade["pnl"] *= lot_size
                in_trade = False

    return trades

def plot_trades(df, trades):
    fig = go.Figure(data=[go.Candlestick(x=df.index,
                                        open=df['open'],
                                        high=df['high'],
                                        low=df['low'],
                                        close=df['close'],
                                        increasing_line_color='orange',
                                        decreasing_line_color='green',
                                        line_width=1)])

    for trade in trades:
        entry_time = trade["entry_time"]
        entry_price = trade["entry_price"]
        exit_time = trade.get("exit_time", None)
        exit_price = trade.get("exit_price", None)

        fig.add_trace(go.Scatter(x=[entry_time],
        y=[entry_price],
        mode='markers',
        marker=dict(size=[10],
        symbol=['triangle-up'],
        color=['orange'],
        line=dict(width=2)),
        name="Entry"))

        if exit_time is not None and exit_price is not None:
            fig.add_trace(go.Scatter(x=[exit_time],
            y=[exit_price],
            mode='markers',
            marker=dict(size=[10],
            symbol=['triangle-down'],
            color=['green'],
            line=dict(width=2)),
            name="Exit"))

    fig.update_layout(
        title="Backtest Trades",
        xaxis_title="Time",
        yaxis_title="Price",
        xaxis_rangeslider_visible=False,
        plot_bgcolor='black',
        paper_bgcolor='black',
        font=dict(color='white'),
        showlegend=True,
        autosize=True,
        margin=dict(l=50, r=50, t=50, b=50),
        xaxis_showgrid=False,
        yaxis_showgrid=False,
    )

    fig.update_layout(width=800, height=800)

    fig.show()

def plot_histogram(trades):
    pnl_values = [trade.get('pnl', 0) for trade in trades]

    # Filter out zero values (trades that didn't close)
    pnl_values = [pnl for pnl in pnl_values if pnl != 0]

    winning_trades = [pnl for pnl in pnl_values if pnl > 0]
    losing_trades = [pnl for pnl in pnl_values if pnl < 0]

    fig = go.Figure()

    fig.add_trace(go.Histogram(x=winning_trades, opacity=0.75, name="Winning Trades"))
    fig.add_trace(go.Histogram(x=losing_trades, opacity=0.75, name="Losing Trades"))

    fig.update_layout(
        title="Number of Winning and Losing Trades",
        xaxis_title="Profit/Loss",
        yaxis_title="Number of Trades",
        plot_bgcolor='black',
        paper_bgcolor='black',
        font=dict(color='white'),
        showlegend=True,
        autosize=True,
        margin=dict(l=50, r=50, t=50, b=50),
        xaxis_showgrid=True,
        yaxis_showgrid=True,
    )

    fig.update_layout(barmode='overlay')

    fig.show()

def plot_total(trades):
    pnl_values = [trade.get('pnl', 0) for trade in trades]

    # Filter out zero values (trades that didn't close)
    pnl_values = [pnl for pnl in pnl_values if pnl != 0]

    winning_trades = [pnl for pnl in pnl_values if pnl > 0]
    losing_trades = [pnl for pnl in pnl_values if pnl < 0]

    total_winning_trades = len(winning_trades)
    total_losing_trades = len(losing_trades)

    fig = go.Figure()

    fig.add_trace(go.Bar(x=["Winning Trades"], y=[total_winning_trades], name="Winning Trades", marker_color='green'))
    fig.add_trace(go.Bar(x=["Losing Trades"], y=[total_losing_trades], name="Losing Trades", marker_color='red'))

    fig.update_layout(
        title="Number of Winning and Losing Trades",
        xaxis_title="Trade Type",
        yaxis_title="Number of Trades",
        plot_bgcolor='black',
        paper_bgcolor='black',
        font=dict(color='white'),
        showlegend=True,
        autosize=True,
        margin=dict(l=50, r=50, t=50, b=50),
        xaxis_showgrid=False,
        yaxis_showgrid=True,
    )

    fig.show()


if __name__ == "__main__":
    symbol = "Boom 1000 Index"
    timeframe = mt5.TIMEFRAME_M1
    lot_size = 1.0
    period = 7

    # Specify the date range for historical data (adjust as needed)
    start_date = datetime(2023, 8, 16)
    end_date = datetime.now()

    # Step 1: Load historical data within the specified date range
    df = get_historical_data(symbol, timeframe, start_date, end_date)

    # Step 2: Calculate RSI
    calculate_rsi(df, period)

    # Step 3: Backtest the new strategy
    new_trades = backtest_new_strategy(df, lot_size)

    # Step 4: Print the backtest results
    total_pnl = 0
    for trade in new_trades:
        print(f"Trade Type: {trade['trade_type']}")
        print(f"Entry Time: {trade['entry_time']}, Entry Price: {trade['entry_price']}")
        print(f"Exit Time: {trade.get('exit_time', 'Not closed')}, Exit Price: {trade.get('exit_price', 'N/A')}")
        print(f"Profit/Loss: {trade.get('pnl', 0):.2f}\n")
        total_pnl += trade.get('pnl', 0)

    print(f"Total Profit/Loss: {total_pnl:.2f}")
    print(f"Total Trades: {len(new_trades)}")
    plot_histogram(new_trades)
    plot_total(new_trades)
    #plot_trades(df, trades)
# Out:
# Retrieved 1280 data points
# Trade Type: SELL
# Entry Time: 2023-08-15 23:31:00, Entry Price: 10461.464
# Exit Time: 2023-08-15 23:32:00, Exit Price: 10460.366
# Profit/Loss: 1.10
#
# Trade Type: SELL
# Entry Time: 2023-08-16 00:08:00, Entry Price: 10481.12
# Exit Time: 2023-08-16 00:09:00, Exit Price: 10494.265
# Profit/Loss: -13.14
#
# Trade Type: SELL
# Entry Time: 2023-08-16 00:23:00, Entry Price: 10485.976
# Exit Time: 2023-08-16 00:24:00, Exit Price: 10484.766
# Profit/Loss: 1.21
#
# Trade Type: SELL
# Entry Time: 2023-08-16 01:00:00, Entry Price: 10494.916
# Exit Time: 2023-08-16 01:01:00, Exit Price: 10493.655
# Profit/Loss: 1.26
#
# Trade Type: SELL
# Entry Time: 2023-08-16 01:44:00, Entry Price: 10471.685
# Exit Time: 2023-08-16 01:45:00, Exit Price: 10470.294
# Profit/Loss: 1.39
#
# Trade Type: SELL
# Entry Time: 2023-08-16 02:19:00, Entry Price: 10487.494
# Exit Time: 2023-08-16 02:20:00, Exit Price: 10486.34
# Profit/Loss: 1.15
#
# Trade Type: SELL
# Entry Time: 2023-08-16 02:34:00, Entry Price: 10481.559
# Exit Time: 2023-08-16 02:35:00, Exit Price: 10480.295
# Profit/Loss: 1.26
#
# Trade Type: SELL
# Entry Time: 2023-08-16 02:58:00, Entry Price: 10469.299
# Exit Time: 2023-08-16 02:59:00, Exit Price: 10468.016
# Profit/Loss: 1.28
#
# Trade Type: SELL
# Entry Time: 2023-08-16 03:27:00, Entry Price: 10471.507
# Exit Time: 2023-08-16 03:28:00, Exit Price: 10470.108
# Profit/Loss: 1.40
#
# Trade Type: SELL
# Entry Time: 2023-08-16 04:18:00, Entry Price: 10458.199
# Exit Time: 2023-08-16 04:19:00, Exit Price: 10456.78
# Profit/Loss: 1.42
#
# Trade Type: SELL
# Entry Time: 2023-08-16 05:02:00, Entry Price: 10443.101
# Exit Time: 2023-08-16 05:03:00, Exit Price: 10441.917
# Profit/Loss: 1.18
#
# Trade Type: SELL
# Entry Time: 2023-08-16 05:44:00, Entry Price: 10457.593
# Exit Time: 2023-08-16 05:45:00, Exit Price: 10456.347
# Profit/Loss: 1.25
#
# Trade Type: SELL
# Entry Time: 2023-08-16 06:06:00, Entry Price: 10461.326
# Exit Time: 2023-08-16 06:07:00, Exit Price: 10464.786
# Profit/Loss: -3.46
#
# Trade Type: SELL
# Entry Time: 2023-08-16 06:16:00, Entry Price: 10460.899
# Exit Time: 2023-08-16 06:17:00, Exit Price: 10459.564
# Profit/Loss: 1.33
#
# Trade Type: SELL
# Entry Time: 2023-08-16 06:32:00, Entry Price: 10453.597
# Exit Time: 2023-08-16 06:33:00, Exit Price: 10452.327
# Profit/Loss: 1.27
#
# Trade Type: SELL
# Entry Time: 2023-08-16 07:05:00, Entry Price: 10444.933
# Exit Time: 2023-08-16 07:06:00, Exit Price: 10443.642
# Profit/Loss: 1.29
#
# Trade Type: SELL
# Entry Time: 2023-08-16 07:34:00, Entry Price: 10463.462
# Exit Time: 2023-08-16 07:35:00, Exit Price: 10462.145
# Profit/Loss: 1.32
#
# Trade Type: SELL
# Entry Time: 2023-08-16 07:55:00, Entry Price: 10455.536
# Exit Time: 2023-08-16 07:56:00, Exit Price: 10454.232
# Profit/Loss: 1.30
#
# Trade Type: SELL
# Entry Time: 2023-08-16 08:29:00, Entry Price: 10461.298
# Exit Time: 2023-08-16 08:30:00, Exit Price: 10460.032
# Profit/Loss: 1.27
#
# Trade Type: SELL
# Entry Time: 2023-08-16 09:29:00, Entry Price: 10431.487
# Exit Time: 2023-08-16 09:30:00, Exit Price: 10430.27
# Profit/Loss: 1.22
#
# Trade Type: SELL
# Entry Time: 2023-08-16 09:46:00, Entry Price: 10428.312
# Exit Time: 2023-08-16 09:47:00, Exit Price: 10427.177
# Profit/Loss: 1.14
#
# Trade Type: SELL
# Entry Time: 2023-08-16 10:00:00, Entry Price: 10425.3
# Exit Time: 2023-08-16 10:01:00, Exit Price: 10424.006
# Profit/Loss: 1.29
#
# Trade Type: SELL
# Entry Time: 2023-08-16 10:28:00, Entry Price: 10422.605
# Exit Time: 2023-08-16 10:29:00, Exit Price: 10421.375
# Profit/Loss: 1.23
#
# Trade Type: SELL
# Entry Time: 2023-08-16 10:34:00, Entry Price: 10421.351
# Exit Time: 2023-08-16 10:35:00, Exit Price: 10420.156
# Profit/Loss: 1.19
#
# Trade Type: SELL
# Entry Time: 2023-08-16 11:51:00, Entry Price: 10415.253
# Exit Time: 2023-08-16 11:52:00, Exit Price: 10413.887
# Profit/Loss: 1.37
#
# Trade Type: SELL
# Entry Time: 2023-08-16 12:35:00, Entry Price: 10396.818
# Exit Time: 2023-08-16 12:36:00, Exit Price: 10395.583
# Profit/Loss: 1.23
#
# Trade Type: SELL
# Entry Time: 2023-08-16 13:01:00, Entry Price: 10392.362
# Exit Time: 2023-08-16 13:02:00, Exit Price: 10391.192
# Profit/Loss: 1.17
#
# Trade Type: SELL
# Entry Time: 2023-08-16 13:28:00, Entry Price: 10381.825
# Exit Time: 2023-08-16 13:29:00, Exit Price: 10380.532
# Profit/Loss: 1.29
#
# Trade Type: SELL
# Entry Time: 2023-08-16 14:28:00, Entry Price: 10401.14
# Exit Time: 2023-08-16 14:29:00, Exit Price: 10412.43
# Profit/Loss: -11.29
#
# Trade Type: SELL
# Entry Time: 2023-08-16 15:07:00, Entry Price: 10469.963
# Exit Time: 2023-08-16 15:08:00, Exit Price: 10468.602
# Profit/Loss: 1.36
#
# Trade Type: SELL
# Entry Time: 2023-08-16 16:14:00, Entry Price: 10474.168
# Exit Time: 2023-08-16 16:15:00, Exit Price: 10472.927
# Profit/Loss: 1.24
#
# Trade Type: SELL
# Entry Time: 2023-08-16 17:12:00, Entry Price: 10498.403
# Exit Time: 2023-08-16 17:13:00, Exit Price: 10497.094
# Profit/Loss: 1.31
#
# Trade Type: SELL
# Entry Time: 2023-08-16 17:31:00, Entry Price: 10499.597
# Exit Time: 2023-08-16 17:32:00, Exit Price: 10498.294
# Profit/Loss: 1.30
#
# Trade Type: SELL
# Entry Time: 2023-08-16 17:44:00, Entry Price: 10497.456
# Exit Time: 2023-08-16 17:45:00, Exit Price: 10496.19
# Profit/Loss: 1.27
#
# Trade Type: SELL
# Entry Time: 2023-08-16 18:00:00, Entry Price: 10496.144
# Exit Time: 2023-08-16 18:01:00, Exit Price: 10494.853
# Profit/Loss: 1.29
#
# Trade Type: SELL
# Entry Time: 2023-08-16 19:14:00, Entry Price: 10469.012
# Exit Time: 2023-08-16 19:15:00, Exit Price: 10467.82
# Profit/Loss: 1.19
#
# Trade Type: SELL
# Entry Time: 2023-08-16 19:40:00, Entry Price: 10460.489
# Exit Time: 2023-08-16 19:41:00, Exit Price: 10459.255
# Profit/Loss: 1.23
#
# Trade Type: SELL
# Entry Time: 2023-08-16 20:05:00, Entry Price: 10460.2
# Exit Time: 2023-08-16 20:06:00, Exit Price: 10459.046
# Profit/Loss: 1.15
#
# Total Profit/Loss: 16.28
# Total Trades: 38

# %% [markdown]
# # ***BackTest (RSI over 70 strategy Crash) + Trade Visualizer (Profitable ✅)***

# %% [markdown]
# ### This strategy seems to catch every spike (This should be Impossible)

# %% [markdown]
# ### Promitting but to be tested wildly before deploying, watch out for performance on demo account and see the logic behind it !!!

# %% [markdown]
# ### This look like a simulation of if a trade was taken on every spike

# %%
# ...

def backtest_new_strategy(df, lot_size=0.2):
    trades = []
    in_trade = False

    for i in range(2, len(df)):
        current_bar = df.iloc[i]
        previous_bar = df.iloc[i - 1]

        # Check for new sell conditions
        if previous_bar["rsi"] > 70 and current_bar["rsi"] <= 70:
            if not in_trade:
                # Open a sell trade
                trade = {"entry_time": current_bar.name, "entry_price": current_bar["open"], "trade_type": "SELL"}
                trades.append(trade)
                in_trade = True

        # Check for trade closing condition
        if in_trade:
            # Calculate the closing time for the trade (1 minute after the trade was executed)
            closing_time = trade["entry_time"] + timedelta(minutes=1)

            if current_bar.name >= closing_time:
                # Close the trade
                trade["exit_time"] = current_bar.name
                trade["exit_price"] = current_bar["close"]
                trade["pnl"] = trade["entry_price"] - trade["exit_price"]
                trade["pnl"] *= lot_size
                in_trade = False

    return trades

def plot_histogram(trades):
    pnl_values = [trade.get('pnl', 0) for trade in trades]

    # Filter out zero values (trades that didn't close)
    pnl_values = [pnl for pnl in pnl_values if pnl != 0]

    winning_trades = [pnl for pnl in pnl_values if pnl > 0]
    losing_trades = [pnl for pnl in pnl_values if pnl < 0]

    fig = go.Figure()

    fig.add_trace(go.Histogram(x=winning_trades, opacity=0.75, name="Winning Trades"))
    fig.add_trace(go.Histogram(x=losing_trades, opacity=0.75, name="Losing Trades"))

    fig.update_layout(
        title="Number of Winning and Losing Trades",
        xaxis_title="Profit/Loss",
        yaxis_title="Number of Trades",
        plot_bgcolor='black',
        paper_bgcolor='black',
        font=dict(color='white'),
        showlegend=True,
        autosize=True,
        margin=dict(l=50, r=50, t=50, b=50),
        xaxis_showgrid=True,
        yaxis_showgrid=True,
    )

    fig.update_layout(barmode='overlay')

    fig.show()
    
if __name__ == "__main__":
    symbol = "Crash 1000 Index"
    timeframe = mt5.TIMEFRAME_M1
    lot_size = 1
    period = 7

    # Specify the date range for historical data (adjust as needed)
    start_date = datetime(2023, 7, 16)
    end_date = datetime.now()

    # Step 1: Load historical data within the specified date range
    df = get_historical_data(symbol, timeframe, start_date, end_date)

    # Step 2: Calculate RSI
    calculate_rsi(df, period)

    # Step 3: Backtest the new strategy
    new_trades = backtest_new_strategy(df, lot_size)

    # Step 4: Print the backtest results
    total_pnl = 0
    for trade in new_trades:
        print(f"Trade Type: {trade['trade_type']}")
        print(f"Entry Time: {trade['entry_time']}, Entry Price: {trade['entry_price']}")
        print(f"Exit Time: {trade.get('exit_time', 'Not closed')}, Exit Price: {trade.get('exit_price', 'N/A')}")
        print(f"Profit/Loss: {trade.get('pnl', 0):.2f}\n")
        total_pnl += trade.get('pnl', 0)

    print(f"Total Profit/Loss: {total_pnl:.2f}")
    print(f"Total Trades: {len(new_trades)}")
    plot_histogram(new_trades)
    plot_total(new_trades)
# Out:
# Retrieved 45892 data points
# Trade Type: SELL
# Entry Time: 2023-07-15 23:23:00, Entry Price: 7513.015
# Exit Time: 2023-07-15 23:24:00, Exit Price: 7507.308
# Profit/Loss: 5.71
#
# Trade Type: SELL
# Entry Time: 2023-07-16 00:01:00, Entry Price: 7501.343
# Exit Time: 2023-07-16 00:02:00, Exit Price: 7490.44
# Profit/Loss: 10.90
#
# Trade Type: SELL
# Entry Time: 2023-07-16 00:56:00, Entry Price: 7513.414
# Exit Time: 2023-07-16 00:57:00, Exit Price: 7505.458
# Profit/Loss: 7.96
#
# Trade Type: SELL
# Entry Time: 2023-07-16 01:29:00, Entry Price: 7518.542
# Exit Time: 2023-07-16 01:30:00, Exit Price: 7516.448
# Profit/Loss: 2.09
#
# Trade Type: SELL
# Entry Time: 2023-07-16 02:15:00, Entry Price: 7536.189
# Exit Time: 2023-07-16 02:16:00, Exit Price: 7519.415
# Profit/Loss: 16.77
#
# Trade Type: SELL
# Entry Time: 2023-07-16 03:17:00, Entry Price: 7546.676
# Exit Time: 2023-07-16 03:18:00, Exit Price: 7537.307
# Profit/Loss: 9.37
#
# Trade Type: SELL
# Entry Time: 2023-07-16 04:12:00, Entry Price: 7515.156
# Exit Time: 2023-07-16 04:13:00, Exit Price: 7511.492
# Profit/Loss: 3.66
#
# Trade Type: SELL
# Entry Time: 2023-07-16 04:41:00, Entry Price: 7523.955
# Exit Time: 2023-07-16 04:42:00, Exit Price: 7510.792
# Profit/Loss: 13.16
#
# Trade Type: SELL
# Entry Time: 2023-07-16 05:00:00, Entry Price: 7518.526
# Exit Time: 2023-07-16 05:01:00, Exit Price: 7511.821
# Profit/Loss: 6.70
#
# Trade Type: SELL
# Entry Time: 2023-07-16 06:20:00, Entry Price: 7546.16
# Exit Time: 2023-07-16 06:21:00, Exit Price: 7542.35
# Profit/Loss: 3.81
#
# Trade Type: SELL
# Entry Time: 2023-07-16 07:06:00, Entry Price: 7540.241
# Exit Time: 2023-07-16 07:07:00, Exit Price: 7530.709
# Profit/Loss: 9.53
#
# Trade Type: SELL
# Entry Time: 2023-07-16 07:51:00, Entry Price: 7523.162
# Exit Time: 2023-07-16 07:52:00, Exit Price: 7520.174
# Profit/Loss: 2.99
#
# Trade Type: SELL
# Entry Time: 2023-07-16 08:33:00, Entry Price: 7529.392
# Exit Time: 2023-07-16 08:34:00, Exit Price: 7525.0
# Profit/Loss: 4.39
#
# Trade Type: SELL
# Entry Time: 2023-07-16 09:08:00, Entry Price: 7522.322
# Exit Time: 2023-07-16 09:09:00, Exit Price: 7509.535
# Profit/Loss: 12.79
#
# Trade Type: SELL
# Entry Time: 2023-07-16 10:24:00, Entry Price: 7539.418
# Exit Time: 2023-07-16 10:25:00, Exit Price: 7525.658
# Profit/Loss: 13.76
#
# Trade Type: SELL
# Entry Time: 2023-07-16 11:03:00, Entry Price: 7542.765
# Exit Time: 2023-07-16 11:04:00, Exit Price: 7524.685
# Profit/Loss: 18.08
#
# Trade Type: SELL
# Entry Time: 2023-07-16 11:33:00, Entry Price: 7537.429
# Exit Time: 2023-07-16 11:34:00, Exit Price: 7524.101
# Profit/Loss: 13.33
#
# Trade Type: SELL
# Entry Time: 2023-07-16 12:20:00, Entry Price: 7544.096
# Exit Time: 2023-07-16 12:21:00, Exit Price: 7540.16
# Profit/Loss: 3.94
#
# Trade Type: SELL
# Entry Time: 2023-07-16 13:00:00, Entry Price: 7523.062
# Exit Time: 2023-07-16 13:01:00, Exit Price: 7521.437
# Profit/Loss: 1.62
#
# Trade Type: SELL
# Entry Time: 2023-07-16 14:08:00, Entry Price: 7487.354
# Exit Time: 2023-07-16 14:09:00, Exit Price: 7484.876
# Profit/Loss: 2.48
#
# Trade Type: SELL
# Entry Time: 2023-07-16 14:21:00, Entry Price: 7489.778
# Exit Time: 2023-07-16 14:22:00, Exit Price: 7482.338
# Profit/Loss: 7.44
#
# Trade Type: SELL
# Entry Time: 2023-07-16 15:15:00, Entry Price: 7502.191
# Exit Time: 2023-07-16 15:16:00, Exit Price: 7500.223
# Profit/Loss: 1.97
#
# Trade Type: SELL
# Entry Time: 2023-07-16 15:29:00, Entry Price: 7505.674
# Exit Time: 2023-07-16 15:30:00, Exit Price: 7497.74
# Profit/Loss: 7.93
#
# Trade Type: SELL
# Entry Time: 2023-07-16 15:56:00, Entry Price: 7509.159
# Exit Time: 2023-07-16 15:57:00, Exit Price: 7501.44
# Profit/Loss: 7.72
#
# Trade Type: SELL
# Entry Time: 2023-07-16 16:15:00, Entry Price: 7509.237
# Exit Time: 2023-07-16 16:16:00, Exit Price: 7500.842
# Profit/Loss: 8.40
#
# Trade Type: SELL
# Entry Time: 2023-07-16 16:48:00, Entry Price: 7490.54
# Exit Time: 2023-07-16 16:49:00, Exit Price: 7478.502
# Profit/Loss: 12.04
#
# Trade Type: SELL
# Entry Time: 2023-07-16 17:23:00, Entry Price: 7493.005
# Exit Time: 2023-07-16 17:24:00, Exit Price: 7484.996
# Profit/Loss: 8.01
#
# Trade Type: SELL
# Entry Time: 2023-07-16 18:02:00, Entry Price: 7493.314
# Exit Time: 2023-07-16 18:03:00, Exit Price: 7486.3
# Profit/Loss: 7.01
#
# Trade Type: SELL
# Entry Time: 2023-07-16 18:29:00, Entry Price: 7493.601
# Exit Time: 2023-07-16 18:30:00, Exit Price: 7485.676
# Profit/Loss: 7.92
#
# Trade Type: SELL
# Entry Time: 2023-07-16 18:48:00, Entry Price: 7490.217
# Exit Time: 2023-07-16 18:49:00, Exit Price: 7480.864
# Profit/Loss: 9.35
#
# Trade Type: SELL
# Entry Time: 2023-07-16 19:04:00, Entry Price: 7487.285
# Exit Time: 2023-07-16 19:05:00, Exit Price: 7480.76
# Profit/Loss: 6.52
#
# Trade Type: SELL
# Entry Time: 2023-07-16 19:44:00, Entry Price: 7483.476
# Exit Time: 2023-07-16 19:45:00, Exit Price: 7464.631
# Profit/Loss: 18.84
#
# Trade Type: SELL
# Entry Time: 2023-07-16 20:13:00, Entry Price: 7473.579
# Exit Time: 2023-07-16 20:14:00, Exit Price: 7462.672
# Profit/Loss: 10.91
#
# Trade Type: SELL
# Entry Time: 2023-07-16 20:52:00, Entry Price: 7478.642
# Exit Time: 2023-07-16 20:53:00, Exit Price: 7472.232
# Profit/Loss: 6.41
#
# Trade Type: SELL
# Entry Time: 2023-07-16 22:12:00, Entry Price: 7407.698
# Exit Time: 2023-07-16 22:13:00, Exit Price: 7395.582
# Profit/Loss: 12.12
#
# Trade Type: SELL
# Entry Time: 2023-07-16 23:13:00, Entry Price: 7419.567
# Exit Time: 2023-07-16 23:14:00, Exit Price: 7412.267
# Profit/Loss: 7.30
#
# Trade Type: SELL
# Entry Time: 2023-07-16 23:28:00, Entry Price: 7418.213
# Exit Time: 2023-07-16 23:29:00, Exit Price: 7409.191
# Profit/Loss: 9.02
#
# Trade Type: SELL
# Entry Time: 2023-07-16 23:56:00, Entry Price: 7415.651
# Exit Time: 2023-07-16 23:57:00, Exit Price: 7404.34
# Profit/Loss: 11.31
#
# Trade Type: SELL
# Entry Time: 2023-07-17 00:19:00, Entry Price: 7413.479
# Exit Time: 2023-07-17 00:20:00, Exit Price: 7394.062
# Profit/Loss: 19.42
#
# Trade Type: SELL
# Entry Time: 2023-07-17 01:54:00, Entry Price: 7435.462
# Exit Time: 2023-07-17 01:55:00, Exit Price: 7430.437
# Profit/Loss: 5.03
#
# Trade Type: SELL
# Entry Time: 2023-07-17 02:54:00, Entry Price: 7438.487
# Exit Time: 2023-07-17 02:55:00, Exit Price: 7436.053
# Profit/Loss: 2.43
#
# Trade Type: SELL
# Entry Time: 2023-07-17 03:23:00, Entry Price: 7448.224
# Exit Time: 2023-07-17 03:24:00, Exit Price: 7445.372
# Profit/Loss: 2.85
#
# Trade Type: SELL
# Entry Time: 2023-07-17 03:41:00, Entry Price: 7443.48
# Exit Time: 2023-07-17 03:42:00, Exit Price: 7437.51
# Profit/Loss: 5.97
#
# Trade Type: SELL
# Entry Time: 2023-07-17 03:56:00, Entry Price: 7443.551
# Exit Time: 2023-07-17 03:57:00, Exit Price: 7439.833
# Profit/Loss: 3.72
#
# Trade Type: SELL
# Entry Time: 2023-07-17 04:17:00, Entry Price: 7448.463
# Exit Time: 2023-07-17 04:18:00, Exit Price: 7437.997
# Profit/Loss: 10.47
#
# Trade Type: SELL
# Entry Time: 2023-07-17 05:38:00, Entry Price: 7443.932
# Exit Time: 2023-07-17 05:39:00, Exit Price: 7435.161
# Profit/Loss: 8.77
#
# Trade Type: SELL
# Entry Time: 2023-07-17 06:35:00, Entry Price: 7451.631
# Exit Time: 2023-07-17 06:36:00, Exit Price: 7437.804
# Profit/Loss: 13.83
#
# Trade Type: SELL
# Entry Time: 2023-07-17 07:23:00, Entry Price: 7458.23
# Exit Time: 2023-07-17 07:24:00, Exit Price: 7441.877
# Profit/Loss: 16.35
#
# Trade Type: SELL
# Entry Time: 2023-07-17 08:04:00, Entry Price: 7458.897
# Exit Time: 2023-07-17 08:05:00, Exit Price: 7449.295
# Profit/Loss: 9.60
#
# Trade Type: SELL
# Entry Time: 2023-07-17 08:51:00, Entry Price: 7467.925
# Exit Time: 2023-07-17 08:52:00, Exit Price: 7465.156
# Profit/Loss: 2.77
#
# Trade Type: SELL
# Entry Time: 2023-07-17 09:20:00, Entry Price: 7469.357
# Exit Time: 2023-07-17 09:21:00, Exit Price: 7463.984
# Profit/Loss: 5.37
#
# Trade Type: SELL
# Entry Time: 2023-07-17 09:52:00, Entry Price: 7465.759
# Exit Time: 2023-07-17 09:53:00, Exit Price: 7460.447
# Profit/Loss: 5.31
#
# Trade Type: SELL
# Entry Time: 2023-07-17 10:14:00, Entry Price: 7459.494
# Exit Time: 2023-07-17 10:15:00, Exit Price: 7448.541
# Profit/Loss: 10.95
#
# Trade Type: SELL
# Entry Time: 2023-07-17 11:17:00, Entry Price: 7444.492
# Exit Time: 2023-07-17 11:18:00, Exit Price: 7442.424
# Profit/Loss: 2.07
#
# Trade Type: SELL
# Entry Time: 2023-07-17 12:42:00, Entry Price: 7469.176
# Exit Time: 2023-07-17 12:43:00, Exit Price: 7461.946
# Profit/Loss: 7.23
#
# Trade Type: SELL
# Entry Time: 2023-07-17 13:17:00, Entry Price: 7475.83
# Exit Time: 2023-07-17 13:18:00, Exit Price: 7472.982
# Profit/Loss: 2.85
#
# Trade Type: SELL
# Entry Time: 2023-07-17 14:06:00, Entry Price: 7447.172
# Exit Time: 2023-07-17 14:07:00, Exit Price: 7446.694
# Profit/Loss: 0.48
#
# Trade Type: SELL
# Entry Time: 2023-07-17 14:19:00, Entry Price: 7451.596
# Exit Time: 2023-07-17 14:20:00, Exit Price: 7437.678
# Profit/Loss: 13.92
#
# Trade Type: SELL
# Entry Time: 2023-07-17 14:49:00, Entry Price: 7439.423
# Exit Time: 2023-07-17 14:50:00, Exit Price: 7437.953
# Profit/Loss: 1.47
#
# Trade Type: SELL
# Entry Time: 2023-07-17 14:56:00, Entry Price: 7440.263
# Exit Time: 2023-07-17 14:57:00, Exit Price: 7434.992
# Profit/Loss: 5.27
#
# Trade Type: SELL
# Entry Time: 2023-07-17 15:42:00, Entry Price: 7453.555
# Exit Time: 2023-07-17 15:43:00, Exit Price: 7450.94
# Profit/Loss: 2.62
#
# Trade Type: SELL
# Entry Time: 2023-07-17 16:04:00, Entry Price: 7459.902
# Exit Time: 2023-07-17 16:05:00, Exit Price: 7458.265
# Profit/Loss: 1.64
#
# Trade Type: SELL
# Entry Time: 2023-07-17 16:10:00, Entry Price: 7460.095
# Exit Time: 2023-07-17 16:11:00, Exit Price: 7446.284
# Profit/Loss: 13.81
#
# Trade Type: SELL
# Entry Time: 2023-07-17 16:31:00, Entry Price: 7455.158
# Exit Time: 2023-07-17 16:32:00, Exit Price: 7452.505
# Profit/Loss: 2.65
#
# Trade Type: SELL
# Entry Time: 2023-07-17 16:58:00, Entry Price: 7463.726
# Exit Time: 2023-07-17 16:59:00, Exit Price: 7452.941
# Profit/Loss: 10.78
#
# Trade Type: SELL
# Entry Time: 2023-07-17 17:21:00, Entry Price: 7462.444
# Exit Time: 2023-07-17 17:22:00, Exit Price: 7456.46
# Profit/Loss: 5.98
#
# Trade Type: SELL
# Entry Time: 2023-07-17 17:57:00, Entry Price: 7471.503
# Exit Time: 2023-07-17 17:58:00, Exit Price: 7469.0
# Profit/Loss: 2.50
#
# Trade Type: SELL
# Entry Time: 2023-07-17 19:01:00, Entry Price: 7461.916
# Exit Time: 2023-07-17 19:02:00, Exit Price: 7439.191
# Profit/Loss: 22.73
#
# Trade Type: SELL
# Entry Time: 2023-07-17 19:51:00, Entry Price: 7460.575
# Exit Time: 2023-07-17 19:52:00, Exit Price: 7453.787
# Profit/Loss: 6.79
#
# Trade Type: SELL
# Entry Time: 2023-07-17 20:27:00, Entry Price: 7469.589
# Exit Time: 2023-07-17 20:28:00, Exit Price: 7460.905
# Profit/Loss: 8.68
#
# Trade Type: SELL
# Entry Time: 2023-07-17 21:13:00, Entry Price: 7457.614
# Exit Time: 2023-07-17 21:14:00, Exit Price: 7441.059
# Profit/Loss: 16.55
#
# Trade Type: SELL
# Entry Time: 2023-07-17 21:57:00, Entry Price: 7451.373
# Exit Time: 2023-07-17 21:58:00, Exit Price: 7448.515
# Profit/Loss: 2.86
#
# Trade Type: SELL
# Entry Time: 2023-07-17 22:12:00, Entry Price: 7454.226
# Exit Time: 2023-07-17 22:13:00, Exit Price: 7451.978
# Profit/Loss: 2.25
#
# Trade Type: SELL
# Entry Time: 2023-07-17 22:50:00, Entry Price: 7467.968
# Exit Time: 2023-07-17 22:51:00, Exit Price: 7464.286
# Profit/Loss: 3.68
#
# Trade Type: SELL
# Entry Time: 2023-07-17 23:08:00, Entry Price: 7471.603
# Exit Time: 2023-07-17 23:09:00, Exit Price: 7464.065
# Profit/Loss: 7.54
#
# Trade Type: SELL
# Entry Time: 2023-07-17 23:21:00, Entry Price: 7469.178
# Exit Time: 2023-07-17 23:22:00, Exit Price: 7463.002
# Profit/Loss: 6.18
#
# Trade Type: SELL
# Entry Time: 2023-07-17 23:53:00, Entry Price: 7460.333
# Exit Time: 2023-07-17 23:54:00, Exit Price: 7448.718
# Profit/Loss: 11.61
#
# Trade Type: SELL
# Entry Time: 2023-07-18 00:26:00, Entry Price: 7449.826
# Exit Time: 2023-07-18 00:27:00, Exit Price: 7448.78
# Profit/Loss: 1.05
#
# Trade Type: SELL
# Entry Time: 2023-07-18 01:47:00, Entry Price: 7481.659
# Exit Time: 2023-07-18 01:48:00, Exit Price: 7467.359
# Profit/Loss: 14.30
#
# Trade Type: SELL
# Entry Time: 2023-07-18 02:22:00, Entry Price: 7481.766
# Exit Time: 2023-07-18 02:23:00, Exit Price: 7466.984
# Profit/Loss: 14.78
#
# Trade Type: SELL
# Entry Time: 2023-07-18 02:52:00, Entry Price: 7471.035
# Exit Time: 2023-07-18 02:53:00, Exit Price: 7457.149
# Profit/Loss: 13.89
#
# Trade Type: SELL
# Entry Time: 2023-07-18 03:17:00, Entry Price: 7467.322
# Exit Time: 2023-07-18 03:18:00, Exit Price: 7452.197
# Profit/Loss: 15.12
#
# Trade Type: SELL
# Entry Time: 2023-07-18 04:29:00, Entry Price: 7459.947
# Exit Time: 2023-07-18 04:30:00, Exit Price: 7450.255
# Profit/Loss: 9.69
#
# Trade Type: SELL
# Entry Time: 2023-07-18 05:09:00, Entry Price: 7434.768
# Exit Time: 2023-07-18 05:10:00, Exit Price: 7428.735
# Profit/Loss: 6.03
#
# Trade Type: SELL
# Entry Time: 2023-07-18 05:30:00, Entry Price: 7437.419
# Exit Time: 2023-07-18 05:31:00, Exit Price: 7426.556
# Profit/Loss: 10.86
#
# Trade Type: SELL
# Entry Time: 2023-07-18 05:53:00, Entry Price: 7435.975
# Exit Time: 2023-07-18 05:54:00, Exit Price: 7426.131
# Profit/Loss: 9.84
#
# Trade Type: SELL
# Entry Time: 2023-07-18 06:18:00, Entry Price: 7435.971
# Exit Time: 2023-07-18 06:19:00, Exit Price: 7429.267
# Profit/Loss: 6.70
#
# Trade Type: SELL
# Entry Time: 2023-07-18 06:38:00, Entry Price: 7434.043
# Exit Time: 2023-07-18 06:39:00, Exit Price: 7426.327
# Profit/Loss: 7.72
#
# Trade Type: SELL
# Entry Time: 2023-07-18 07:15:00, Entry Price: 7442.058
# Exit Time: 2023-07-18 07:16:00, Exit Price: 7436.974
# Profit/Loss: 5.08
#
# Trade Type: SELL
# Entry Time: 2023-07-18 07:59:00, Entry Price: 7420.085
# Exit Time: 2023-07-18 08:00:00, Exit Price: 7403.82
# Profit/Loss: 16.27
#
# Trade Type: SELL
# Entry Time: 2023-07-18 08:18:00, Entry Price: 7411.595
# Exit Time: 2023-07-18 08:19:00, Exit Price: 7406.891
# Profit/Loss: 4.70
#
# Trade Type: SELL
# Entry Time: 2023-07-18 08:38:00, Entry Price: 7414.788
# Exit Time: 2023-07-18 08:39:00, Exit Price: 7402.137
# Profit/Loss: 12.65
#
# Trade Type: SELL
# Entry Time: 2023-07-18 09:03:00, Entry Price: 7411.295
# Exit Time: 2023-07-18 09:04:00, Exit Price: 7399.226
# Profit/Loss: 12.07
#
# Trade Type: SELL
# Entry Time: 2023-07-18 10:57:00, Entry Price: 7437.792
# Exit Time: 2023-07-18 10:58:00, Exit Price: 7434.44
# Profit/Loss: 3.35
#
# Trade Type: SELL
# Entry Time: 2023-07-18 11:21:00, Entry Price: 7443.624
# Exit Time: 2023-07-18 11:22:00, Exit Price: 7433.672
# Profit/Loss: 9.95
#
# Trade Type: SELL
# Entry Time: 2023-07-18 12:01:00, Entry Price: 7441.086
# Exit Time: 2023-07-18 12:02:00, Exit Price: 7436.496
# Profit/Loss: 4.59
#
# Trade Type: SELL
# Entry Time: 2023-07-18 12:12:00, Entry Price: 7440.328
# Exit Time: 2023-07-18 12:13:00, Exit Price: 7421.95
# Profit/Loss: 18.38
#
# Trade Type: SELL
# Entry Time: 2023-07-18 12:32:00, Entry Price: 7430.247
# Exit Time: 2023-07-18 12:33:00, Exit Price: 7415.975
# Profit/Loss: 14.27
#
# Trade Type: SELL
# Entry Time: 2023-07-18 12:52:00, Entry Price: 7417.973
# Exit Time: 2023-07-18 12:53:00, Exit Price: 7403.944
# Profit/Loss: 14.03
#
# Trade Type: SELL
# Entry Time: 2023-07-18 13:16:00, Entry Price: 7409.825
# Exit Time: 2023-07-18 13:17:00, Exit Price: 7389.319
# Profit/Loss: 20.51
#
# Trade Type: SELL
# Entry Time: 2023-07-18 13:36:00, Entry Price: 7397.525
# Exit Time: 2023-07-18 13:37:00, Exit Price: 7388.536
# Profit/Loss: 8.99
#
# Trade Type: SELL
# Entry Time: 2023-07-18 14:33:00, Entry Price: 7406.024
# Exit Time: 2023-07-18 14:34:00, Exit Price: 7403.138
# Profit/Loss: 2.89
#
# Trade Type: SELL
# Entry Time: 2023-07-18 14:42:00, Entry Price: 7406.103
# Exit Time: 2023-07-18 14:43:00, Exit Price: 7399.168
# Profit/Loss: 6.94
#
# Trade Type: SELL
# Entry Time: 2023-07-18 15:20:00, Entry Price: 7408.085
# Exit Time: 2023-07-18 15:21:00, Exit Price: 7406.187
# Profit/Loss: 1.90
#
# Trade Type: SELL
# Entry Time: 2023-07-18 15:55:00, Entry Price: 7420.51
# Exit Time: 2023-07-18 15:56:00, Exit Price: 7413.188
# Profit/Loss: 7.32
#
# Trade Type: SELL
# Entry Time: 2023-07-18 16:24:00, Entry Price: 7423.426
# Exit Time: 2023-07-18 16:25:00, Exit Price: 7416.582
# Profit/Loss: 6.84
#
# Trade Type: SELL
# Entry Time: 2023-07-18 17:13:00, Entry Price: 7437.397
# Exit Time: 2023-07-18 17:14:00, Exit Price: 7430.268
# Profit/Loss: 7.13
#
# Trade Type: SELL
# Entry Time: 2023-07-18 17:55:00, Entry Price: 7433.048
# Exit Time: 2023-07-18 17:56:00, Exit Price: 7432.345
# Profit/Loss: 0.70
#
# Trade Type: SELL
# Entry Time: 2023-07-18 18:07:00, Entry Price: 7436.889
# Exit Time: 2023-07-18 18:08:00, Exit Price: 7425.381
# Profit/Loss: 11.51
#
# Trade Type: SELL
# Entry Time: 2023-07-18 18:35:00, Entry Price: 7433.004
# Exit Time: 2023-07-18 18:36:00, Exit Price: 7428.671
# Profit/Loss: 4.33
#
# Trade Type: SELL
# Entry Time: 2023-07-18 19:24:00, Entry Price: 7449.42
# Exit Time: 2023-07-18 19:25:00, Exit Price: 7440.224
# Profit/Loss: 9.20
#
# Trade Type: SELL
# Entry Time: 2023-07-18 20:04:00, Entry Price: 7457.345
# Exit Time: 2023-07-18 20:05:00, Exit Price: 7447.535
# Profit/Loss: 9.81
#
# Trade Type: SELL
# Entry Time: 2023-07-18 20:36:00, Entry Price: 7460.843
# Exit Time: 2023-07-18 20:37:00, Exit Price: 7443.585
# Profit/Loss: 17.26
#
# Trade Type: SELL
# Entry Time: 2023-07-18 21:14:00, Entry Price: 7454.472
# Exit Time: 2023-07-18 21:15:00, Exit Price: 7451.589
# Profit/Loss: 2.88
#
# Trade Type: SELL
# Entry Time: 2023-07-18 21:29:00, Entry Price: 7457.357
# Exit Time: 2023-07-18 21:30:00, Exit Price: 7452.031
# Profit/Loss: 5.33
#
# Trade Type: SELL
# Entry Time: 2023-07-18 21:47:00, Entry Price: 7459.266
# Exit Time: 2023-07-18 21:48:00, Exit Price: 7447.449
# Profit/Loss: 11.82
#
# Trade Type: SELL
# Entry Time: 2023-07-18 22:35:00, Entry Price: 7459.003
# Exit Time: 2023-07-18 22:36:00, Exit Price: 7447.686
# Profit/Loss: 11.32
#
# Trade Type: SELL
# Entry Time: 2023-07-18 23:09:00, Entry Price: 7462.053
# Exit Time: 2023-07-18 23:10:00, Exit Price: 7447.391
# Profit/Loss: 14.66
#
# Trade Type: SELL
# Entry Time: 2023-07-18 23:42:00, Entry Price: 7446.676
# Exit Time: 2023-07-18 23:43:00, Exit Price: 7444.919
# Profit/Loss: 1.76
#
# Trade Type: SELL
# Entry Time: 2023-07-18 23:56:00, Entry Price: 7450.3
# Exit Time: 2023-07-18 23:57:00, Exit Price: 7446.026
# Profit/Loss: 4.27
#
# Trade Type: SELL
# Entry Time: 2023-07-19 00:24:00, Entry Price: 7457.664
# Exit Time: 2023-07-19 00:25:00, Exit Price: 7449.011
# Profit/Loss: 8.65
#
# Trade Type: SELL
# Entry Time: 2023-07-19 00:45:00, Entry Price: 7457.396
# Exit Time: 2023-07-19 00:46:00, Exit Price: 7447.347
# Profit/Loss: 10.05
#
# Trade Type: SELL
# Entry Time: 2023-07-19 01:09:00, Entry Price: 7457.254
# Exit Time: 2023-07-19 01:10:00, Exit Price: 7444.775
# Profit/Loss: 12.48
#
# Trade Type: SELL
# Entry Time: 2023-07-19 02:17:00, Entry Price: 7444.37
# Exit Time: 2023-07-19 02:18:00, Exit Price: 7439.36
# Profit/Loss: 5.01
#
# Trade Type: SELL
# Entry Time: 2023-07-19 02:49:00, Entry Price: 7453.005
# Exit Time: 2023-07-19 02:50:00, Exit Price: 7443.554
# Profit/Loss: 9.45
#
# Trade Type: SELL
# Entry Time: 2023-07-19 03:59:00, Entry Price: 7473.933
# Exit Time: 2023-07-19 04:00:00, Exit Price: 7464.573
# Profit/Loss: 9.36
#
# Trade Type: SELL
# Entry Time: 2023-07-19 04:40:00, Entry Price: 7467.804
# Exit Time: 2023-07-19 04:41:00, Exit Price: 7454.218
# Profit/Loss: 13.59
#
# Trade Type: SELL
# Entry Time: 2023-07-19 04:58:00, Entry Price: 7461.629
# Exit Time: 2023-07-19 04:59:00, Exit Price: 7455.015
# Profit/Loss: 6.61
#
# Trade Type: SELL
# Entry Time: 2023-07-19 05:17:00, Entry Price: 7462.64
# Exit Time: 2023-07-19 05:18:00, Exit Price: 7462.08
# Profit/Loss: 0.56
#
# Trade Type: SELL
# Entry Time: 2023-07-19 06:02:00, Entry Price: 7480.811
# Exit Time: 2023-07-19 06:03:00, Exit Price: 7479.027
# Profit/Loss: 1.78
#
# Trade Type: SELL
# Entry Time: 2023-07-19 06:10:00, Entry Price: 7481.661
# Exit Time: 2023-07-19 06:11:00, Exit Price: 7478.486
# Profit/Loss: 3.18
#
# Trade Type: SELL
# Entry Time: 2023-07-19 06:39:00, Entry Price: 7490.377
# Exit Time: 2023-07-19 06:40:00, Exit Price: 7484.845
# Profit/Loss: 5.53
#
# Trade Type: SELL
# Entry Time: 2023-07-19 07:15:00, Entry Price: 7500.362
# Exit Time: 2023-07-19 07:16:00, Exit Price: 7493.625
# Profit/Loss: 6.74
#
# Trade Type: SELL
# Entry Time: 2023-07-19 08:25:00, Entry Price: 7505.156
# Exit Time: 2023-07-19 08:26:00, Exit Price: 7503.093
# Profit/Loss: 2.06
#
# Trade Type: SELL
# Entry Time: 2023-07-19 08:38:00, Entry Price: 7508.465
# Exit Time: 2023-07-19 08:39:00, Exit Price: 7500.111
# Profit/Loss: 8.35
#
# Trade Type: SELL
# Entry Time: 2023-07-19 09:41:00, Entry Price: 7473.473
# Exit Time: 2023-07-19 09:42:00, Exit Price: 7455.942
# Profit/Loss: 17.53
#
# Trade Type: SELL
# Entry Time: 2023-07-19 10:47:00, Entry Price: 7468.241
# Exit Time: 2023-07-19 10:48:00, Exit Price: 7457.433
# Profit/Loss: 10.81
#
# Trade Type: SELL
# Entry Time: 2023-07-19 11:43:00, Entry Price: 7479.094
# Exit Time: 2023-07-19 11:44:00, Exit Price: 7477.112
# Profit/Loss: 1.98
#
# Trade Type: SELL
# Entry Time: 2023-07-19 11:59:00, Entry Price: 7483.117
# Exit Time: 2023-07-19 12:00:00, Exit Price: 7473.499
# Profit/Loss: 9.62
#
# Trade Type: SELL
# Entry Time: 2023-07-19 12:42:00, Entry Price: 7459.133
# Exit Time: 2023-07-19 12:43:00, Exit Price: 7458.834
# Profit/Loss: 0.30
#
# Trade Type: SELL
# Entry Time: 2023-07-19 13:40:00, Entry Price: 7483.869
# Exit Time: 2023-07-19 13:41:00, Exit Price: 7480.759
# Profit/Loss: 3.11
#
# Trade Type: SELL
# Entry Time: 2023-07-19 14:16:00, Entry Price: 7496.025
# Exit Time: 2023-07-19 14:17:00, Exit Price: 7482.538
# Profit/Loss: 13.49
#
# Trade Type: SELL
# Entry Time: 2023-07-19 15:07:00, Entry Price: 7500.47
# Exit Time: 2023-07-19 15:08:00, Exit Price: 7499.4
# Profit/Loss: 1.07
#
# Trade Type: SELL
# Entry Time: 2023-07-19 15:27:00, Entry Price: 7507.563
# Exit Time: 2023-07-19 15:28:00, Exit Price: 7504.969
# Profit/Loss: 2.59
#
# Trade Type: SELL
# Entry Time: 2023-07-19 15:40:00, Entry Price: 7510.175
# Exit Time: 2023-07-19 15:41:00, Exit Price: 7508.239
# Profit/Loss: 1.94
#
# Trade Type: SELL
# Entry Time: 2023-07-19 16:07:00, Entry Price: 7502.547
# Exit Time: 2023-07-19 16:08:00, Exit Price: 7492.541
# Profit/Loss: 10.01
#
# Trade Type: SELL
# Entry Time: 2023-07-19 16:42:00, Entry Price: 7497.384
# Exit Time: 2023-07-19 16:43:00, Exit Price: 7482.086
# Profit/Loss: 15.30
#
# Trade Type: SELL
# Entry Time: 2023-07-19 18:01:00, Entry Price: 7515.404
# Exit Time: 2023-07-19 18:02:00, Exit Price: 7512.029
# Profit/Loss: 3.38
#
# Trade Type: SELL
# Entry Time: 2023-07-19 18:10:00, Entry Price: 7515.298
# Exit Time: 2023-07-19 18:11:00, Exit Price: 7512.919
# Profit/Loss: 2.38
#
# Trade Type: SELL
# Entry Time: 2023-07-19 19:39:00, Entry Price: 7480.974
# Exit Time: 2023-07-19 19:40:00, Exit Price: 7479.078
# Profit/Loss: 1.90
#
# Trade Type: SELL
# Entry Time: 2023-07-19 19:56:00, Entry Price: 7485.77
# Exit Time: 2023-07-19 19:57:00, Exit Price: 7478.943
# Profit/Loss: 6.83
#
# Trade Type: SELL
# Entry Time: 2023-07-19 21:25:00, Entry Price: 7516.443
# Exit Time: 2023-07-19 21:26:00, Exit Price: 7507.145
# Profit/Loss: 9.30
#
# Trade Type: SELL
# Entry Time: 2023-07-19 22:12:00, Entry Price: 7512.099
# Exit Time: 2023-07-19 22:13:00, Exit Price: 7508.223
# Profit/Loss: 3.88
#
# Trade Type: SELL
# Entry Time: 2023-07-19 23:10:00, Entry Price: 7512.611
# Exit Time: 2023-07-19 23:11:00, Exit Price: 7485.482
# Profit/Loss: 27.13
#
# Trade Type: SELL
# Entry Time: 2023-07-19 23:52:00, Entry Price: 7503.161
# Exit Time: 2023-07-19 23:53:00, Exit Price: 7495.766
# Profit/Loss: 7.40
#
# Trade Type: SELL
# Entry Time: 2023-07-20 00:11:00, Entry Price: 7503.782
# Exit Time: 2023-07-20 00:12:00, Exit Price: 7501.944
# Profit/Loss: 1.84
#
# Trade Type: SELL
# Entry Time: 2023-07-20 00:56:00, Entry Price: 7520.745
# Exit Time: 2023-07-20 00:57:00, Exit Price: 7512.344
# Profit/Loss: 8.40
#
# Trade Type: SELL
# Entry Time: 2023-07-20 01:30:00, Entry Price: 7508.368
# Exit Time: 2023-07-20 01:31:00, Exit Price: 7500.311
# Profit/Loss: 8.06
#
# Trade Type: SELL
# Entry Time: 2023-07-20 02:34:00, Entry Price: 7442.94
# Exit Time: 2023-07-20 02:35:00, Exit Price: 7442.125
# Profit/Loss: 0.81
#
# Trade Type: SELL
# Entry Time: 2023-07-20 02:49:00, Entry Price: 7446.028
# Exit Time: 2023-07-20 02:50:00, Exit Price: 7436.487
# Profit/Loss: 9.54
#
# Trade Type: SELL
# Entry Time: 2023-07-20 03:07:00, Entry Price: 7443.64
# Exit Time: 2023-07-20 03:08:00, Exit Price: 7441.193
# Profit/Loss: 2.45
#
# Trade Type: SELL
# Entry Time: 2023-07-20 03:22:00, Entry Price: 7446.938
# Exit Time: 2023-07-20 03:23:00, Exit Price: 7446.308
# Profit/Loss: 0.63
#
# Trade Type: SELL
# Entry Time: 2023-07-20 03:29:00, Entry Price: 7448.528
# Exit Time: 2023-07-20 03:30:00, Exit Price: 7442.205
# Profit/Loss: 6.32
#
# Trade Type: SELL
# Entry Time: 2023-07-20 03:48:00, Entry Price: 7449.554
# Exit Time: 2023-07-20 03:49:00, Exit Price: 7445.379
# Profit/Loss: 4.18
#
# Trade Type: SELL
# Entry Time: 2023-07-20 04:13:00, Entry Price: 7453.775
# Exit Time: 2023-07-20 04:14:00, Exit Price: 7445.195
# Profit/Loss: 8.58
#
# Trade Type: SELL
# Entry Time: 2023-07-20 04:34:00, Entry Price: 7451.697
# Exit Time: 2023-07-20 04:35:00, Exit Price: 7451.303
# Profit/Loss: 0.39
#
# Trade Type: SELL
# Entry Time: 2023-07-20 04:38:00, Entry Price: 7452.236
# Exit Time: 2023-07-20 04:39:00, Exit Price: 7439.381
# Profit/Loss: 12.85
#
# Trade Type: SELL
# Entry Time: 2023-07-20 05:12:00, Entry Price: 7453.975
# Exit Time: 2023-07-20 05:13:00, Exit Price: 7452.06
# Profit/Loss: 1.91
#
# Trade Type: SELL
# Entry Time: 2023-07-20 05:25:00, Entry Price: 7456.841
# Exit Time: 2023-07-20 05:26:00, Exit Price: 7445.855
# Profit/Loss: 10.99
#
# Trade Type: SELL
# Entry Time: 2023-07-20 06:52:00, Entry Price: 7483.873
# Exit Time: 2023-07-20 06:53:00, Exit Price: 7481.196
# Profit/Loss: 2.68
#
# Trade Type: SELL
# Entry Time: 2023-07-20 08:22:00, Entry Price: 7505.023
# Exit Time: 2023-07-20 08:23:00, Exit Price: 7502.7
# Profit/Loss: 2.32
#
# Trade Type: SELL
# Entry Time: 2023-07-20 09:09:00, Entry Price: 7523.034
# Exit Time: 2023-07-20 09:10:00, Exit Price: 7520.341
# Profit/Loss: 2.69
#
# Trade Type: SELL
# Entry Time: 2023-07-20 09:25:00, Entry Price: 7525.765
# Exit Time: 2023-07-20 09:26:00, Exit Price: 7520.908
# Profit/Loss: 4.86
#
# Trade Type: SELL
# Entry Time: 2023-07-20 09:56:00, Entry Price: 7515.701
# Exit Time: 2023-07-20 09:57:00, Exit Price: 7508.974
# Profit/Loss: 6.73
#
# Trade Type: SELL
# Entry Time: 2023-07-20 11:26:00, Entry Price: 7548.095
# Exit Time: 2023-07-20 11:27:00, Exit Price: 7538.886
# Profit/Loss: 9.21
#
# Trade Type: SELL
# Entry Time: 2023-07-20 12:25:00, Entry Price: 7564.336
# Exit Time: 2023-07-20 12:26:00, Exit Price: 7553.462
# Profit/Loss: 10.87
#
# Trade Type: SELL
# Entry Time: 2023-07-20 12:51:00, Entry Price: 7564.413
# Exit Time: 2023-07-20 12:52:00, Exit Price: 7558.722
# Profit/Loss: 5.69
#
# Trade Type: SELL
# Entry Time: 2023-07-20 13:27:00, Entry Price: 7574.177
# Exit Time: 2023-07-20 13:28:00, Exit Price: 7565.795
# Profit/Loss: 8.38
#
# Trade Type: SELL
# Entry Time: 2023-07-20 13:54:00, Entry Price: 7577.425
# Exit Time: 2023-07-20 13:55:00, Exit Price: 7560.2
# Profit/Loss: 17.23
#
# Trade Type: SELL
# Entry Time: 2023-07-20 14:58:00, Entry Price: 7528.737
# Exit Time: 2023-07-20 14:59:00, Exit Price: 7525.052
# Profit/Loss: 3.69
#
# Trade Type: SELL
# Entry Time: 2023-07-20 15:26:00, Entry Price: 7537.208
# Exit Time: 2023-07-20 15:27:00, Exit Price: 7529.483
# Profit/Loss: 7.72
#
# Trade Type: SELL
# Entry Time: 2023-07-20 16:14:00, Entry Price: 7542.645
# Exit Time: 2023-07-20 16:15:00, Exit Price: 7533.514
# Profit/Loss: 9.13
#
# Trade Type: SELL
# Entry Time: 2023-07-20 16:30:00, Entry Price: 7540.076
# Exit Time: 2023-07-20 16:31:00, Exit Price: 7534.881
# Profit/Loss: 5.19
#
# Trade Type: SELL
# Entry Time: 2023-07-20 17:20:00, Entry Price: 7521.267
# Exit Time: 2023-07-20 17:21:00, Exit Price: 7511.653
# Profit/Loss: 9.61
#
# Trade Type: SELL
# Entry Time: 2023-07-20 17:52:00, Entry Price: 7516.554
# Exit Time: 2023-07-20 17:53:00, Exit Price: 7514.328
# Profit/Loss: 2.23
#
# Trade Type: SELL
# Entry Time: 2023-07-20 18:20:00, Entry Price: 7525.728
# Exit Time: 2023-07-20 18:21:00, Exit Price: 7510.136
# Profit/Loss: 15.59
#
# Trade Type: SELL
# Entry Time: 2023-07-20 19:32:00, Entry Price: 7523.783
# Exit Time: 2023-07-20 19:33:00, Exit Price: 7519.075
# Profit/Loss: 4.71
#
# Trade Type: SELL
# Entry Time: 2023-07-20 19:48:00, Entry Price: 7525.454
# Exit Time: 2023-07-20 19:49:00, Exit Price: 7519.649
# Profit/Loss: 5.80
#
# Trade Type: SELL
# Entry Time: 2023-07-20 20:20:00, Entry Price: 7522.446
# Exit Time: 2023-07-20 20:21:00, Exit Price: 7511.287
# Profit/Loss: 11.16
#
# Trade Type: SELL
# Entry Time: 2023-07-20 20:39:00, Entry Price: 7518.734
# Exit Time: 2023-07-20 20:40:00, Exit Price: 7511.418
# Profit/Loss: 7.32
#
# Trade Type: SELL
# Entry Time: 2023-07-20 21:10:00, Entry Price: 7524.635
# Exit Time: 2023-07-20 21:11:00, Exit Price: 7518.597
# Profit/Loss: 6.04
#
# Trade Type: SELL
# Entry Time: 2023-07-20 22:03:00, Entry Price: 7541.238
# Exit Time: 2023-07-20 22:04:00, Exit Price: 7532.86
# Profit/Loss: 8.38
#
# Trade Type: SELL
# Entry Time: 2023-07-20 23:19:00, Entry Price: 7565.142
# Exit Time: 2023-07-20 23:20:00, Exit Price: 7559.329
# Profit/Loss: 5.81
#
# Trade Type: SELL
# Entry Time: 2023-07-20 23:32:00, Entry Price: 7564.367
# Exit Time: 2023-07-20 23:33:00, Exit Price: 7561.5
# Profit/Loss: 2.87
#
# Trade Type: SELL
# Entry Time: 2023-07-21 00:04:00, Entry Price: 7574.577
# Exit Time: 2023-07-21 00:05:00, Exit Price: 7561.286
# Profit/Loss: 13.29
#
# Trade Type: SELL
# Entry Time: 2023-07-21 01:12:00, Entry Price: 7557.536
# Exit Time: 2023-07-21 01:13:00, Exit Price: 7552.559
# Profit/Loss: 4.98
#
# Trade Type: SELL
# Entry Time: 2023-07-21 01:44:00, Entry Price: 7566.529
# Exit Time: 2023-07-21 01:45:00, Exit Price: 7563.967
# Profit/Loss: 2.56
#
# Trade Type: SELL
# Entry Time: 2023-07-21 02:52:00, Entry Price: 7593.919
# Exit Time: 2023-07-21 02:53:00, Exit Price: 7582.582
# Profit/Loss: 11.34
#
# Trade Type: SELL
# Entry Time: 2023-07-21 03:40:00, Entry Price: 7585.279
# Exit Time: 2023-07-21 03:41:00, Exit Price: 7577.916
# Profit/Loss: 7.36
#
# Trade Type: SELL
# Entry Time: 2023-07-21 04:36:00, Entry Price: 7596.169
# Exit Time: 2023-07-21 04:37:00, Exit Price: 7588.246
# Profit/Loss: 7.92
#
# Trade Type: SELL
# Entry Time: 2023-07-21 05:12:00, Entry Price: 7602.87
# Exit Time: 2023-07-21 05:13:00, Exit Price: 7595.389
# Profit/Loss: 7.48
#
# Trade Type: SELL
# Entry Time: 2023-07-21 06:10:00, Entry Price: 7594.139
# Exit Time: 2023-07-21 06:11:00, Exit Price: 7585.024
# Profit/Loss: 9.11
#
# Trade Type: SELL
# Entry Time: 2023-07-21 06:35:00, Entry Price: 7595.513
# Exit Time: 2023-07-21 06:36:00, Exit Price: 7589.609
# Profit/Loss: 5.90
#
# Trade Type: SELL
# Entry Time: 2023-07-21 07:10:00, Entry Price: 7589.12
# Exit Time: 2023-07-21 07:11:00, Exit Price: 7580.194
# Profit/Loss: 8.93
#
# Trade Type: SELL
# Entry Time: 2023-07-21 07:35:00, Entry Price: 7590.828
# Exit Time: 2023-07-21 07:36:00, Exit Price: 7585.74
# Profit/Loss: 5.09
#
# Trade Type: SELL
# Entry Time: 2023-07-21 08:08:00, Entry Price: 7599.799
# Exit Time: 2023-07-21 08:09:00, Exit Price: 7588.909
# Profit/Loss: 10.89
#
# Trade Type: SELL
# Entry Time: 2023-07-21 08:24:00, Entry Price: 7595.079
# Exit Time: 2023-07-21 08:25:00, Exit Price: 7584.858
# Profit/Loss: 10.22
#
# Trade Type: SELL
# Entry Time: 2023-07-21 09:15:00, Entry Price: 7581.551
# Exit Time: 2023-07-21 09:16:00, Exit Price: 7571.759
# Profit/Loss: 9.79
#
# Trade Type: SELL
# Entry Time: 2023-07-21 09:54:00, Entry Price: 7573.368
# Exit Time: 2023-07-21 09:55:00, Exit Price: 7556.715
# Profit/Loss: 16.65
#
# Trade Type: SELL
# Entry Time: 2023-07-21 10:35:00, Entry Price: 7574.74
# Exit Time: 2023-07-21 10:36:00, Exit Price: 7565.549
# Profit/Loss: 9.19
#
# Trade Type: SELL
# Entry Time: 2023-07-21 10:53:00, Entry Price: 7572.809
# Exit Time: 2023-07-21 10:54:00, Exit Price: 7561.019
# Profit/Loss: 11.79
#
# Trade Type: SELL
# Entry Time: 2023-07-21 11:10:00, Entry Price: 7568.039
# Exit Time: 2023-07-21 11:11:00, Exit Price: 7561.549
# Profit/Loss: 6.49
#
# Trade Type: SELL
# Entry Time: 2023-07-21 11:26:00, Entry Price: 7567.767
# Exit Time: 2023-07-21 11:27:00, Exit Price: 7565.045
# Profit/Loss: 2.72
#
# Trade Type: SELL
# Entry Time: 2023-07-21 11:35:00, Entry Price: 7568.148
# Exit Time: 2023-07-21 11:36:00, Exit Price: 7561.517
# Profit/Loss: 6.63
#
# Trade Type: SELL
# Entry Time: 2023-07-21 12:49:00, Entry Price: 7594.289
# Exit Time: 2023-07-21 12:50:00, Exit Price: 7590.187
# Profit/Loss: 4.10
#
# Trade Type: SELL
# Entry Time: 2023-07-21 13:20:00, Entry Price: 7603.703
# Exit Time: 2023-07-21 13:21:00, Exit Price: 7597.179
# Profit/Loss: 6.52
#
# Trade Type: SELL
# Entry Time: 2023-07-21 14:12:00, Entry Price: 7613.385
# Exit Time: 2023-07-21 14:13:00, Exit Price: 7606.739
# Profit/Loss: 6.65
#
# Trade Type: SELL
# Entry Time: 2023-07-21 14:29:00, Entry Price: 7613.615
# Exit Time: 2023-07-21 14:30:00, Exit Price: 7601.915
# Profit/Loss: 11.70
#
# Trade Type: SELL
# Entry Time: 2023-07-21 15:31:00, Entry Price: 7592.727
# Exit Time: 2023-07-21 15:32:00, Exit Price: 7593.72
# Profit/Loss: -0.99
#
# Trade Type: SELL
# Entry Time: 2023-07-21 15:54:00, Entry Price: 7603.509
# Exit Time: 2023-07-21 15:55:00, Exit Price: 7599.988
# Profit/Loss: 3.52
#
# Trade Type: SELL
# Entry Time: 2023-07-21 16:10:00, Entry Price: 7606.767
# Exit Time: 2023-07-21 16:11:00, Exit Price: 7582.615
# Profit/Loss: 24.15
#
# Trade Type: SELL
# Entry Time: 2023-07-21 17:11:00, Entry Price: 7590.885
# Exit Time: 2023-07-21 17:12:00, Exit Price: 7589.618
# Profit/Loss: 1.27
#
# Trade Type: SELL
# Entry Time: 2023-07-21 17:39:00, Entry Price: 7601.195
# Exit Time: 2023-07-21 17:40:00, Exit Price: 7587.506
# Profit/Loss: 13.69
#
# Trade Type: SELL
# Entry Time: 2023-07-21 18:42:00, Entry Price: 7614.467
# Exit Time: 2023-07-21 18:43:00, Exit Price: 7608.37
# Profit/Loss: 6.10
#
# Trade Type: SELL
# Entry Time: 2023-07-21 19:20:00, Entry Price: 7601.857
# Exit Time: 2023-07-21 19:21:00, Exit Price: 7584.839
# Profit/Loss: 17.02
#
# Trade Type: SELL
# Entry Time: 2023-07-21 20:46:00, Entry Price: 7601.182
# Exit Time: 2023-07-21 20:47:00, Exit Price: 7602.08
# Profit/Loss: -0.90
#
# Trade Type: SELL
# Entry Time: 2023-07-21 21:46:00, Entry Price: 7592.267
# Exit Time: 2023-07-21 21:47:00, Exit Price: 7587.172
# Profit/Loss: 5.10
#
# Trade Type: SELL
# Entry Time: 2023-07-21 22:36:00, Entry Price: 7562.612
# Exit Time: 2023-07-21 22:37:00, Exit Price: 7559.955
# Profit/Loss: 2.66
#
# Trade Type: SELL
# Entry Time: 2023-07-21 22:50:00, Entry Price: 7565.379
# Exit Time: 2023-07-21 22:51:00, Exit Price: 7554.542
# Profit/Loss: 10.84
#
# Trade Type: SELL
# Entry Time: 2023-07-21 23:39:00, Entry Price: 7570.555
# Exit Time: 2023-07-21 23:40:00, Exit Price: 7550.535
# Profit/Loss: 20.02
#
# Trade Type: SELL
# Entry Time: 2023-07-22 00:03:00, Entry Price: 7559.434
# Exit Time: 2023-07-22 00:04:00, Exit Price: 7545.521
# Profit/Loss: 13.91
#
# Trade Type: SELL
# Entry Time: 2023-07-22 00:35:00, Entry Price: 7546.569
# Exit Time: 2023-07-22 00:36:00, Exit Price: 7537.286
# Profit/Loss: 9.28
#
# Trade Type: SELL
# Entry Time: 2023-07-22 01:45:00, Entry Price: 7548.445
# Exit Time: 2023-07-22 01:46:00, Exit Price: 7534.99
# Profit/Loss: 13.45
#
# Trade Type: SELL
# Entry Time: 2023-07-22 02:47:00, Entry Price: 7504.821
# Exit Time: 2023-07-22 02:48:00, Exit Price: 7499.744
# Profit/Loss: 5.08
#
# Trade Type: SELL
# Entry Time: 2023-07-22 03:13:00, Entry Price: 7499.236
# Exit Time: 2023-07-22 03:14:00, Exit Price: 7480.062
# Profit/Loss: 19.17
#
# Trade Type: SELL
# Entry Time: 2023-07-22 03:32:00, Entry Price: 7487.6
# Exit Time: 2023-07-22 03:33:00, Exit Price: 7487.217
# Profit/Loss: 0.38
#
# Trade Type: SELL
# Entry Time: 2023-07-22 03:50:00, Entry Price: 7494.49
# Exit Time: 2023-07-22 03:51:00, Exit Price: 7490.017
# Profit/Loss: 4.47
#
# Trade Type: SELL
# Entry Time: 2023-07-22 04:17:00, Entry Price: 7501.592
# Exit Time: 2023-07-22 04:18:00, Exit Price: 7494.101
# Profit/Loss: 7.49
#
# Trade Type: SELL
# Entry Time: 2023-07-22 04:38:00, Entry Price: 7499.947
# Exit Time: 2023-07-22 04:39:00, Exit Price: 7493.997
# Profit/Loss: 5.95
#
# Trade Type: SELL
# Entry Time: 2023-07-22 05:12:00, Entry Price: 7490.437
# Exit Time: 2023-07-22 05:13:00, Exit Price: 7479.77
# Profit/Loss: 10.67
#
# Trade Type: SELL
# Entry Time: 2023-07-22 05:55:00, Entry Price: 7498.432
# Exit Time: 2023-07-22 05:56:00, Exit Price: 7480.854
# Profit/Loss: 17.58
#
# Trade Type: SELL
# Entry Time: 2023-07-22 06:20:00, Entry Price: 7479.563
# Exit Time: 2023-07-22 06:21:00, Exit Price: 7464.678
# Profit/Loss: 14.89
#
# Trade Type: SELL
# Entry Time: 2023-07-22 06:41:00, Entry Price: 7472.866
# Exit Time: 2023-07-22 06:42:00, Exit Price: 7471.198
# Profit/Loss: 1.67
#
# Trade Type: SELL
# Entry Time: 2023-07-22 07:26:00, Entry Price: 7490.174
# Exit Time: 2023-07-22 07:27:00, Exit Price: 7487.051
# Profit/Loss: 3.12
#
# Trade Type: SELL
# Entry Time: 2023-07-22 07:45:00, Entry Price: 7494.721
# Exit Time: 2023-07-22 07:46:00, Exit Price: 7489.52
# Profit/Loss: 5.20
#
# Trade Type: SELL
# Entry Time: 2023-07-22 08:27:00, Entry Price: 7507.539
# Exit Time: 2023-07-22 08:28:00, Exit Price: 7499.475
# Profit/Loss: 8.06
#
# Trade Type: SELL
# Entry Time: 2023-07-22 09:38:00, Entry Price: 7511.334
# Exit Time: 2023-07-22 09:39:00, Exit Price: 7501.026
# Profit/Loss: 10.31
#
# Trade Type: SELL
# Entry Time: 2023-07-22 10:21:00, Entry Price: 7519.304
# Exit Time: 2023-07-22 10:22:00, Exit Price: 7518.42
# Profit/Loss: 0.88
#
# Trade Type: SELL
# Entry Time: 2023-07-22 10:59:00, Entry Price: 7534.813
# Exit Time: 2023-07-22 11:00:00, Exit Price: 7523.066
# Profit/Loss: 11.75
#
# Trade Type: SELL
# Entry Time: 2023-07-22 11:32:00, Entry Price: 7529.073
# Exit Time: 2023-07-22 11:33:00, Exit Price: 7525.237
# Profit/Loss: 3.84
#
# Trade Type: SELL
# Entry Time: 2023-07-22 11:51:00, Entry Price: 7533.03
# Exit Time: 2023-07-22 11:52:00, Exit Price: 7526.509
# Profit/Loss: 6.52
#
# Trade Type: SELL
# Entry Time: 2023-07-22 12:33:00, Entry Price: 7532.723
# Exit Time: 2023-07-22 12:34:00, Exit Price: 7527.832
# Profit/Loss: 4.89
#
# Trade Type: SELL
# Entry Time: 2023-07-22 13:21:00, Entry Price: 7548.112
# Exit Time: 2023-07-22 13:22:00, Exit Price: 7537.15
# Profit/Loss: 10.96
#
# Trade Type: SELL
# Entry Time: 2023-07-22 13:54:00, Entry Price: 7544.4
# Exit Time: 2023-07-22 13:55:00, Exit Price: 7533.866
# Profit/Loss: 10.53
#
# Trade Type: SELL
# Entry Time: 2023-07-22 14:14:00, Entry Price: 7541.958
# Exit Time: 2023-07-22 14:15:00, Exit Price: 7522.954
# Profit/Loss: 19.00
#
# Trade Type: SELL
# Entry Time: 2023-07-22 14:53:00, Entry Price: 7540.186
# Exit Time: 2023-07-22 14:54:00, Exit Price: 7527.342
# Profit/Loss: 12.84
#
# Trade Type: SELL
# Entry Time: 2023-07-22 15:31:00, Entry Price: 7513.823
# Exit Time: 2023-07-22 15:32:00, Exit Price: 7498.052
# Profit/Loss: 15.77
#
# Trade Type: SELL
# Entry Time: 2023-07-22 16:25:00, Entry Price: 7487.838
# Exit Time: 2023-07-22 16:26:00, Exit Price: 7484.397
# Profit/Loss: 3.44
#
# Trade Type: SELL
# Entry Time: 2023-07-22 16:42:00, Entry Price: 7491.013
# Exit Time: 2023-07-22 16:43:00, Exit Price: 7487.076
# Profit/Loss: 3.94
#
# Trade Type: SELL
# Entry Time: 2023-07-22 17:20:00, Entry Price: 7503.2
# Exit Time: 2023-07-22 17:21:00, Exit Price: 7488.918
# Profit/Loss: 14.28
#
# Trade Type: SELL
# Entry Time: 2023-07-22 17:55:00, Entry Price: 7503.498
# Exit Time: 2023-07-22 17:56:00, Exit Price: 7495.223
# Profit/Loss: 8.27
#
# Trade Type: SELL
# Entry Time: 2023-07-22 18:34:00, Entry Price: 7488.074
# Exit Time: 2023-07-22 18:35:00, Exit Price: 7483.01
# Profit/Loss: 5.06
#
# Trade Type: SELL
# Entry Time: 2023-07-22 18:57:00, Entry Price: 7492.363
# Exit Time: 2023-07-22 18:58:00, Exit Price: 7486.128
# Profit/Loss: 6.24
#
# Trade Type: SELL
# Entry Time: 2023-07-22 19:19:00, Entry Price: 7494.654
# Exit Time: 2023-07-22 19:20:00, Exit Price: 7492.262
# Profit/Loss: 2.39
#
# Trade Type: SELL
# Entry Time: 2023-07-22 19:37:00, Entry Price: 7499.422
# Exit Time: 2023-07-22 19:38:00, Exit Price: 7489.17
# Profit/Loss: 10.25
#
# Trade Type: SELL
# Entry Time: 2023-07-22 20:51:00, Entry Price: 7475.303
# Exit Time: 2023-07-22 20:52:00, Exit Price: 7474.397
# Profit/Loss: 0.91
#
# Trade Type: SELL
# Entry Time: 2023-07-22 21:02:00, Entry Price: 7478.495
# Exit Time: 2023-07-22 21:03:00, Exit Price: 7476.437
# Profit/Loss: 2.06
#
# Trade Type: SELL
# Entry Time: 2023-07-22 21:24:00, Entry Price: 7485.694
# Exit Time: 2023-07-22 21:25:00, Exit Price: 7475.981
# Profit/Loss: 9.71
#
# Trade Type: SELL
# Entry Time: 2023-07-22 21:43:00, Entry Price: 7483.513
# Exit Time: 2023-07-22 21:44:00, Exit Price: 7475.477
# Profit/Loss: 8.04
#
# Trade Type: SELL
# Entry Time: 2023-07-22 22:02:00, Entry Price: 7483.011
# Exit Time: 2023-07-22 22:03:00, Exit Price: 7476.072
# Profit/Loss: 6.94
#
# Trade Type: SELL
# Entry Time: 2023-07-22 22:29:00, Entry Price: 7487.262
# Exit Time: 2023-07-22 22:30:00, Exit Price: 7484.394
# Profit/Loss: 2.87
#
# Trade Type: SELL
# Entry Time: 2023-07-22 22:44:00, Entry Price: 7490.394
# Exit Time: 2023-07-22 22:45:00, Exit Price: 7479.143
# Profit/Loss: 11.25
#
# Trade Type: SELL
# Entry Time: 2023-07-22 23:09:00, Entry Price: 7485.374
# Exit Time: 2023-07-22 23:10:00, Exit Price: 7474.639
# Profit/Loss: 10.73
#
# Trade Type: SELL
# Entry Time: 2023-07-22 23:25:00, Entry Price: 7481.14
# Exit Time: 2023-07-22 23:26:00, Exit Price: 7475.263
# Profit/Loss: 5.88
#
# Trade Type: SELL
# Entry Time: 2023-07-22 23:51:00, Entry Price: 7486.344
# Exit Time: 2023-07-22 23:52:00, Exit Price: 7484.094
# Profit/Loss: 2.25
#
# Trade Type: SELL
# Entry Time: 2023-07-23 01:02:00, Entry Price: 7507.72
# Exit Time: 2023-07-23 01:03:00, Exit Price: 7489.532
# Profit/Loss: 18.19
#
# Trade Type: SELL
# Entry Time: 2023-07-23 01:26:00, Entry Price: 7499.102
# Exit Time: 2023-07-23 01:27:00, Exit Price: 7494.194
# Profit/Loss: 4.91
#
# Trade Type: SELL
# Entry Time: 2023-07-23 02:11:00, Entry Price: 7487.195
# Exit Time: 2023-07-23 02:12:00, Exit Price: 7480.879
# Profit/Loss: 6.32
#
# Trade Type: SELL
# Entry Time: 2023-07-23 02:37:00, Entry Price: 7467.868
# Exit Time: 2023-07-23 02:38:00, Exit Price: 7466.681
# Profit/Loss: 1.19
#
# Trade Type: SELL
# Entry Time: 2023-07-23 03:13:00, Entry Price: 7482.181
# Exit Time: 2023-07-23 03:14:00, Exit Price: 7474.991
# Profit/Loss: 7.19
#
# Trade Type: SELL
# Entry Time: 2023-07-23 03:28:00, Entry Price: 7480.691
# Exit Time: 2023-07-23 03:29:00, Exit Price: 7474.386
# Profit/Loss: 6.30
#
# Trade Type: SELL
# Entry Time: 2023-07-23 04:18:00, Entry Price: 7470.794
# Exit Time: 2023-07-23 04:19:00, Exit Price: 7466.279
# Profit/Loss: 4.51
#
# Trade Type: SELL
# Entry Time: 2023-07-23 04:36:00, Entry Price: 7473.625
# Exit Time: 2023-07-23 04:37:00, Exit Price: 7470.686
# Profit/Loss: 2.94
#
# Trade Type: SELL
# Entry Time: 2023-07-23 05:28:00, Entry Price: 7493.461
# Exit Time: 2023-07-23 05:29:00, Exit Price: 7478.907
# Profit/Loss: 14.55
#
# Trade Type: SELL
# Entry Time: 2023-07-23 05:51:00, Entry Price: 7488.359
# Exit Time: 2023-07-23 05:52:00, Exit Price: 7484.499
# Profit/Loss: 3.86
#
# Trade Type: SELL
# Entry Time: 2023-07-23 06:12:00, Entry Price: 7488.934
# Exit Time: 2023-07-23 06:13:00, Exit Price: 7480.259
# Profit/Loss: 8.68
#
# Trade Type: SELL
# Entry Time: 2023-07-23 06:44:00, Entry Price: 7479.084
# Exit Time: 2023-07-23 06:45:00, Exit Price: 7475.318
# Profit/Loss: 3.77
#
# Trade Type: SELL
# Entry Time: 2023-07-23 07:11:00, Entry Price: 7465.047
# Exit Time: 2023-07-23 07:12:00, Exit Price: 7462.362
# Profit/Loss: 2.68
#
# Trade Type: SELL
# Entry Time: 2023-07-23 08:12:00, Entry Price: 7429.174
# Exit Time: 2023-07-23 08:13:00, Exit Price: 7421.686
# Profit/Loss: 7.49
#
# Trade Type: SELL
# Entry Time: 2023-07-23 08:27:00, Entry Price: 7427.266
# Exit Time: 2023-07-23 08:28:00, Exit Price: 7424.605
# Profit/Loss: 2.66
#
# Trade Type: SELL
# Entry Time: 2023-07-23 09:06:00, Entry Price: 7428.734
# Exit Time: 2023-07-23 09:07:00, Exit Price: 7424.887
# Profit/Loss: 3.85
#
# Trade Type: SELL
# Entry Time: 2023-07-23 09:22:00, Entry Price: 7431.139
# Exit Time: 2023-07-23 09:23:00, Exit Price: 7423.455
# Profit/Loss: 7.68
#
# Trade Type: SELL
# Entry Time: 2023-07-23 09:37:00, Entry Price: 7429.272
# Exit Time: 2023-07-23 09:38:00, Exit Price: 7428.877
# Profit/Loss: 0.39
#
# Trade Type: SELL
# Entry Time: 2023-07-23 09:47:00, Entry Price: 7432.392
# Exit Time: 2023-07-23 09:48:00, Exit Price: 7421.124
# Profit/Loss: 11.27
#
# Trade Type: SELL
# Entry Time: 2023-07-23 10:25:00, Entry Price: 7429.794
# Exit Time: 2023-07-23 10:26:00, Exit Price: 7421.648
# Profit/Loss: 8.15
#
# Trade Type: SELL
# Entry Time: 2023-07-23 11:21:00, Entry Price: 7426.743
# Exit Time: 2023-07-23 11:22:00, Exit Price: 7419.623
# Profit/Loss: 7.12
#
# Trade Type: SELL
# Entry Time: 2023-07-23 11:40:00, Entry Price: 7427.161
# Exit Time: 2023-07-23 11:41:00, Exit Price: 7413.463
# Profit/Loss: 13.70
#
# Trade Type: SELL
# Entry Time: 2023-07-23 12:51:00, Entry Price: 7409.561
# Exit Time: 2023-07-23 12:52:00, Exit Price: 7404.072
# Profit/Loss: 5.49
#
# Trade Type: SELL
# Entry Time: 2023-07-23 13:22:00, Entry Price: 7416.643
# Exit Time: 2023-07-23 13:23:00, Exit Price: 7403.991
# Profit/Loss: 12.65
#
# Trade Type: SELL
# Entry Time: 2023-07-23 14:40:00, Entry Price: 7391.91
# Exit Time: 2023-07-23 14:41:00, Exit Price: 7378.246
# Profit/Loss: 13.66
#
# Trade Type: SELL
# Entry Time: 2023-07-23 15:01:00, Entry Price: 7386.537
# Exit Time: 2023-07-23 15:02:00, Exit Price: 7361.023
# Profit/Loss: 25.51
#
# Trade Type: SELL
# Entry Time: 2023-07-23 16:03:00, Entry Price: 7347.278
# Exit Time: 2023-07-23 16:04:00, Exit Price: 7343.633
# Profit/Loss: 3.65
#
# Trade Type: SELL
# Entry Time: 2023-07-23 16:13:00, Entry Price: 7347.016
# Exit Time: 2023-07-23 16:14:00, Exit Price: 7337.891
# Profit/Loss: 9.12
#
# Trade Type: SELL
# Entry Time: 2023-07-23 16:36:00, Entry Price: 7346.808
# Exit Time: 2023-07-23 16:37:00, Exit Price: 7338.995
# Profit/Loss: 7.81
#
# Trade Type: SELL
# Entry Time: 2023-07-23 17:18:00, Entry Price: 7337.276
# Exit Time: 2023-07-23 17:19:00, Exit Price: 7333.821
# Profit/Loss: 3.45
#
# Trade Type: SELL
# Entry Time: 2023-07-23 17:44:00, Entry Price: 7334.674
# Exit Time: 2023-07-23 17:45:00, Exit Price: 7328.63
# Profit/Loss: 6.04
#
# Trade Type: SELL
# Entry Time: 2023-07-23 18:00:00, Entry Price: 7334.837
# Exit Time: 2023-07-23 18:01:00, Exit Price: 7330.573
# Profit/Loss: 4.26
#
# Trade Type: SELL
# Entry Time: 2023-07-23 18:20:00, Entry Price: 7338.405
# Exit Time: 2023-07-23 18:21:00, Exit Price: 7330.246
# Profit/Loss: 8.16
#
# Trade Type: SELL
# Entry Time: 2023-07-23 18:49:00, Entry Price: 7329.301
# Exit Time: 2023-07-23 18:50:00, Exit Price: 7321.754
# Profit/Loss: 7.55
#
# Trade Type: SELL
# Entry Time: 2023-07-23 19:13:00, Entry Price: 7331.597
# Exit Time: 2023-07-23 19:14:00, Exit Price: 7329.746
# Profit/Loss: 1.85
#
# Trade Type: SELL
# Entry Time: 2023-07-23 19:56:00, Entry Price: 7307.791
# Exit Time: 2023-07-23 19:57:00, Exit Price: 7306.473
# Profit/Loss: 1.32
#
# Trade Type: SELL
# Entry Time: 2023-07-23 20:04:00, Entry Price: 7309.104
# Exit Time: 2023-07-23 20:05:00, Exit Price: 7299.832
# Profit/Loss: 9.27
#
# Trade Type: SELL
# Entry Time: 2023-07-23 20:31:00, Entry Price: 7307.773
# Exit Time: 2023-07-23 20:32:00, Exit Price: 7297.624
# Profit/Loss: 10.15
#
# Trade Type: SELL
# Entry Time: 2023-07-23 21:38:00, Entry Price: 7289.794
# Exit Time: 2023-07-23 21:39:00, Exit Price: 7290.607
# Profit/Loss: -0.81
#
# Trade Type: SELL
# Entry Time: 2023-07-23 22:04:00, Entry Price: 7301.159
# Exit Time: 2023-07-23 22:05:00, Exit Price: 7295.515
# Profit/Loss: 5.64
#
# Trade Type: SELL
# Entry Time: 2023-07-23 22:36:00, Entry Price: 7301.311
# Exit Time: 2023-07-23 22:37:00, Exit Price: 7286.113
# Profit/Loss: 15.20
#
# Trade Type: SELL
# Entry Time: 2023-07-23 23:02:00, Entry Price: 7296.624
# Exit Time: 2023-07-23 23:03:00, Exit Price: 7282.776
# Profit/Loss: 13.85
#
# Trade Type: SELL
# Entry Time: 2023-07-23 23:27:00, Entry Price: 7280.54
# Exit Time: 2023-07-23 23:28:00, Exit Price: 7280.039
# Profit/Loss: 0.50
#
# Trade Type: SELL
# Entry Time: 2023-07-23 23:37:00, Entry Price: 7283.602
# Exit Time: 2023-07-23 23:38:00, Exit Price: 7266.55
# Profit/Loss: 17.05
#
# Trade Type: SELL
# Entry Time: 2023-07-24 00:04:00, Entry Price: 7277.668
# Exit Time: 2023-07-24 00:05:00, Exit Price: 7269.741
# Profit/Loss: 7.93
#
# Trade Type: SELL
# Entry Time: 2023-07-24 00:27:00, Entry Price: 7272.489
# Exit Time: 2023-07-24 00:28:00, Exit Price: 7271.535
# Profit/Loss: 0.95
#
# Trade Type: SELL
# Entry Time: 2023-07-24 00:39:00, Entry Price: 7275.954
# Exit Time: 2023-07-24 00:40:00, Exit Price: 7266.297
# Profit/Loss: 9.66
#
# Trade Type: SELL
# Entry Time: 2023-07-24 01:01:00, Entry Price: 7274.756
# Exit Time: 2023-07-24 01:02:00, Exit Price: 7259.801
# Profit/Loss: 14.95
#
# Trade Type: SELL
# Entry Time: 2023-07-24 01:55:00, Entry Price: 7277.339
# Exit Time: 2023-07-24 01:56:00, Exit Price: 7261.688
# Profit/Loss: 15.65
#
# Trade Type: SELL
# Entry Time: 2023-07-24 02:24:00, Entry Price: 7269.417
# Exit Time: 2023-07-24 02:25:00, Exit Price: 7264.247
# Profit/Loss: 5.17
#
# Trade Type: SELL
# Entry Time: 2023-07-24 02:51:00, Entry Price: 7275.397
# Exit Time: 2023-07-24 02:52:00, Exit Price: 7261.916
# Profit/Loss: 13.48
#
# Trade Type: SELL
# Entry Time: 2023-07-24 03:12:00, Entry Price: 7263.465
# Exit Time: 2023-07-24 03:13:00, Exit Price: 7264.25
# Profit/Loss: -0.78
#
# Trade Type: SELL
# Entry Time: 2023-07-24 03:29:00, Entry Price: 7270.813
# Exit Time: 2023-07-24 03:30:00, Exit Price: 7265.91
# Profit/Loss: 4.90
#
# Trade Type: SELL
# Entry Time: 2023-07-24 04:03:00, Entry Price: 7279.87
# Exit Time: 2023-07-24 04:04:00, Exit Price: 7278.458
# Profit/Loss: 1.41
#
# Trade Type: SELL
# Entry Time: 2023-07-24 04:23:00, Entry Price: 7286.363
# Exit Time: 2023-07-24 04:24:00, Exit Price: 7280.261
# Profit/Loss: 6.10
#
# Trade Type: SELL
# Entry Time: 2023-07-24 04:47:00, Entry Price: 7289.086
# Exit Time: 2023-07-24 04:48:00, Exit Price: 7276.781
# Profit/Loss: 12.31
#
# Trade Type: SELL
# Entry Time: 2023-07-24 05:07:00, Entry Price: 7284.603
# Exit Time: 2023-07-24 05:08:00, Exit Price: 7275.721
# Profit/Loss: 8.88
#
# Trade Type: SELL
# Entry Time: 2023-07-24 05:25:00, Entry Price: 7282.931
# Exit Time: 2023-07-24 05:26:00, Exit Price: 7280.153
# ...
# Exit Time: 2023-08-14 01:02:00, Exit Price: 6779.822
# Profit/Loss: 9.29
#
# Trade Type: SELL
# Entry Time: 2023-08-14 01:31:00, Entry Price: 6781.86
# Exit Time: 2023-08-14 01:32:00, Exit Price: 6781.813
# Profit/Loss: 0.05
#
# Trade Type: SELL
# Entry Time: 2023-08-14 02:03:00, Entry Price: 6794.063
# Exit Time: 2023-08-14 02:04:00, Exit Price: 6788.683
# Profit/Loss: 5.38
#
# Trade Type: SELL
# Entry Time: 2023-08-14 03:18:00, Entry Price: 6785.4
# Exit Time: 2023-08-14 03:19:00, Exit Price: 6782.052
# Profit/Loss: 3.35
#
# Trade Type: SELL
# Entry Time: 2023-08-14 03:27:00, Entry Price: 6784.892
# Exit Time: 2023-08-14 03:28:00, Exit Price: 6775.497
# Profit/Loss: 9.39
#
# Trade Type: SELL
# Entry Time: 2023-08-14 04:14:00, Entry Price: 6780.331
# Exit Time: 2023-08-14 04:15:00, Exit Price: 6780.083
# Profit/Loss: 0.25
#
# Trade Type: SELL
# Entry Time: 2023-08-14 04:18:00, Entry Price: 6780.913
# Exit Time: 2023-08-14 04:19:00, Exit Price: 6775.781
# Profit/Loss: 5.13
#
# Trade Type: SELL
# Entry Time: 2023-08-14 04:36:00, Entry Price: 6782.372
# Exit Time: 2023-08-14 04:37:00, Exit Price: 6774.988
# Profit/Loss: 7.38
#
# Trade Type: SELL
# Entry Time: 2023-08-14 04:56:00, Entry Price: 6773.616
# Exit Time: 2023-08-14 04:57:00, Exit Price: 6772.367
# Profit/Loss: 1.25
#
# Trade Type: SELL
# Entry Time: 2023-08-14 05:17:00, Entry Price: 6774.569
# Exit Time: 2023-08-14 05:18:00, Exit Price: 6773.513
# Profit/Loss: 1.06
#
# Trade Type: SELL
# Entry Time: 2023-08-14 05:23:00, Entry Price: 6775.217
# Exit Time: 2023-08-14 05:24:00, Exit Price: 6766.818
# Profit/Loss: 8.40
#
# Trade Type: SELL
# Entry Time: 2023-08-14 05:50:00, Entry Price: 6777.001
# Exit Time: 2023-08-14 05:51:00, Exit Price: 6775.424
# Profit/Loss: 1.58
#
# Trade Type: SELL
# Entry Time: 2023-08-14 06:05:00, Entry Price: 6780.769
# Exit Time: 2023-08-14 06:06:00, Exit Price: 6770.97
# Profit/Loss: 9.80
#
# Trade Type: SELL
# Entry Time: 2023-08-14 07:10:00, Entry Price: 6754.802
# Exit Time: 2023-08-14 07:11:00, Exit Price: 6749.462
# Profit/Loss: 5.34
#
# Trade Type: SELL
# Entry Time: 2023-08-14 07:42:00, Entry Price: 6746.471
# Exit Time: 2023-08-14 07:43:00, Exit Price: 6733.391
# Profit/Loss: 13.08
#
# Trade Type: SELL
# Entry Time: 2023-08-14 08:14:00, Entry Price: 6737.938
# Exit Time: 2023-08-14 08:15:00, Exit Price: 6719.753
# Profit/Loss: 18.19
#
# Trade Type: SELL
# Entry Time: 2023-08-14 09:23:00, Entry Price: 6746.832
# Exit Time: 2023-08-14 09:24:00, Exit Price: 6741.311
# Profit/Loss: 5.52
#
# Trade Type: SELL
# Entry Time: 2023-08-14 09:37:00, Entry Price: 6746.216
# Exit Time: 2023-08-14 09:38:00, Exit Price: 6744.737
# Profit/Loss: 1.48
#
# Trade Type: SELL
# Entry Time: 2023-08-14 10:13:00, Entry Price: 6757.971
# Exit Time: 2023-08-14 10:14:00, Exit Price: 6753.705
# Profit/Loss: 4.27
#
# Trade Type: SELL
# Entry Time: 2023-08-14 11:35:00, Entry Price: 6747.701
# Exit Time: 2023-08-14 11:36:00, Exit Price: 6726.098
# Profit/Loss: 21.60
#
# Trade Type: SELL
# Entry Time: 2023-08-14 12:03:00, Entry Price: 6736.607
# Exit Time: 2023-08-14 12:04:00, Exit Price: 6735.484
# Profit/Loss: 1.12
#
# Trade Type: SELL
# Entry Time: 2023-08-14 12:21:00, Entry Price: 6741.957
# Exit Time: 2023-08-14 12:22:00, Exit Price: 6733.552
# Profit/Loss: 8.41
#
# Trade Type: SELL
# Entry Time: 2023-08-14 12:44:00, Entry Price: 6738.496
# Exit Time: 2023-08-14 12:45:00, Exit Price: 6718.288
# Profit/Loss: 20.21
#
# Trade Type: SELL
# Entry Time: 2023-08-14 13:05:00, Entry Price: 6725.987
# Exit Time: 2023-08-14 13:06:00, Exit Price: 6720.936
# Profit/Loss: 5.05
#
# Trade Type: SELL
# Entry Time: 2023-08-14 13:36:00, Entry Price: 6732.525
# Exit Time: 2023-08-14 13:37:00, Exit Price: 6727.888
# Profit/Loss: 4.64
#
# Trade Type: SELL
# Entry Time: 2023-08-14 13:57:00, Entry Price: 6735.49
# Exit Time: 2023-08-14 13:58:00, Exit Price: 6729.131
# Profit/Loss: 6.36
#
# Trade Type: SELL
# Entry Time: 2023-08-14 14:31:00, Entry Price: 6742.247
# Exit Time: 2023-08-14 14:32:00, Exit Price: 6740.46
# Profit/Loss: 1.79
#
# Trade Type: SELL
# Entry Time: 2023-08-14 14:59:00, Entry Price: 6751.309
# Exit Time: 2023-08-14 15:00:00, Exit Price: 6749.041
# Profit/Loss: 2.27
#
# Trade Type: SELL
# Entry Time: 2023-08-14 15:26:00, Entry Price: 6758.675
# Exit Time: 2023-08-14 15:27:00, Exit Price: 6757.248
# Profit/Loss: 1.43
#
# Trade Type: SELL
# Entry Time: 2023-08-14 15:34:00, Entry Price: 6759.488
# Exit Time: 2023-08-14 15:35:00, Exit Price: 6753.817
# Profit/Loss: 5.67
#
# Trade Type: SELL
# Entry Time: 2023-08-14 16:01:00, Entry Price: 6763.879
# Exit Time: 2023-08-14 16:02:00, Exit Price: 6756.302
# Profit/Loss: 7.58
#
# Trade Type: SELL
# Entry Time: 2023-08-14 16:25:00, Entry Price: 6765.483
# Exit Time: 2023-08-14 16:26:00, Exit Price: 6758.276
# Profit/Loss: 7.21
#
# Trade Type: SELL
# Entry Time: 2023-08-14 17:04:00, Entry Price: 6773.348
# Exit Time: 2023-08-14 17:05:00, Exit Price: 6769.039
# Profit/Loss: 4.31
#
# Trade Type: SELL
# Entry Time: 2023-08-14 17:20:00, Entry Price: 6774.582
# Exit Time: 2023-08-14 17:21:00, Exit Price: 6771.154
# Profit/Loss: 3.43
#
# Trade Type: SELL
# Entry Time: 2023-08-14 18:05:00, Entry Price: 6788.897
# Exit Time: 2023-08-14 18:06:00, Exit Price: 6782.42
# Profit/Loss: 6.48
#
# Trade Type: SELL
# Entry Time: 2023-08-14 19:08:00, Entry Price: 6797.477
# Exit Time: 2023-08-14 19:09:00, Exit Price: 6787.109
# Profit/Loss: 10.37
#
# Trade Type: SELL
# Entry Time: 2023-08-14 19:30:00, Entry Price: 6795.543
# Exit Time: 2023-08-14 19:31:00, Exit Price: 6793.514
# Profit/Loss: 2.03
#
# Trade Type: SELL
# Entry Time: 2023-08-14 19:37:00, Entry Price: 6795.482
# Exit Time: 2023-08-14 19:38:00, Exit Price: 6786.913
# Profit/Loss: 8.57
#
# Trade Type: SELL
# Entry Time: 2023-08-14 20:22:00, Entry Price: 6777.012
# Exit Time: 2023-08-14 20:23:00, Exit Price: 6773.711
# Profit/Loss: 3.30
#
# Trade Type: SELL
# Entry Time: 2023-08-14 20:32:00, Entry Price: 6776.96
# Exit Time: 2023-08-14 20:33:00, Exit Price: 6769.913
# Profit/Loss: 7.05
#
# Trade Type: SELL
# Entry Time: 2023-08-14 21:05:00, Entry Price: 6782.599
# Exit Time: 2023-08-14 21:06:00, Exit Price: 6770.342
# Profit/Loss: 12.26
#
# Trade Type: SELL
# Entry Time: 2023-08-14 22:01:00, Entry Price: 6792.811
# Exit Time: 2023-08-14 22:02:00, Exit Price: 6787.221
# Profit/Loss: 5.59
#
# Trade Type: SELL
# Entry Time: 2023-08-14 22:39:00, Entry Price: 6779.176
# Exit Time: 2023-08-14 22:40:00, Exit Price: 6752.229
# Profit/Loss: 26.95
#
# Trade Type: SELL
# Entry Time: 2023-08-15 00:07:00, Entry Price: 6781.778
# Exit Time: 2023-08-15 00:08:00, Exit Price: 6773.524
# Profit/Loss: 8.25
#
# Trade Type: SELL
# Entry Time: 2023-08-15 00:49:00, Entry Price: 6779.289
# Exit Time: 2023-08-15 00:50:00, Exit Price: 6771.46
# Profit/Loss: 7.83
#
# Trade Type: SELL
# Entry Time: 2023-08-15 01:23:00, Entry Price: 6784.768
# Exit Time: 2023-08-15 01:24:00, Exit Price: 6782.697
# Profit/Loss: 2.07
#
# Trade Type: SELL
# Entry Time: 2023-08-15 01:35:00, Entry Price: 6786.756
# Exit Time: 2023-08-15 01:36:00, Exit Price: 6786.319
# Profit/Loss: 0.44
#
# Trade Type: SELL
# Entry Time: 2023-08-15 01:41:00, Entry Price: 6787.952
# Exit Time: 2023-08-15 01:42:00, Exit Price: 6773.127
# Profit/Loss: 14.82
#
# Trade Type: SELL
# Entry Time: 2023-08-15 02:00:00, Entry Price: 6780.28
# Exit Time: 2023-08-15 02:01:00, Exit Price: 6773.133
# Profit/Loss: 7.15
#
# Trade Type: SELL
# Entry Time: 2023-08-15 03:04:00, Entry Price: 6797.424
# Exit Time: 2023-08-15 03:05:00, Exit Price: 6785.047
# Profit/Loss: 12.38
#
# Trade Type: SELL
# Entry Time: 2023-08-15 03:32:00, Entry Price: 6782.339
# Exit Time: 2023-08-15 03:33:00, Exit Price: 6783.118
# Profit/Loss: -0.78
#
# Trade Type: SELL
# Entry Time: 2023-08-15 05:19:00, Entry Price: 6825.741
# Exit Time: 2023-08-15 05:20:00, Exit Price: 6821.784
# Profit/Loss: 3.96
#
# Trade Type: SELL
# Entry Time: 2023-08-15 06:05:00, Entry Price: 6839.665
# Exit Time: 2023-08-15 06:06:00, Exit Price: 6837.125
# Profit/Loss: 2.54
#
# Trade Type: SELL
# Entry Time: 2023-08-15 06:24:00, Entry Price: 6843.809
# Exit Time: 2023-08-15 06:25:00, Exit Price: 6839.689
# Profit/Loss: 4.12
#
# Trade Type: SELL
# Entry Time: 2023-08-15 06:35:00, Entry Price: 6843.484
# Exit Time: 2023-08-15 06:36:00, Exit Price: 6838.141
# Profit/Loss: 5.34
#
# Trade Type: SELL
# Entry Time: 2023-08-15 07:07:00, Entry Price: 6850.854
# Exit Time: 2023-08-15 07:08:00, Exit Price: 6845.052
# Profit/Loss: 5.80
#
# Trade Type: SELL
# Entry Time: 2023-08-15 08:24:00, Entry Price: 6854.657
# Exit Time: 2023-08-15 08:25:00, Exit Price: 6852.554
# Profit/Loss: 2.10
#
# Trade Type: SELL
# Entry Time: 2023-08-15 08:49:00, Entry Price: 6860.239
# Exit Time: 2023-08-15 08:50:00, Exit Price: 6858.971
# Profit/Loss: 1.27
#
# Trade Type: SELL
# Entry Time: 2023-08-15 09:22:00, Entry Price: 6871.639
# Exit Time: 2023-08-15 09:23:00, Exit Price: 6866.672
# Profit/Loss: 4.97
#
# Trade Type: SELL
# Entry Time: 2023-08-15 09:36:00, Entry Price: 6871.858
# Exit Time: 2023-08-15 09:37:00, Exit Price: 6868.006
# Profit/Loss: 3.85
#
# Trade Type: SELL
# Entry Time: 2023-08-15 09:59:00, Entry Price: 6876.377
# Exit Time: 2023-08-15 10:00:00, Exit Price: 6875.072
# Profit/Loss: 1.31
#
# Trade Type: SELL
# Entry Time: 2023-08-15 10:42:00, Entry Price: 6892.147
# Exit Time: 2023-08-15 10:43:00, Exit Price: 6882.217
# Profit/Loss: 9.93
#
# Trade Type: SELL
# Entry Time: 2023-08-15 11:31:00, Entry Price: 6901.628
# Exit Time: 2023-08-15 11:32:00, Exit Price: 6893.069
# Profit/Loss: 8.56
#
# Trade Type: SELL
# Entry Time: 2023-08-15 12:07:00, Entry Price: 6878.716
# Exit Time: 2023-08-15 12:08:00, Exit Price: 6872.458
# Profit/Loss: 6.26
#
# Trade Type: SELL
# Entry Time: 2023-08-15 12:45:00, Entry Price: 6887.128
# Exit Time: 2023-08-15 12:46:00, Exit Price: 6882.404
# Profit/Loss: 4.72
#
# Trade Type: SELL
# Entry Time: 2023-08-15 14:38:00, Entry Price: 6906.846
# Exit Time: 2023-08-15 14:39:00, Exit Price: 6893.518
# Profit/Loss: 13.33
#
# Trade Type: SELL
# Entry Time: 2023-08-15 15:55:00, Entry Price: 6911.824
# Exit Time: 2023-08-15 15:56:00, Exit Price: 6907.581
# Profit/Loss: 4.24
#
# Trade Type: SELL
# Entry Time: 2023-08-15 16:15:00, Entry Price: 6914.827
# Exit Time: 2023-08-15 16:16:00, Exit Price: 6907.823
# Profit/Loss: 7.00
#
# Trade Type: SELL
# Entry Time: 2023-08-15 17:21:00, Entry Price: 6905.008
# Exit Time: 2023-08-15 17:22:00, Exit Price: 6897.247
# Profit/Loss: 7.76
#
# Trade Type: SELL
# Entry Time: 2023-08-15 19:15:00, Entry Price: 6913.898
# Exit Time: 2023-08-15 19:16:00, Exit Price: 6904.425
# Profit/Loss: 9.47
#
# Trade Type: SELL
# Entry Time: 2023-08-15 19:58:00, Entry Price: 6896.499
# Exit Time: 2023-08-15 19:59:00, Exit Price: 6892.708
# Profit/Loss: 3.79
#
# Trade Type: SELL
# Entry Time: 2023-08-15 20:18:00, Entry Price: 6900.113
# Exit Time: 2023-08-15 20:19:00, Exit Price: 6888.784
# Profit/Loss: 11.33
#
# Trade Type: SELL
# Entry Time: 2023-08-15 20:53:00, Entry Price: 6902.705
# Exit Time: 2023-08-15 20:54:00, Exit Price: 6892.732
# Profit/Loss: 9.97
#
# Trade Type: SELL
# Entry Time: 2023-08-15 21:11:00, Entry Price: 6899.452
# Exit Time: 2023-08-15 21:12:00, Exit Price: 6885.318
# Profit/Loss: 14.13
#
# Trade Type: SELL
# Entry Time: 2023-08-15 21:32:00, Entry Price: 6892.99
# Exit Time: 2023-08-15 21:33:00, Exit Price: 6891.508
# Profit/Loss: 1.48
#
# Trade Type: SELL
# Entry Time: 2023-08-15 22:05:00, Entry Price: 6902.963
# Exit Time: 2023-08-15 22:06:00, Exit Price: 6897.154
# Profit/Loss: 5.81
#
# Trade Type: SELL
# Entry Time: 2023-08-15 22:28:00, Entry Price: 6905.792
# Exit Time: 2023-08-15 22:29:00, Exit Price: 6898.817
# Profit/Loss: 6.98
#
# Trade Type: SELL
# Entry Time: 2023-08-15 23:10:00, Entry Price: 6898.254
# Exit Time: 2023-08-15 23:11:00, Exit Price: 6890.545
# Profit/Loss: 7.71
#
# Trade Type: SELL
# Entry Time: 2023-08-15 23:34:00, Entry Price: 6895.101
# Exit Time: 2023-08-15 23:35:00, Exit Price: 6892.182
# Profit/Loss: 2.92
#
# Trade Type: SELL
# Entry Time: 2023-08-16 00:09:00, Entry Price: 6891.978
# Exit Time: 2023-08-16 00:10:00, Exit Price: 6879.711
# Profit/Loss: 12.27
#
# Trade Type: SELL
# Entry Time: 2023-08-16 01:44:00, Entry Price: 6895.858
# Exit Time: 2023-08-16 01:45:00, Exit Price: 6893.288
# Profit/Loss: 2.57
#
# Trade Type: SELL
# Entry Time: 2023-08-16 02:33:00, Entry Price: 6911.394
# Exit Time: 2023-08-16 02:34:00, Exit Price: 6894.504
# Profit/Loss: 16.89
#
# Trade Type: SELL
# Entry Time: 2023-08-16 03:02:00, Entry Price: 6902.261
# Exit Time: 2023-08-16 03:03:00, Exit Price: 6892.356
# Profit/Loss: 9.91
#
# Trade Type: SELL
# Entry Time: 2023-08-16 04:40:00, Entry Price: 6916.14
# Exit Time: 2023-08-16 04:41:00, Exit Price: 6909.556
# Profit/Loss: 6.58
#
# Trade Type: SELL
# Entry Time: 2023-08-16 04:54:00, Entry Price: 6914.842
# Exit Time: 2023-08-16 04:55:00, Exit Price: 6910.452
# Profit/Loss: 4.39
#
# Trade Type: SELL
# Entry Time: 2023-08-16 05:59:00, Entry Price: 6935.644
# Exit Time: 2023-08-16 06:00:00, Exit Price: 6930.988
# Profit/Loss: 4.66
#
# Trade Type: SELL
# Entry Time: 2023-08-16 06:43:00, Entry Price: 6948.084
# Exit Time: 2023-08-16 06:44:00, Exit Price: 6938.357
# Profit/Loss: 9.73
#
# Trade Type: SELL
# Entry Time: 2023-08-16 07:03:00, Entry Price: 6945.923
# Exit Time: 2023-08-16 07:04:00, Exit Price: 6941.629
# Profit/Loss: 4.29
#
# Trade Type: SELL
# Entry Time: 2023-08-16 07:40:00, Entry Price: 6947.036
# Exit Time: 2023-08-16 07:41:00, Exit Price: 6941.282
# Profit/Loss: 5.75
#
# Trade Type: SELL
# Entry Time: 2023-08-16 08:02:00, Entry Price: 6940.296
# Exit Time: 2023-08-16 08:03:00, Exit Price: 6932.38
# Profit/Loss: 7.92
#
# Trade Type: SELL
# Entry Time: 2023-08-16 09:06:00, Entry Price: 6952.628
# Exit Time: 2023-08-16 09:07:00, Exit Price: 6948.511
# Profit/Loss: 4.12
#
# Trade Type: SELL
# Entry Time: 2023-08-16 09:31:00, Entry Price: 6957.901
# Exit Time: 2023-08-16 09:32:00, Exit Price: 6949.359
# Profit/Loss: 8.54
#
# Trade Type: SELL
# Entry Time: 2023-08-16 10:11:00, Entry Price: 6949.061
# Exit Time: 2023-08-16 10:12:00, Exit Price: 6942.507
# Profit/Loss: 6.55
#
# Trade Type: SELL
# Entry Time: 2023-08-16 10:31:00, Entry Price: 6944.602
# Exit Time: 2023-08-16 10:32:00, Exit Price: 6943.768
# Profit/Loss: 0.83
#
# Trade Type: SELL
# Entry Time: 2023-08-16 10:41:00, Entry Price: 6947.099
# Exit Time: 2023-08-16 10:42:00, Exit Price: 6946.519
# Profit/Loss: 0.58
#
# Trade Type: SELL
# Entry Time: 2023-08-16 11:42:00, Entry Price: 6969.957
# Exit Time: 2023-08-16 11:43:00, Exit Price: 6966.436
# Profit/Loss: 3.52
#
# Trade Type: SELL
# Entry Time: 2023-08-16 13:03:00, Entry Price: 6943.45
# Exit Time: 2023-08-16 13:04:00, Exit Price: 6934.703
# Profit/Loss: 8.75
#
# Trade Type: SELL
# Entry Time: 2023-08-16 13:30:00, Entry Price: 6945.123
# Exit Time: 2023-08-16 13:31:00, Exit Price: 6944.556
# Profit/Loss: 0.57
#
# Trade Type: SELL
# Entry Time: 2023-08-16 13:38:00, Entry Price: 6947.063
# Exit Time: 2023-08-16 13:39:00, Exit Price: 6937.073
# Profit/Loss: 9.99
#
# Trade Type: SELL
# Entry Time: 2023-08-16 14:23:00, Entry Price: 6948.138
# Exit Time: 2023-08-16 14:24:00, Exit Price: 6935.256
# Profit/Loss: 12.88
#
# Trade Type: SELL
# Entry Time: 2023-08-16 15:15:00, Entry Price: 6931.311
# Exit Time: 2023-08-16 15:16:00, Exit Price: 6922.078
# Profit/Loss: 9.23
#
# Trade Type: SELL
# Entry Time: 2023-08-16 16:05:00, Entry Price: 6928.899
# Exit Time: 2023-08-16 16:06:00, Exit Price: 6924.33
# Profit/Loss: 4.57
#
# Trade Type: SELL
# Entry Time: 2023-08-16 16:16:00, Entry Price: 6928.033
# Exit Time: 2023-08-16 16:17:00, Exit Price: 6917.356
# Profit/Loss: 10.68
#
# Trade Type: SELL
# Entry Time: 2023-08-16 16:45:00, Entry Price: 6911.765
# Exit Time: 2023-08-16 16:46:00, Exit Price: 6908.735
# Profit/Loss: 3.03
#
# Trade Type: SELL
# Entry Time: 2023-08-16 17:08:00, Entry Price: 6917.533
# Exit Time: 2023-08-16 17:09:00, Exit Price: 6913.199
# Profit/Loss: 4.33
#
# Trade Type: SELL
# Entry Time: 2023-08-16 17:47:00, Entry Price: 6912.158
# Exit Time: 2023-08-16 17:48:00, Exit Price: 6911.076
# Profit/Loss: 1.08
#
# Trade Type: SELL
# Entry Time: 2023-08-16 18:06:00, Entry Price: 6918.05
# Exit Time: 2023-08-16 18:07:00, Exit Price: 6914.765
# Profit/Loss: 3.28
#
# Trade Type: SELL
# Entry Time: 2023-08-16 18:50:00, Entry Price: 6929.396
# Exit Time: 2023-08-16 18:51:00, Exit Price: 6926.482
# Profit/Loss: 2.91
#
# Trade Type: SELL
# Entry Time: 2023-08-16 19:35:00, Entry Price: 6944.319
# Exit Time: 2023-08-16 19:36:00, Exit Price: 6939.752
# Profit/Loss: 4.57
#
# Trade Type: SELL
# Entry Time: 2023-08-16 19:49:00, Entry Price: 6944.8
# Exit Time: 2023-08-16 19:50:00, Exit Price: 6940.832
# Profit/Loss: 3.97
#
# Trade Type: SELL
# Entry Time: 2023-08-16 20:10:00, Entry Price: 6949.127
# Exit Time: 2023-08-16 20:11:00, Exit Price: 6945.791
# Profit/Loss: 3.34
#
# Total Profit/Loss: 9279.73
# Total Trades: 1263
